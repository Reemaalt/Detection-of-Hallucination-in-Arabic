# %% [markdown]
# <a href="https://colab.research.google.com/github/Reemaalt/Detection-of-Hallucination-in-Arabic/blob/main/Human_labeling_and_cleaning_generations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Annotate Groundtruths

# %%
import json
import random
import re
import os

def is_english(text):
    #this checks if the text contains more English characters than non-English
    english_char_pattern = re.compile(r'[a-zA-Z]')
    non_english_char_pattern = re.compile(r'[^\x00-\x7F]')

    english_chars = len(english_char_pattern.findall(text))
    non_english_chars = len(non_english_char_pattern.findall(text))

    return english_chars > non_english_chars

def annotate_data():
    input_file = input("Enter your file path: ")
    output_file = input_file.replace('.json', '_modified.json')
    sample_file = input_file.replace('.json', '_sample.json')

    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    print(f"Loaded {len(data)} questions from file.")

    #create a copy for modification
    modified_data = data.copy()

    #adding placeholders for labels and handle English answers
    english_groundtruths = []
    for question_id, content in data.items():
        # Check if original answer is in English
        if "original_answer" in content and is_english(content["original_answer"]):
            english_groundtruths.append(question_id)

        #add placeholders regardless of language
        if "question_label" not in content:
            modified_data[question_id]["question_label"] = ""

        for cluster in modified_data[question_id].get("clusters", []):
            for answer_item in cluster.get("answers", []):
                if len(answer_item) == 2:  # If it's [answer, score]
                    answer_item.append("")  # Add answer label placeholder

    # Handle English original answers if any exist
    if english_groundtruths:
        print(f"\nFound {len(english_groundtruths)} questions with English original answers.")

        for question_id in english_groundtruths:
            content = modified_data[question_id]
            print(f"\nQuestion ID: {question_id}")
            print(f"Question: {content['question']}")
            print(f"Current Original Answer: {content['original_answer']}")

            new_answer = input("Enter translated original answer (or press Enter to keep current): ")
            if new_answer:
                modified_data[question_id]["original_answer"] = new_answer
                print("Answer updated")
            else:
                print("Answer unchanged")
    else:
        print("No questions with English original answers found.")

    #select 100 random questions for the sample file
    sample_keys = random.sample(list(data.keys()), 100)
    sample_data = {k: modified_data[k] for k in sample_keys}

    # Remove sampled questions from the main data
    for k in sample_keys:
        modified_data.pop(k)

    #save sampled data
    with open(sample_file, 'w', encoding='utf-8') as f:
        json.dump(sample_data, f, ensure_ascii=False, indent=4)
    print(f"\nSaved 100 random questions to {sample_file}")

    #save modified data
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(modified_data, f, ensure_ascii=False, indent=4)
    print(f"Saved modified data to {output_file}")

# %%
annotate_data()
# Out:
# Enter your file path: entailment_clusters_Llama3.1-8b-xor_tydiqa.json
# Loaded 708 questions from file.
#
# Found 68 questions with English original answers.
#
# Question ID: -2275140940114918987
# Question: هل زار ابن بطوطة اليمن؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 2644346659247031062
# Question: هل توجد قواعد عسكرية فرنسية في جيبوتي؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -525316578670747929
# Question: هل يوجد لقاح للحدّ من مرض حمى الضنك؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -240961318888839500
# Question: هل هناك تساوي بين الرجل والمرأة في الهند ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: -3514747139730663213
# Question: هل يمكن وصف دواء نيترازيبام للمصابين بالسكري ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 3661870610421663093
# Question: هل يهطل الثلج في جنوب أفريقيا؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -7061991093333947865
# Question: هل المثلية الجنسبة مشرعة في روسيا؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 3446235732612001784
# Question: هل هوليويد  تتنج الأفلام الإباحية؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 8565103393138035907
# Question: هل تقنية الجيل الخامس تعتبر خطرة ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: -6856719717136926903
# Question: هل القرآن من حافظ علي اللغة العربية ليومنا هذا ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -8194281104466613799
# Question: هل يمثل الأفارقة أكثر اللّاجئين في العالم؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: -8415036766977218184
# Question: هل يمكن تخزين الجينات البشرية؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 3502011813630983094
# Question: هل هناك علاج لي حمي ماربور؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: -4613718306297354582
# Question: هل المثليون معرضون بنسبة أكثر إلي متلازمة نقص المناعة المكتسبة ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -829036627684848566
# Question: هل يمكن نقل الوعي البشري إلى دماغ آلي ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: -1406141124033401191
# Question: لماذا تم تسمية نبتة القديس يوحنا المثقبة بهذا الإسم ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 5711550411274939437
# Question: هل يعتبر التشدد الديني شكلا من اشكال الفاشية؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 2321250568829211656
# Question: هل الهرمونات هى المسبب الرئيسي للعواطف ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 5501121917215292794
# Question: هل كندا تساعد في تجنب الإحتباس الحراري ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -2743274644814708252
# Question: هل تمتلك أي دولة حدودا ً برية مع ايرلندا؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 8295525145007665416
# Question: هل تنتج شجرة السماء ثماراً ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 4298311044092876001
# Question: هل بؤدي نقص فيتامين بي 12 الى التهاب الاطراف؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -181547103888650582
# Question: هل يوجد حزب شيوعي في الكويت؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 351298879969738607
# Question: هل حيازة الأسلحة قانوني في ولاية أوكلاهوما الأمريكية ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 3097328361883556881
# Question: هل تدعم الديانات الوحدانية نظرية التطور؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 5285184931143085675
# Question: هل يعد بركان سترومبولي من البراكين النشطة في ايطاليا؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -3340154248186072670
# Question: هل تم تدمير بيت المقدس خلال الحرب الصليبية الأولى ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 3527694787492110685
# Question: هل كبريتيد الزنك ذا لون أصفر؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: -2667488543695144896
# Question: هل البتراء الأردنية مدرجة على لائحة اليونسكو للتراث العالمي؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -1685051248539882021
# Question: هل يمكن تعديل البروكسي لتجنب الحضر علي بعض المواقع المحضورة ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -6567694797184049120
# Question: هل    وباكليتاكسيل هو دواء يساعد على التخفيف من  الميلانوما؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -6707077121483046145
# Question: هل الميلانوما مؤلمة ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 4831393778874802181
# Question: هل هنالك تشابه في التوحيد بين الديانة اليهودية والإسلام؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 4592318755363704682
# Question: هل تعد الحشرات من ذوات الدم البارد؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -306681433041987381
# Question: هل يحوي لحم الأرنب على السكريات؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -3431099828060106781
# Question: هل يمكن علاج سرطان الدماغ ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 3372073478214272026
# Question: هل يسمى عيد الفطر باسم العيد الكبير ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 1287195155166960643
# Question: هل رتبة الشماسية هي ادنى الرتب الكهنوتية في الكنيسة؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 7141649886798701040
# Question: هل التعليم في الجامعات الحكومية في سوريا يتم بللغة العربية؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: -485565942849333620
# Question: هل يمكن أن يصيب السرطان الشرج؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -3273256070984452919
# Question: هل أفلاطون فيلسوف يوناني؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 3690152581462837378
# Question: هل تحصلت الأردن على كأس آسيا لكرة القدم ؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 4649321140015379049
# Question: هل الميثان هو أبسط الهيدروكربونات؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 2477744247078614337
# Question: هل يذوب حمض الكبريتيك في الماء ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 1010866703034430598
# Question: هل يساهم التلوث الضوضائي في الامراض النفسية؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 677031460678707248
# Question: هل الأندلس هو الاسم الذي أطلقه المسلمون على شبه جزيرة أيبيريا؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -6596145305155678886
# Question: هل تؤدي البُرْفيرِيَّةٌ إلى  ألم في البطن وقيء؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 4061190988877246563
# Question: هل يحتوي الغلاف الجوي على غاز الآرغون؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -8531231185125485054
# Question: هل كان يلقب مايكل جاكسون ب ملك البوب؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 4030082186437822652
# Question: هل يأثر التدخين على صحة الجنين ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -1877497777816268141
# Question: هل يكون الشخص واعيا خلال نوبة شلل النوم؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 731376935545437173
# Question: هل توجد قبائل طوراق في موريتانيا؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 5180565872103207121
# Question: هل ينشطر اليورانيوم طبيعيا ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -3230154906044902229
# Question: هل تختلف عدد الجينات بين الذكر و الأنثى؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 6064782969762135686
# Question: هل ممكن أن يسبب مرض الماء الأزرق العمى؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 7624165879587554172
# Question: هل المغني خوليو إجلسياس هو والد المغني انريكي إجلسياس؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -977773631799938987
# Question: هل النرجسية مرض من أمراض اضطراب الشخصية؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -884348111383067534
# Question: هل توحد بورصة في مصر؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -5846760312909928950
# Question: هل يطبق حكم الإعدام في السعودية ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 3790996546097785323
# Question: هل تنتقل المعلومات عبر الخلايا العصبية بسرعات مختلفة في الدماغ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 8831046622311867276
# Question: هل  تطل إستونيا على بحر البطليق ؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 6636944240188714235
# Question: ما هو الفيروس المسبب للهربس النطاقي؟
# Current Original Answer: Varicella-Zoster Virus
# Enter translated original answer (or press Enter to keep current): فيروس جدري الماء النطاقي
# Answer updated
#
# Question ID: 8048925719678264026
# Question: هل علي بن أبي طالب هو رابع الخلفاء الراشدين؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -2914384853166503371
# Question: هل حارب عبد الله بن الزبير بن العوام الأسدي القرشي مع جيش المسلمين؟
# Current Original Answer: no
# Enter translated original answer (or press Enter to keep current): لا
# Answer updated
#
# Question ID: 2619371864438605103
# Question: هل تسبب اشعة الـيو في مرض سرطان الجلد؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -5483492060525995875
# Question: هل يعتبر دستور الولايات المتحدة وثيقة علمانية؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: -68695569273057092
# Question: هل هرقل يعتبر آلهة إغريقية؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Question ID: 3989000223354134411
# Question: هل الغثيان  واليرقان من أعراض  التهاب الكبد الفيروسي ج؟
# Current Original Answer: yes
# Enter translated original answer (or press Enter to keep current): نعم
# Answer updated
#
# Saved 100 random questions to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
# Saved modified data to entailment_clusters_Llama3.1-8b-xor_tydiqa_modified.json

# %% [markdown]
# #Annotate answers & Questions

# %%
def huamn_labeling():
  sample_file = input("Enter your sample file path: ")
  print("For each answer, enter 'H' for Hallucinated or 'N' for Non-Hallucinated")

  # Load the sample data
  with open(sample_file, 'r', encoding='utf-8') as f:
      sample_data = json.load(f)

  #process each question
  for question_id, content in sample_data.items():
      print(f"\n\nQuestion ID: {question_id}")
      print(f"Question: {content['question']}")
      print(f"Original Answer: {content['original_answer']}")

      non_hallucinated_count = 0
      total_answers = 0

      #processing each answer in each cluster
      for cluster in content.get("clusters", []):
          print(f"\nCluster {cluster['cluster_number']}:")

          for i, answer_item in enumerate(cluster.get("answers", [])):
              answer_text = answer_item[0]
              print(f"\n[{i+1}] {answer_text}")

              valid_label = False
              while not valid_label:
                  label = input("Label (H/N): ").strip().upper()
                  if label in ['H', 'N']:
                      valid_label = True
                      # Store full label text
                      answer_label = "Non-Hallucinated" if label == 'N' else "Hallucinated"
                      answer_item[2] = answer_label

                      if label == 'N':
                          non_hallucinated_count += 1
                      total_answers += 1
                  else:
                      print("Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.")

      #determine question label
      if non_hallucinated_count >= 6:
          question_label = "Non-Hallucinated"
      else:
          question_label = "Hallucinated"

      content["question_label"] = question_label
      print(f"\nQuestion Label: {question_label} (based on {non_hallucinated_count}/{total_answers} non-hallucinated answers)")

      # Save after each question in case the process is interrupted
      with open(sample_file, 'w', encoding='utf-8') as f:
          json.dump(sample_data, f, ensure_ascii=False, indent=4)
      print(f"Progress saved to {sample_file}")

  print("\nAnswer labeling complete!")

# %%
huamn_labeling()
# Out:
# Streaming output truncated to the last 5000 lines.
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 7835952656544964295
# Question: ما هي الكاروتينات ؟
# Original Answer: صبغات عضوية تيتراتيربينويدية (tetraterpenoid) صفراء اللون ، توجد بشكل طبيعي في الخضروات والفاكهة
#
# Cluster 0:
#
# [1] الكاروتينات هي مركبات كيميائية من الفيتامينات التي توجد في الطعام مثل البطاطس والفلفل والخضروات الخضراء والفواكه الحمراء والبرتقال، وتتألف من مركبات كيميائية تؤدي دورًا مهمًا في صحة الإنسان
# Label (H/N): n
#
# Cluster 1:
#
# [1] الكاروتينات هي مركبات عضوية متعددة الجزيئات مشتقة من الفيتامين أ
# Label (H/N): n
#
# [2] الكاروتينات هي فصائل من الفيتامينات، وتشمل فيتامين أ (البيتا كاروتين) وفيتامين أ (ألفا كاروتين) وفيتامين أ (بيتا كاروتين) وفيتامين أ (جاما كاروتين)
# Label (H/N): n
#
# Cluster 2:
#
# [1] الكاروتينات هي مركبات ك
# Label (H/N): h
#
# Cluster 3:
#
# [1] الكاروتينات هي مركبات عضوية من الفيتامينات الموجودة في الخضار والفواكه
# Label (H/N): h
#
# [2] الكاروتينات هي مركبات كيميائية متعددة الوظائف، وتتألف من مركبات كيميائية تسمى البيريداز، وهي مركبات كيميائية تعتمد على الهيدروجين والكربون والنيتروجين، وهي توجد في العديد من الأطعمة، مثل الفواكه والخضروات، وهي تؤدي دورًا هامًا في الحفاظ على صحة الجسم، وتعتبر مركبات كيميائية قوية، وتؤدي دورًا
# Label (H/N): h
#
# Cluster 4:
#
# [1] الكاروتينات هي مجموعة من المركبات العضوية التي توجد في العديد من الأطعمة مثل الفواكه والخضروات، وتعتبر مصدرًا رئيسيًا للفيتامين A في النظام الغذائي البشري
# Label (H/N): n
#
# Cluster 5:
#
# [1] الكاروتينات هي مركبات كيميائية توجد في النباتات والحيوانات، وتشمل البتا كاروتين والفيتامين أ
# Label (H/N): h
#
# Cluster 6:
#
# [1] الكاروتينات هي مجموعة من المواد الكيميائية التي تكون موجودة في بعض النباتات، وهي تُعتبر من المصادر الرئيسية للفيتامين أ والفيتامين د في النظام الغذائي البشري
# Label (H/N): n
#
# Cluster 7:
#
# [1] الكاروتينات هي مركبات كيميائية تعتبر مصدرًا رئيسيًا للفيتامين أ، وهي موجودة بشكل طبيعي في العديد من الأطعمة مثل الفواكه والخضروات والبذور
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 3594222040211173813
# Question: من هم القوط؟
# Original Answer: قبائل جرمانية شرقية
#
# Cluster 0:
#
# [1] قبل أن ينت
# Label (H/N): h
#
# Cluster 1:
#
# [1] القوط هم شعباً جرمانياً عاشوا في أوروبا الغربية في العصور الوسطى، كانوا يعتبرون من القبائل الجرمانية التي هاجرت إلى أوروبا الغربية
# Label (H/N): n
#
# Cluster 2:
#
# [1] القوط هم مجموعة عرقية جرمانية قديمة من أصل أوروبي شرقي، نشأت في أواخر العصر الروماني وبداية العصور الوسطى، في منطقة بحر قزوين وشمال بحر الأسود
# Label (H/N): n
#
# Cluster 3:
#
# [1] القوط هم شعباً جرمانياً عاشوا في أوروبا الغربية في العصور الوسطى
# Label (H/N): n
#
# [2] القوط هم مجموعة من الشعوب الأوربية التي نشأت في منطقة القوقاز في القرن الخامس الميلادي، وتزعم أنهم من نسل القوط، وهم من أهم القبائل الأوربية التي هاجرت إلى أوروبا الغربية، وهم من أهم القبائل التي هاجرت إلى أوروبا الغربية في العصور الوسطى
# Label (H/N): h
#
# Cluster 4:
#
# [1] القوط هم شعب جرماني قديم، كانوا يعيشون في أوروبا الشرقية في العصور القديمة والوسطى
# Label (H/N): n
#
# Cluster 5:
#
# [1] القوط هم قبيلة جرمانية من الشعوب الجرمانية، وهم من أصول أوروبية، وهم من أصل جرماني، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أصول جرمانية، وهم من أ
# Label (H/N): n
#
# [2] القوط هم شعوب جرمانية، وهم من أصل عرقي قريب من العرقيات الألمانية والدانية، وهم أصلعون، وهم يعيشون في أوروبا الغربية، وهم يعيشون في أوروبا الغربية، وهم يعيشون في أوروبا الغربية، وهم يعيشون في أوروبا الغربية، وهم يعيشون في أوروبا الغربية، وهم يعيشون في أوروبا الغربية، وهم يعيشون في أوروبا الغ
# Label (H/N): n
#
# Cluster 6:
#
# [1] القوط هم مجموعة من الشعوب الأوروبية الغربية التي نشأت في أوائل القرن الخامس الميلادي في منطقة البلقان، وكانت تعيش في إقليم القوطية، وتمتد من نهر الدانوب في الشمال إلى البحر الأدرياتيكي في الجنوب، وتمتد من نهر الدانوب إلى البحر الأسود في الشرق، وتمتد إلى البحر الأبيض المتوسط في الغرب
# Label (H/N): h
#
# Cluster 7:
#
# [1] القوط هم شعباً جرمانياً نشأوا في أواخر العصور القديمة وبداية العصور الوسطى في منطقة برابانتيا، التي تقع في شمال أوروبا، وهم يعتبرون من أقرب الشعوب الجرمانية إلى الرومان، وقد سكنوا في الغالب في المناطق الواقعة جنوب نهر الراين، وبالتالي كانوا على تماس وثيق مع الرومان، وهم كانوا من أهم الشعوب التي ساهمت في تكوين أوروبا
# Label (H/N): n
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 7098678477313023653
# Question: كم عدد العضلات التي تربط اللسان بالفك؟
# Original Answer: 4
#
# Cluster 0:
#
# [1] تسعة عضلات تربط اللسان بالفك
# Label (H/N): h
#
# Cluster 1:
#
# [1] العضلات التي تربط اللسان بالفك هي:
# Label (H/N): h
#
# [2] العضلات الستة التي تربط اللسان بالفك هي: العضلة البلعومية، والعضلة البلعومية اللسانية، والعضلة البلعومية الفكية، والعضلة البلعومية الفكية اللسانية، والعضلة البلعومية الفكية الذقنية، والعضلة البلعومية الذقنية
# Label (H/N): h
#
# Cluster 2:
#
# [1] ثلاث عضلات ترب
# Label (H/N): h
#
# [2] ثلاثة عضلات تربط ال
# Label (H/N): h
#
# Cluster 3:
#
# [1] 12 عضلة
# Label (H/N): h
#
# Cluster 4:
#
# [1] 4 عضلات
# Label (H/N): n
#
# Cluster 5:
#
# [1] 8
# Label (H/N): h
#
# Cluster 6:
#
# [1] العضلة اللعابية هي عضلة خيطية، وتتصل باللسان في الجز
# Label (H/N): h
#
# Cluster 7:
#
# [1] عضلة المجرور
# Label (H/N): h
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 559171685534849
# Question: في أي عام تم اختراع الفاكس ؟
# Original Answer: عام 1964
#
# Cluster 0:
#
# [1] استخدم صامويل مورس طريقة الأشعة الصادعة لاختراع الفاكس
# Label (H/N): h
#
# Cluster 1:
#
# [1] الوظيفة الأساسية للفاكس هي ارسال الرسائل وال
# Label (H/N): h
#
# Cluster 2:
#
# [1] يمكنها نقل الصور والرسائل والوثائق بسرعة
# Label (H/N): h
#
# Cluster 3:
#
# [1] الفاكس يسمى
# Label (H/N): h
#
# Cluster 4:
#
# [1] التكنولوجيا الرقمية
# Label (H/N): h
#
# Cluster 5:
#
# [1] في مجال الأعمال والتواصل
# Label (H/N): h
#
# Cluster 6:
#
# [1] أليكسندر جراه
# Label (H/N): h
#
# Cluster 7:
#
# [1] مصر
# Label (H/N): h
#
# Cluster 8:
#
# [1] أنتوني سكوت
# Label (H/N): h
#
# Cluster 9:
#
# [1] صامويل مورس
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -5740024306765732629
# Question: في أي عام تمت تصفية محافظ بغداد علي الحيدري؟
# Original Answer: تشرين الأول عام 2004
#
# Cluster 0:
#
# [1] الحزب الإسلامي
# Label (H/N): h
#
# Cluster 1:
#
# [1] الاضطرابات السياسية والصراعات بين الحكومة
# Label (H/N): h
#
# Cluster 2:
#
# [1] تاريخ وفاة علي الحيدري غير معروف
# Label (H/N): h
#
# Cluster 3:
#
# [1] 2003
# Label (H/N): h
#
# [2] 2003
# Label (H/N): h
#
# Cluster 4:
#
# [1] المافيا
# Label (H/N): h
#
# Cluster 5:
#
# [1] 2006
# Label (H/N): h
#
# Cluster 6:
#
# [1] مهدي
# Label (H/N): h
#
# Cluster 7:
#
# [1] السيد علي الحيدري
# Label (H/N): h
#
# Cluster 8:
#
# [1] الحزب الوطني العراقي
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 731376935545437173
# Question: هل توجد قبائل طوراق في موريتانيا؟
# Original Answer: لا
#
# Cluster 0:
#
# [1] نعم، هناك قبائل طوراق في موريتانيا
# Label (H/N): h
#
# [2] قبائل موريتانيا تتضمن قبائل البديل، والوازاب، والبيزاوة، والوارلا، والوازناغ، والواركينين، والوارلا، والواركينين، والواركينين، والواركينين، والواركينين، والواركينين، والواركينين، والوارك
# Label (H/N): h
#
# [3] نعم، توجد قبائل طوراق في موريتانيا
# Label (H/N): h
#
# [4] توجد في موريتانيا العديد من القبائل، مثل: البولان، والولوف، والبيزانجا، والبربر، والسماسال، والسماسل، والسماسل، والسماسل، والسماسل، والسماسل، والسماسل، والسماسل، والسماسل، والسماسل، والسم
# Label (H/N): h
#
# [5] نعم، توجد قبائل طوراق في موريتانيا
# Label (H/N): h
#
# [6] نعم، توجد قبائل طوراق في موريتانيا
# Label (H/N): h
#
# Cluster 1:
#
# [1] قبائل الطوارق هي مجموعة قبائل بدوية تعيش في صحراء الصحارى في شمال أفريقيا، وهم يعيشون
# Label (H/N): h
#
# Cluster 2:
#
# [1] قبائل طوراق هي قبائل عربية تعيش في موريتانيا
# Label (H/N): h
#
# Cluster 3:
#
# [1] اللغة الرسمية في موريتانيا هي اللغة العربية
# Label (H/N): h
#
# Cluster 4:
#
# [1] الطوراق هي قبيلة من قبائل الصحراء الغربية وموريتانيا
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 335743688712966179
# Question: متى تم تأسيس التحالف الديمقراطي الكردي في سوريا؟
# Original Answer: 13 شباط عام 2016
#
# Cluster 0:
#
# [1] 2014
# Label (H/N): h
#
# Cluster 1:
#
# [1] 2012
# Label (H/N): h
#
# Cluster 2:
#
# [1] يعتبر التحالف جزءًا من الحركة الكردية في
# Label (H/N): h
#
# Cluster 3:
#
# [1] 2003
# Label (H/N): h
#
# [2] 2003
# Label (H/N): h
#
# [3] 2003
# Label (H/N): h
#
# [4] 2003
# Label (H/N): h
#
# [5] 2003
# Label (H/N): h
#
# Cluster 4:
#
# [1] تم تأسيس التحالف الديمقراطي الكردي في سوريا في عام 2003
# Label (H/N): h
#
# Cluster 5:
#
# [1] The Kurdish Democratic Alliance in Syria was founded in 2003
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -8526828217368550297
# Question: أين  وقعت أول جريمة قتل في البشرية؟
# Original Answer: عرف الإنسان الجريمة منذ فجر البشرية منذ هابيل وقابيل حيث وقعت أول جريمة قتل في التاريخ الإنساني
#
# Cluster 0:
#
# [1] في مصر
# Label (H/N): ا
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): h
#
# Cluster 1:
#
# [1] سُميت الحضارة المصرية القديمة أول حضارة في العالم
# Label (H/N): h
#
# Cluster 2:
#
# [1] في مكان ما في أفريقيا
# Label (H/N): ا
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): h
#
# [2] في أفريقيا
# Label (H/N): h
#
# [3] في أفريقيا
# Label (H/N): h
#
# Cluster 3:
#
# [1] القاهرة
# Label (H/N): h
#
# Cluster 4:
#
# [1] منس
# Label (H/N): h
#
# Cluster 5:
#
# [1] في وادي هومو هابيليس
# Label (H/N): h
#
# Cluster 6:
#
# [1] في شلالات نهر النيل
# Label (H/N): h
#
# Cluster 7:
#
# [1]
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 3097328361883556881
# Question: هل تدعم الديانات الوحدانية نظرية التطور؟
# Original Answer: لا
#
# Cluster 0:
#
# [1] لا تدعم معظم الديانات الوحدانية نظرية التطور
# Label (H/N): h
#
# [2] لا تدعم معظم الديانات الوحدانية نظرية التطور
# Label (H/N): n
#
# [3] لا تدعم الديانات الوحدانية نظرية التطور بشكل مباشر
# Label (H/N): n
#
# Cluster 1:
#
# [1] البهائية هي ديانة وحدانية تأسست في القرن التاسع عشر في إيران، تدعو إلى وحدة جميع الأديان و
# Label (H/N): h
#
# Cluster 2:
#
# [1] لا تدعم الديانات الوحدانية نظرية التطور
# Label (H/N): n
#
# [2] لا تدعم الديانات الوحدانية نظرية التطور
# Label (H/N): n
#
# Cluster 3:
#
# [1] لا تدعم الديانات الوحدانية نظرية التطور، حيث تعتبر الحياة بكل ما فيها من تنوع وتطورات كخلق من الله، ولا تؤمن بالتطورات التي يحدثها الاصطفاء الطبيعي
# Label (H/N): n
#
# Cluster 4:
#
# [1] إسرائيل هي بلد مسيحي
# Label (H/N): h
#
# Cluster 5:
#
# [1] نعم، تدعم معظم الديانات الوحدانية نظرية التطور، حيث تؤمن هذه الديانات بالوحدة والتنوع في الخليقة، وتدعم فكرة التطور من خلال النظريات العلمية
# Label (H/N): h
#
# Cluster 6:
#
# [1] بعض الديانات الوحدانية هي اليهودية، المسيحية، الإسلام، البهائية، والهندوس
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -2097151119901942214
# Question: اين ظهرت الدولة النجاحية؟
# Original Answer: زبيد في منطقة تهامة (الأراضي المنخفضة) في اليمن
#
# Cluster 0:
#
# [1] ظهرت الدولة النجاحية في الص
# Label (H/N): h
#
# Cluster 1:
#
# [1] ظهرت الدولة النجاحية في إسرائيل في عام 1948
# Label (H/N): h
#
# Cluster 2:
#
# [1] دولة عرب
# Label (H/N): n
#
# Cluster 3:
#
# [1] ظهرت الدولة النجاحية في القرن التاسع عشر في أمريكا الشمالية
# Label (H/N): h
#
# Cluster 4:
#
# [1] دولة النجاح هي دولة تتمتع بالازدهار الاقتصادي والاجتماعي
# Label (H/N): h
#
# Cluster 5:
#
# [1] ظهرت الدولة النجاحية في أوروبا
# Label (H/N): h
#
# Cluster 6:
#
# [1] ظهرت الدولة النجاحية في إسرائيل
# Label (H/N): h
#
# [2] ظهرت الدولة النجاحية في إسرائيل
# Label (H/N): h
#
# Cluster 7:
#
# [1] ظهرت الدولة النجاحية في السنوات ال 12 الأخيرة في الدول المتقدمة
# Label (H/N): h
#
# Cluster 8:
#
# [1] ظهرت الدولة النجاحية في كاليفورنيا
# Label (H/N): h
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -590642422275652377
# Question: من هو مؤسس الحركة الكشفية الكشافة؟
# Original Answer: اللورد روبرت ستيفنسون سميث بادن باول
#
# Cluster 0:
#
# [1] روبرت بادن باول
# Label (H/N): n
#
# [2] روبرت بادن باول
# Label (H/N): n
#
# [3] روبرت بادن باول
# Label (H/N): n
#
# [4] روبرت بادن باول
# Label (H/N): n
#
# [5] روبرت بادن باول
# Label (H/N): n
#
# [6] روبرت بادن باول
# Label (H/N): n
#
# [7] روبرت بادن باول
# Label (H/N): n
#
# Cluster 1:
#
# [1] الثقة، الإخلاص، الصدق، المسؤولية، اللياقة البدنية، التضامن، الالتزام بالوعد
# Label (H/N): h
#
# Cluster 2:
#
# [1] سرجون سبيبي
# Label (H/N): h
#
# Cluster 3:
#
# [1] روبر
# Label (H/N): h
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -652823526357312622
# Question: متى إنتشر فكر المعتزلة في مصر ؟
# Original Answer: القرن الثاني الهجري
#
# Cluster 0:
#
# [1] الإمام البخاري
# Label (H/N): h
#
# Cluster 1:
#
# [1] الشريف المرتضي هو واحد من أشهر الفلاسفة المعتزلة في مصر
# Label (H/N): h
#
# Cluster 2:
#
# [1] في القرن الرابع الهجري
# Label (H/N): h
#
# Cluster 3:
#
# [1] في القرن التاسع الهجري
# Label (H/N): h
#
# Cluster 4:
#
# [1] يعتبر المعتزلة من الفلاسفة المسلمين، وهم معروفون بإيمانهم بال
# Label (H/N): h
#
# Cluster 5:
#
# [1] إنتشر فكر المعتزلة في مصر في القرن الرابع الهجري
# Label (H/N): h
#
# Cluster 6:
#
# [1] كتاب "المنطق" لأبي الحسن بن الحسين بن علي بن الحسين بن الحسن بن علي بن الحسين بن علي بن الحسين بن علي بن الحسين بن علي بن الحسين بن علي بن الحسين بن علي بن الحسين بن علي بن الحسين بن علي بن الحسين بن علي بن
# Label (H/N): h
#
# [2] خلال
# Label (H/N): h
#
# Cluster 7:
#
# [1] يعني اسم المعتزلة "الم
# Label (H/N): h
#
# Cluster 8:
#
# [1] أهم ما يميز المعتزلة هو تعريفهم للكلام بالعقل والفهم، حيث يعتقدون أن الكلام عن
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -3514575832935529925
# Question: كم تبعد مدينة الدار البيضاء عن اكادير؟
# Original Answer: 508 كم
#
# Cluster 0:
#
# [1] تبعد مدينة الدار البيضاء عن مدينة ط
# Label (H/N): h
#
# [2] تبعد مدينة الدار البيضاء عن مدينة ف
# Label (H/N): h
#
# [3] تبعد مدينة الدار البيضاء عن مدينة طنجة
# Label (H/N): h
#
# Cluster 1:
#
# [1] يبلغ عدد سكان مدينة الدار البيضاء 3,359,000 نسمة
# Label (H/N): h
#
# Cluster 2:
#
# [1] 2,655 كم
# Label (H/N): h
#
# Cluster 3:
#
# [1] تب
# Label (H/N): h
#
# [2] يضم إ
# Label (H/N): h
#
# [3]
# Label (H/N): h
#
# Cluster 4:
#
# [1] مدينة الدار
# Label (H/N): h
#
# Cluster 5:
#
# [1] تبعد مدينة الدار البيضاء عن مدينة أكادير 513 كم
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 3305084109647378356
# Question: متى قام  رينيه ديكارت بنشر المقال عن المنهج؟
# Original Answer: 1637
#
# Cluster 0:
#
# [1] الفكرة التي طرحها ديكارت هي أن المعرفة يمكن أن تكون مُستقلة عن الخبرة السابقة، وأن
# Label (H/N): h
#
# Cluster 1:
#
# [1] في عام 1637
# Label (H/N): n
#
# [2] 1637
# Label (H/N): n
#
# [3] 1637
# Label (H/N): n
#
# [4] في عام 1637
# Label (H/N): n
#
# [5] في عام 1637م
# Label (H/N): n
#
# [6] 1637
# Label (H/N): n
#
# Cluster 2:
#
# [1] قام رينيه ديكارت بنشر المقال عن المنهج في عام 1637
# Label (H/N): n
#
# Cluster 3:
#
# [1] المقال عن المنهج
# Label (H/N): h
#
# Cluster 4:
#
# [1] لتعريف الناس بالمنهج العلمي
# Label (H/N): h
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -4658981066655540066
# Question: من هو الإسكندر الأفروديسي؟
# Original Answer: فيلسوف وجدلي ومن أكبر شراح أرسطو في العصر اليوناني الروماني
#
# Cluster 0:
#
# [1] الإسكندر الأفروديسي هو رجل أعمال إغريقي، وهو مؤسس شركة إسكندر الأفروديسي، وهي شركة عالمية للبقالة
# Label (H/N): h
#
# Cluster 1:
#
# [1] الإسكندر الأفروديسي (باللغة الإغريقية: Ἀλέξανδρος ὁ Ἀφροδισεύς) هو أستاذ في الفلسفة في أكاديمية أثينا
# Label (H/N): n
#
# Cluster 2:
#
# [1] الإسكندر الأفروديسي هو طبيب يوناني قديم، اسمه بالكامل الإسكندر الفريجاني الأفروديسي
# Label (H/N): h
#
# Cluster 3:
#
# [1] الإسكندر الأفروديسي (الاسم اليوناني: Ἀλέξανδρος ὁ Ἀφροδισεύς) هو ملك بحريني قديم، من الأساطير اليونانية
# Label (H/N): h
#
# Cluster 4:
#
# [1] الإسكندر الأفروديسي هو عالم فيزيائي وفلكي يوناني من القرن الرابع قبل الميلاد، يُعتبر من أشهر علماء الفلك والفيزياء في العصر الهليني القديم
# Label (H/N): h
#
# Cluster 5:
#
# [1] الإسكندر الأفروديسي (الاسم اليوناني: Ἀλέξανδρος Ἀφροδίσεος) هو كاتب ساخر قديم من اليونان، يُعتبر من أبرز كتاب السخرية في العصور القديمة
# Label (H/N): h
#
# Cluster 6:
#
# [1] الإسكندر الأفروديسي هو باحث وفيلسوف يوناني قديم، اشتهر بالبحث في مجال الرياضيات والفيزياء
# Label (H/N): h
#
# Cluster 7:
#
# [1] الإسكندر الأفروديسي هو قائد البحرية البطلمية الذي قاد حملة ضد الإسكندر الأكبر
# Label (H/N): h
#
# Cluster 8:
#
# [1] الإسكندر الأفروديسي هو عالم فيزيائي وعالم رياضيات من إسكندريه، اشتهر بالعديد من المساهمات في مجالات الرياضيات والفيزياء، ومن أشهر هذه المساهمات تطويره لما يعرف ب "نظرية الأشعة" أو "نظرية الإشعاع"
# Label (H/N): h
#
# Cluster 9:
#
# [1] الإسكندر الأفروديسي (أو الإسكندر الأثيني) (350-330 ق
# Label (H/N): h
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -145897886688806563
# Question: من هو مخرج فيلم شغف المسيح ؟
# Original Answer: ميل غيبسون
#
# Cluster 0:
#
# [1] مخرج فيلم شغف المسيح هو كريستوفر نولان
# Label (H/N): h
#
# Cluster 1:
#
# [1] ديرك بارتون
# Label (H/N): h
#
# Cluster 2:
#
# [1] مخرج فيلم شغف المسيح هو جيف ناثانسون
# Label (H/N): h
#
# Cluster 3:
#
# [1] كريستوف نولين هو مخرج سينمائي فرنسي من مواليد 11 سبتمبر 1964
# Label (H/N): h
#
# Cluster 4:
#
# [1] جيف ناثانسون
# Label (H/N): h
#
# Cluster 5:
#
# [1] ريتشارد آتكينسون
# Label (H/N): h
#
# Cluster 6:
#
# [1] روبرت زيميكس
# Label (H/N): h
#
# Cluster 7:
#
# [1] بيتر جاكسون
# Label (H/N): h
#
# Cluster 8:
#
# [1] إيطاليا
# Label (H/N): h
#
# Cluster 9:
#
# [1] كريستوفر نولان
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 8692357650181441889
# Question: من يصادق على ميزانية الدولة في كندا؟
# Original Answer: مجلس عموم
#
# Cluster 0:
#
# [1] البرلمان الكندي
# Label (H/N): h
#
# [2] البرلمان الكندي
# Label (H/N): ر
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): n
#
# [3] البرلمان الكندي
# Label (H/N): n
#
# [4] مجلس العموم الكندي
# Label (H/N): n
#
# Cluster 1:
#
# [1] الملكة في كندا
# Label (H/N): h
#
# Cluster 2:
#
# [1] الملكة
# Label (H/N): h
#
# Cluster 3:
#
# [1] رئيس وزراء كندا
# Label (H/N): h
#
# [2] رئيس وزراء كندا
# Label (H/N): h
#
# Cluster 4:
#
# [1] الملكة إليزابيث الثانية
# Label (H/N): h
#
# Cluster 5:
#
# [1] الحاكم العام
# Label (H/N): ا
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): h
#
# Question Label: Hallucinated (based on 3/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 7518290083831390999
# Question: من هو مؤسس إدارة الغذاء والدواء في الولايات المتحدة ؟
# Original Answer: هارفي واشنطن ويلي
#
# Cluster 0:
#
# [1] هيروزي ويلكيرز
# Label (H/N): h
#
# Cluster 1:
#
# [1] جيمس م
# Label (H/N): h
#
# Cluster 2:
#
# [1] من هو فرانكلين روزفلت
# Label (H/N): h
#
# Cluster 3:
#
# [1] لويس واكر
# Label (H/N): h
#
# Cluster 4:
#
# [1] سوليفان هاميلتون
# Label (H/N): h
#
# Cluster 5:
#
# [1] فرانكلين روزفلت
# Label (H/N): h
#
# Cluster 6:
#
# [1]
# Label (H/N): h
#
# [2]
# Label (H/N): h
#
# Cluster 7:
#
# [1] السيد فرانكلين كيوز
# Label (H/N): h
#
# Cluster 8:
#
# [1] Francis Kelsey
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -6911659915303991900
# Question: ما هو الجُمْرُك؟
# Original Answer: مصلحة ذات طابع اقتصادي وأمني مكلفة بمراقبة المبادلات التجارية على الحدود وجباية الضرائب على الواردات
#
# Cluster 0:
#
# [1] الجُمْرُك هو ماءٌ يُستَخدَم في الصلاة، وهو ماءٌ يُستَخدَم في غسل يدي المُؤمِن قبل الصلاة
# Label (H/N): h
#
# Cluster 1:
#
# [1] هو صَلَصَلَةٌ تُذَكى في الأَطوادِ مِنَ الخُطوبِ وَالخَصَبِ وَالأَشعَثِ وَالأَحجارِ وَالأَزَلَجِ وَالأَخضَرِ وَالأَبيضِ وَالأَحمرِ وَالأَسودِ وَالأَسمَرِ وَالأَصفرِ
# Label (H/N): h
#
# [2] الجُمْرُك هو جسمٌ يَكونُ مِنَ الخَيلِ، يُستَخدمُ لِتحمِيلِ العَربِ وَالرِجالِ في السَفَرِ
# Label (H/N): h
#
# [3] الجُمْرُك هو حجرٌ صَخريٌّ صَلبٌ تُحَفِّرُهُ الناسُ لِتَكُن لَهُ قِيَمٌ وَخَوَطَئٌ
# Label (H/N): h
#
# [4] الجُمْرُك: هو جسمٌ يُستخدم في تَجاوزَ ماءٍ عَلى السُفُنِ، وَهوَ مُصَصَّعٌ بِسِمارٍ مُتَوَقَّعَةٍ، وَيُستَخدمُ لِتَجاوَزِ المَخاوِفِ
# Label (H/N): h
#
# [5] الجُمْرُك هو مَخزونٌ مِنَ العَسَلِ يُستَخدَمُ في التَعَليلِ والَتَخزينِ
# Label (H/N): h
#
# Cluster 2:
#
# [1] الجُمْرُك هو قسيم من جسم الإنسان ي
# Label (H/N): h
#
# Cluster 3:
#
# [1] الجُمْرُك هو شجرة
# Label (H/N): h
#
# Cluster 4:
#
# [1] الجُمْرُك هو نوع من الخضروات
# Label (H/N): h
#
# Cluster 5:
#
# [1] الجُمْرُك هو نبات من نباتات القطبان
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -1486525074463532382
# Question: اين تقع مدينة كانكون ؟
# Original Answer: الشمال الشرقي لولاية كوينتانا رو في المكسيك
#
# Cluster 0:
#
# [1] يمكن مم
# Label (H/N): h
#
# Cluster 1:
#
# [1] أكبر مدينة في المكسيك هي
# Label (H/N): h
#
# Cluster 2:
#
# [1] تقع مدينة كانكون
# Label (H/N): h
#
# Cluster 3:
#
# [1] تقع مدينة كانكون في ولاية كينتانا رو في المكسيك
# Label (H/N): n
#
# [2] تقع مدينة كانكون في ولاية كينتانا رو في المكسيك
# Label (H/N): n
#
# [3] تقع مدينة كانكون في ولاية كينتانا رو في المكسيك
# Label (H/N): n
#
# [4] تقع مدينة كانكون في ولاية كينتانا رو في المكسيك
# Label (H/N): n
#
# Cluster 4:
#
# [1] الأنشطة الشهيرة في مدينة كانكون هي السياحة والاستجمام والرياضة والفنادق والمنتجعات
# Label (H/N): h
#
# Cluster 5:
#
# [1] تقع مدينة كانكون في المكسيك
# Label (H/N): n
#
# Cluster 6:
#
# [1] مدينة كانكون هي المدينة الأكثر زيارة في المكسيك
# Label (H/N): n
#
# Question Label: Non-Hallucinated (based on 6/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 1047525391986625045
# Question: كم عدد أنواع الطيور في جزيرة سقطرى ؟
# Original Answer: 291
#
# Cluster 0:
#
# [1] "جزيرة سقطرى: تاريخها وعلاقاتها مع اليمن"
# Label (H/N): h
#
# Cluster 1:
#
# [1] 29 نوعاً من الطيور
# Label (H/N): h
#
# [2] 29 نوعاً من الطيور
# Label (H/N): h
#
# [3] 29 نوعاً من الطيور
# Label (H/N): h
#
# Cluster 2:
#
# [1] 43 نوعًا من الطيور
# Label (H/N): h
#
# Cluster 3:
#
# [1] 195 نوعاً من الطيور
# Label (H/N): h
#
# Cluster 4:
#
# [1] يوجد في جزيرة سقطرى 44 نوعا من الطيور
# Label (H/N): h
#
# Cluster 5:
#
# [1] 30 نوعاً من الطيور
# Label (H/N): h
#
# Cluster 6:
#
# [1] أكثر من 50 نوعا
# Label (H/N): h
#
# Cluster 7:
#
# [1] يوجد في جزيرة سقطرى 44 نوعا من الطيور، ويُعتبر هذا العدد من أرقام الطيور الموجودة في الجزيرة من أعلى الأرقام في العالم
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -3935704791715085397
# Question: ما هي أكبر مدن ولاية أوريغون؟
# Original Answer: بورتلاند
#
# Cluster 0:
#
# [1] سياتل هي أكبر مدن ولاية واشنطن
# Label (H/N): h
#
# Cluster 1:
#
# [1] بيترزبورغ هي أكبر مدن ولاية أوريغون
# Label (H/N): h
#
# Cluster 2:
#
# [1] مينيابوليس هي أكبر مدن ولاية مينيسوتا
# Label (H/N): h
#
# Cluster 3:
#
# [1] بورتلاند
# Label (H/N): n
#
# [2] هي بورتلاند
# Label (H/N): n
#
# [3] بورتلاند
# Label (H/N): n
#
# Cluster 4:
#
# [1] برمنغ
# Label (H/N): h
#
# Cluster 5:
#
# [1] بورت
# Label (H/N): n
#
# [2] بورتل
# Label (H/N): n
#
# Cluster 6:
#
# [1] مدينة نايروبي
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 776468964493942164
# Question: أين تقع الاسكندرية؟
# Original Answer: مصر
#
# Cluster 0:
#
# [1] أشهر الفناد
# Label (H/N): h
#
# Cluster 1:
#
# [1] تقع مدينة الاسكندرية على ساحل البحر الأبيض المتوسط
# Label (H/N): h
#
# [2] تقع الإسكندرية على ساحل البحر الأبيض المتوسط في مصر
# Label (H/N): n
#
# Cluster 2:
#
# [1] اللغة العربية
# Label (H/N): h
#
# Cluster 3:
#
# [1] تقع الإسكندرية على ساحل البحر الأبيض المتوسط في شمال مصر
# Label (H/N): n
#
# Cluster 4:
#
# [1] بعض المعالم السياحية في الإسكندرية تشمل قلعة قايتباي ومحطة قطار الإسكندرية ومحطة قطار الإسكندرية وم
# Label (H/N): h
#
# Cluster 5:
#
# [1] تقع مدينة الاسكندرية في مصر
# Label (H/N): n
#
# Cluster 6:
#
# [1] مدينة الإسكندرية هي مدينة ساحلية تقع في شمال مصر، وتعتبر ثاني أكبر مدينة في مصر بعد القاهرة
# Label (H/N): n
#
# Cluster 7:
#
# [1] أهمية الإسكندر
# Label (H/N): h
#
# Cluster 8:
#
# [1] الإسكندرية هي مدينة ساحلية مصرية تقع على ساحل البحر الأبيض المتوسط
# Label (H/N): h
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -7923319957367231037
# Question: أين تقع مغارة جعيتا؟
# Original Answer: قضاء كسروان
#
# Cluster 0:
#
# [1] مغارة جع
# Label (H/N): h
#
# [2] تقع مغ
# Label (H/N): h
#
# Cluster 1:
#
# [1] المغارة تعتبر من أهم المعالم الأثرية في لبنان، وتتميز بغرفها الكبيرة والمتقنة التي تم إنشاؤها باليد، كما أنها تشهد على تاريخ لبنان القديم
# Label (H/N): h
#
# Cluster 2:
#
# [1] تقع مغارة جعيتا في لبنان، على بعد 8 كيلومترات من بيروت، وتعتبر من أهم المعالم السياحية في المنطقة
# Label (H/N): h
#
# Cluster 3:
#
# [1] تقع مغارة جعيتا في لبنان
# Label (H/N): h
#
# [2] تقع مغارة جعيتا في لبنان
# Label (H/N): n
#
# [3] تقع مغارة جعيتا في لبنان
# Label (H/N): n
#
# [4] تقع مغارة جعيتا في لبنان
# Label (H/N): n
#
# Cluster 4:
#
# [1] تمتاز مغارة جعيتا بوجود
# Label (H/N): h
#
# Cluster 5:
#
# [1] المادة التي تُستخدم في بن
# Label (H/N): h
#
# Question Label: Hallucinated (based on 3/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -4748207787214884752
# Question: كم عدد الأبراج المستخدمة في علم التنجيم؟
# Original Answer: اثني عشر
#
# Cluster 0:
#
# [1] مصر القديمة
# Label (H/N): h
#
# Cluster 1:
#
# [1] 12 برج
# Label (H/N): n
#
# [2] 12 برج
# Label (H/N): n
#
# [3] 12 برج
# Label (H/N): n
#
# [4] 12 برج
# Label (H/N): n
#
# Cluster 2:
#
# [1] هناك 12 برج في علم التنجيم
# Label (H/N): n
#
# Cluster 3:
#
# [1] الكولين
# Label (H/N): h
#
# Cluster 4:
#
# [1] برج الأسد
# Label (H/N): h
#
# Cluster 5:
#
# [1] برج القوس
# Label (H/N): h
#
# Cluster 6:
#
# [1] العذراء، الحوت، الميزان، الدلو، العقرب، القوس، السرطان، الأسد، الماء
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -6856719717136926903
# Question: هل القرآن من حافظ علي اللغة العربية ليومنا هذا ؟
# Original Answer: نعم
#
# Cluster 0:
#
# [1] أهمية حفظ القرآن الكريم للغة العربية تكمن في الحفاظ علي
# Label (H/N): h
#
# Cluster 1:
#
# [1] نعم، القرآن من حافظ اللغة العربية، فإنه يحافظ على قواعدها واصطلاحاته ورواياتها
# Label (H/N): n
#
# Cluster 2:
#
# [1] لأن القرآن الكريم هو الكتاب المقدس للمسلمين و هو الكتاب الذي كتب باللغة العربية
# Label (H/N): h
#
# Cluster 3:
#
# [1] نعم القرآن حافظ علي اللغة العربية
# Label (H/N): n
#
# [2] نعم، القرآن حافظ علي اللغة العربية
# Label (H/N): n
#
# Cluster 4:
#
# [1] يعزز القرآن اللغة العربية من خلال استخدام كلمات جديدة ومفردات غ
# Label (H/N): h
#
# [2] القرآن هو مصدر للعديد من المفردات التي استعملها العرب في اللغة
# Label (H/N): h
#
# Cluster 5:
#
# [1] نعم
# Label (H/N): n
#
# Cluster 6:
#
# [1] نعم، القرآن حافظ علي اللغة العربية، فالعرب قبل الإسلام كانوا يلعبون ببعض الكلمات التي لا أحد يعرف معناها، ولكن بعد نزول القرآن أصبحوا يعرفون معنى كل كلمة
# Label (H/N): n
#
# Cluster 7:
#
# [1] نعم القرآن من حافظ علي اللغة العربية ليومنا هذا
# Label (H/N): n
#
# Question Label: Non-Hallucinated (based on 6/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 2369816385049075481
# Question: متى تم اكتشاف الاشعه تحت الحمراء ؟
# Original Answer: عام 1800
#
# Cluster 0:
#
# [1] تم اكتشاف أشعة تحت الحمراء في عام 1800 من قبل وليام هييرشل
# Label (H/N): n
#
# [2] اكتشف الفيزيائي البريطاني ويليام هيرشل الاشعة تحت الحمراء في عام 1800
# Label (H/N): n
#
# [3] اكتشف الاشعة تحت الحمراء في عام 1800م من قبل وليام هيرشل
# Label (H/N): n
#
# [4] اكتشف الاشعة تحت الحمراء في عام 1800م من قبل وليم هيرشل
# Label (H/N): n
#
# [5] اكتشف العالم البريطاني ويليام هيرشل الاشعة تحت الحمراء في عام 1800م
# Label (H/N): n
#
# Cluster 1:
#
# [1] الطيف
# Label (H/N): h
#
# Cluster 2:
#
# [1] اكتشف الاشعة تحت الحمراء في عام 1800م
# Label (H/N): n
#
# [2] تم اكتشاف الاشعة تحت الحمراء في عام 1800م
# Label (H/N): n
#
# Cluster 3:
#
# [1] التطبيقات العملية للاشعة تحت الحمراء تشمل استخدامها في الطب، والفضاء، وال
# Label (H/N): h
#
# Cluster 4:
#
# [1] اكتشفها ويليام هيرشل في عام 1801
# Label (H/N): h
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -280996105240611381
# Question: ما هو الكيتين؟
# Original Answer: مادة أحيائية من عديد السكاريد وهي تعتبر المركب الأساسي لجوانب خلية الفطريات وهي الهيكل الصلب الذي يغطي أجسام الحشرات والعديد من مفصليات الأرجل وبعض الحيوانات
#
# Cluster 0:
#
# [1] Keratin is a protein found in bacteria, fungi, and
# Label (H/N): h
#
# [2] الكيتين هو مركب كيميائي يحتوي على الكربون، والهيدروجين، والنتروجين، والفوسفور، والكبريت، والكالكوجين هو مركب كيميائي يحتوي على الكربون، والهيدروجين، والنتروجين، والفوسفور، والكبريت، والكالكوجين هو مركب كيميائي يحتوي على الكربون، والهيدروجين، والنتروجين، والفوسفور، والكبر
# Label (H/N): h
#
# Cluster 1:
#
# [1] الكيتين هو بروتين موجود في جدران الخلايا النباتية والحيوانية والبكتيرية
# Label (H/N): h
#
# Cluster 2:
#
# [1] هو بروتين يوجد في الخلايا النباتية وهو من أهم المواد المكونة للغذاء
# Label (H/N): n
#
# Cluster 3:
#
# [1] الكيتين هو بروتين ينتجه الجسم من الألياف البروتينية في الطعام
# Label (H/N): h
#
# Cluster 4:
#
# [1] الكيتين هو بروتين يعتبر من البروتينات الدهنية، وهو يلعب دورًا مهمًا في تقليل فقدان الألياف العضلية، ويعتبر من البروتينات التي تظهر في الجسم عند فقدان الأنسجة العضلية، ويتم إنتاج الكيتين في الجسم بشكل طبيعي عند التأثيرات التالية: فقدان الأنسجة العضلية، أو الإصابة بالسمنة، أو تدهور الأنسجة العضلية، أو الإصابة بمرض
# Label (H/N): h
#
# Cluster 5:
#
# [1] هو بروتين يلعب دورًا هامًا في بناء الجلد والشعر والحواجب
# Label (H/N): h
#
# Cluster 6:
#
# [1] الكيتين هو بروتين يصنع من قبل بعض أنواع الفطريات، ويستخدم كعامل تآزري في العديد من الأمراض الفطرية، مثل مرض الجلد الفطري
# Label (H/N): h
#
# Cluster 7:
#
# [1] هو بروتين يوجد في الجلد
# Label (H/N): h
#
# Cluster 8:
#
# [1] هو بروتين يوجد في الجلد ويحمي الجلد من الحروق
# Label (H/N): h
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -544511226609573868
# Question: من أول من قام بتشخيص مرض الكساح لدى الأطفال ؟
# Original Answer: دانيال ويسلر
#
# Cluster 0:
#
# [1] العالم الفرنسي "جاكوب نيكولاس بيرنارد" هو أول من قام بتشخيص مرض الكساح لدى الأطفال
# Label (H/N): h
#
# Cluster 1:
#
# [1] ويليام أوسلر
# Label (H/N): h
#
# Cluster 2:
#
# [1] تشخيص مرض الكساح لدى الأطفال أول مرة تم تشخيصه لها من قبل الطبيب الألماني ألكسندر أومان (Alexander Ombredanne) عام 1898
# Label (H/N): h
#
# Cluster 3:
#
# [1] تشخيص مرض الكساح لدى الأطفال هو من عمل الطبيب الإنجليزي "إدوين كينيون" عام 1889
# Label (H/N): h
#
# Cluster 4:
#
# [1] تشخيص مرض الكساح لدى الأطفال يعود إلى الطبيب الفرنسي بيركيه (Pierre Marie Béclard) الذي عاش في القرن التاسع عشر
# Label (H/N): h
#
# Cluster 5:
#
# [1] تشخيص مرض الكساح لدى الأطفال تم تحديده لأول مرة من قبل الطبيب الإيطالي سيلفستر جيلاردو عام 1822
# Label (H/N): h
#
# Cluster 6:
#
# [1] أدولف
# Label (H/N): h
#
# Cluster 7:
#
# [1] الدكتور ويليس كراندال روبنز
# Label (H/N): h
#
# Cluster 8:
#
# [1] العالم البريطاني إدوين كلارك
# Label (H/N): h
#
# Cluster 9:
#
# [1] جيمس هاتون
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 1622311182815275593
# Question: هل بنى  النبيّ سليمان القدس؟
# Original Answer: يعطيه الكتاب المقدس العبري افضل في بناء الهيكل الأول في القدس
#
# Cluster 0:
#
# [1] لا
# Label (H/N): h
#
# Cluster 1:
#
# [1] لا بنى النبيّ سليمان القدس
# Label (H/N): h
#
# [2] لا بنى النبيّ سليمان القدس
# Label (H/N): h
#
# Cluster 2:
#
# [1] بناه النبي داود
# Label (H/N): h
#
# Cluster 3:
#
# [1] الولاية
# Label (H/N): h
#
# Cluster 4:
#
# [1] نعم، بنى النبيّ سليمان القدس
# Label (H/N): n
#
# [2] نعم بنى النبيّ سليمان القدس
# Label (H/N): n
#
# Cluster 5:
#
# [1] إسحق
# Label (H/N): h
#
# Cluster 6:
#
# [1] بنى الن
# Label (H/N): h
#
# Cluster 7:
#
# [1] إن بناء القدس يعود إلى عهد سليمان بن داود، حيث بنى سليمان بن داود مدينة القدس، التي كانت تسمى آنذاك أورشليم، على هضبة الزيتون
# Label (H/N): h
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -8182333893768380864
# Question: متى نشبت معركة مرعش؟
# Original Answer: 7 تموز عام 1742
#
# Cluster 0:
#
# [1] كان الس
# Label (H/N): h
#
# Cluster 1:
#
# [1] في 19 ديسمبر 1914
# Label (H/N): h
#
# Cluster 2:
#
# [1] نيكفوروس باسيلاجيوس
# Label (H/N): h
#
# Cluster 3:
#
# [1] نشبت معركة مرعش في عام 1071م
# Label (H/N): h
#
# Cluster 4:
#
# [1] الزعيم الذي قاد الجيش البيزنطي في معركة مرعش هو روبرت جيسكاس
# Label (H/N): h
#
# Cluster 5:
#
# [1] نشبت معركة مرعش في عام 1517
# Label (H/N): h
#
# Cluster 6:
#
# [1] كان ياسين باي من بين قادة الجيش المماليك في معركة مرعش
# Label (H/N): h
#
# Cluster 7:
#
# [1] متسابق رياضي مصري
# Label (H/N): h
#
# Cluster 8:
#
# [1] نشبت معركة مرعش في 24 ديسمبر
# Label (H/N): h
#
# Cluster 9:
#
# [1] في 25 يناير 151
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -5846760312909928950
# Question: هل يطبق حكم الإعدام في السعودية ؟
# Original Answer: نعم
#
# Cluster 0:
#
# [1] نعم
# Label (H/N): n
#
# [2] نعم
# Label (H/N): n
#
# Cluster 1:
#
# [1] يتم تنفيذ
# Label (H/N): n
#
# [2] نعم، يطبق في بعض الأحيان
# Label (H/N): n
#
# Cluster 2:
#
# [1] يطبق حكم الإعدام في السعودية في القضايا المتعلقة بالجريمة المخلة بالعرض العام، والجريمة ضد الأمن القومي، والجريمة ضد الأمن العام، والجريمة ضد الأفراد، والجريمة ضد الممتلكات، والجريمة ضد النفس،
# Label (H/N): n
#
# Cluster 3:
#
# [1] نعم، يطبق حكم الإعدام في السعودية
# Label (H/N): n
#
# [2] نعم، يطبق حكم الإعدام في السعودية
# Label (H/N): n
#
# [3] نعم، ويعتبر الإعدام عقوبة ممكنة في السعودية
# Label (H/N): n
#
# Cluster 4:
#
# [1] تطبق حكم الإعدام في السعودية في حالات الجرائم المحددة في القانون الجنائي السعودي، مثل القتل العمد، والخيانة العظمى، والزنا، والسرقة، والتعدي على الأمن العام
# Label (H/N): n
#
# Cluster 5:
#
# [1] القسم الخاص بالسجن
# Label (H/N): h
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -1568187473623300963
# Question: ما هي أكبر بحيرة في كندا؟
# Original Answer: بحيرة سوبيريور
#
# Cluster 0:
#
# [1] بحيرة هود
# Label (H/N): h
#
# Cluster 1:
#
# [1] بحيرة супيريور
# Label (H/N): ا
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): h
#
# [2] بحيرة супيريور
# Label (H/N): h
#
# [3] بحيرة супيريور
# Label (H/N): h
#
# [4] بحيرة
# Label (H/N): h
#
# [5] بحيرة سپيريور
# Label (H/N): n
#
# [6] بحيرة супيريور
# Label (H/N): h
#
# Cluster 2:
#
# [1] البحيرة العظمى
# Label (H/N): h
#
# Cluster 3:
#
# [1] بحيرة سوبريور هي أكبر بحيرة في كندا، وتقع في الجزء الشمالي الغربي من الولايات المتحدة
# Label (H/N): n
#
# Cluster 4:
#
# [1] بحيرة سوبريور
# Label (H/N): n
#
# Question Label: Hallucinated (based on 3/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -3572514512686862564
# Question: متى استقلت تونس ؟
# Original Answer: مارس 1956
#
# Cluster 0:
#
# [1] استقلت تونس في 20 مارس 1956
# Label (H/N): n
#
# [2] استقلت تونس في 20 مارس 1956
# Label (H/N): n
#
# [3] استقلت تونس في 20 مارس 1956
# Label (H/N): n
#
# [4] استقلت تونس في 20 مارس 1956
# Label (H/N): n
#
# [5] استقلت تونس في 20 مارس 1956
# Label (H/N): n
#
# [6] استقلت تونس في 20 مارس 1956
# Label (H/N): n
#
# Cluster 1:
#
# [1] استقلت المغرب في 2 مارس 1956
# Label (H/N): n
#
# Cluster 2:
#
# [1] استقلت الجزائر في 5 يوليو 1962
# Label (H/N): h
#
# Cluster 3:
#
# [1] الع
# Label (H/N): h
#
# Cluster 4:
#
# [1] 20 مارس 1956
# Label (H/N): n
#
# Question Label: Non-Hallucinated (based on 8/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -4175003893535735557
# Question: من هو مؤلف كتاب " الحِكَم العطائية " ؟
# Original Answer: ابن عطاء الله السكندري
#
# Cluster 0:
#
# [1] مؤلف كتاب " الحِكَم العطائية " هو أبو عثمان عَمرو بن بِشر بن عُثمان العَطّار
# Label (H/N): h
#
# Cluster 1:
#
# [1] هو " عطاء الله السكندري "
# Label (H/N): n
#
# Cluster 2:
#
# [1] الحكيم العطائية
# Label (H/N): h
#
# [2] أبو إسحاق إبراهيم بن محمد بن إسحاق بن إبراهيم بن سليمان بن عطاء بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن سليمان بن
# Label (H/N): h
#
# Cluster 3:
#
# [1] الحكيم العطاء بن عثمان الساكت
# Label (H/N): h
#
# Cluster 4:
#
# [1] الحِكَم العطائية هو كتاب ألفه أبو إسحاق إبراهيم بن يوسف بن الحسين بن عطاء بن سفيان الأزدي، المعروف بالعطاء بن سفيان
# Label (H/N): h
#
# Cluster 5:
#
# [1] الحَكيم العطار
# Label (H/N): h
#
# Cluster 6:
#
# [1] أبو حامد الغزالي
# Label (H/N): h
#
# Cluster 7:
#
# [1] عطاء الله السجستاني
# Label (H/N): h
#
# Cluster 8:
#
# [1] Imam Al-Hakim Al-Ata'i
# Label (H/N): h
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -6876078920544160795
# Question: في أي عام قام الفنان العالمي ياني بإنتاج أول حفلة موسيقية؟
# Original Answer: عقد 1980
#
# Cluster 0:
#
# [1] 1957
# Label (H/N): h
#
# Cluster 1:
#
# [1] 1972
# Label (H/N): h
#
# Cluster 2:
#
# [1] 1971
# Label (H/N): h
#
# Cluster 3:
#
# [1] في عام 1983، قام الفنان العالمي ياني بإنتاج أول حفلة موسيقية له
# Label (H/N): h
#
# [2] في عام 1983 قام الفنان العالمي ياني بإنتاج أول حفلة موسيقية
# Label (H/N): h
#
# Cluster 4:
#
# [1] ياني ( Yanis Marin) ، ياني ( Yanis Marin) ، ياني ( Yanis Marin
# Label (H/N): h
#
# [2] اليون
# Label (H/N): h
#
# Cluster 5:
#
# [1] لان ياني كان محبًا للجاز
# Label (H/N): h
#
# Cluster 6:
#
# [1] اليونانية
# Label (H/N): h
#
# Cluster 7:
#
# [1] ياني (Yanni) هو موسيقي يوناني، ملحن، ومؤلف موسيقي
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -5579891390712572327
# Question: من هو آخر خلفاء بني أمية في دمشق؟
# Original Answer: هشام المعتد بالله
#
# Cluster 0:
#
# [1] يزيد بن عبد الملك بن مروان
# Label (H/N): h
#
# Cluster 1:
#
# [1] يزيد بن عبد الملك بن مروان بن الحكم بن أبي سفيان بن حرب بن أمية بن عبد شمس بن عبد مناف بن قصي بن كلاب بن مرة بن كعب بن لؤي بن غالب بن فهر بن مالك بن النضر بن كنانة بن خزيمة بن مدركة بن إلياس بن مضر بن نزار بن معد بن عدنان
# Label (H/N): h
#
# Cluster 2:
#
# [1] يزيد بن الوليد
# Label (H/N): h
#
# Cluster 3:
#
# [1] الوليد بن
# Label (H/N): h
#
# [2] الوليد بن
# Label (H/N): h
#
# Cluster 4:
#
# [1] هو يوسف بن عمر
# Label (H/N): h
#
# Cluster 5:
#
# [1] هارون الرشيد
# Label (H/N): h
#
# Cluster 6:
#
# [1] هو الوليد بن يزيد الثاني
# Label (H/N): h
#
# [2] هو الوليد بن يزيد الثاني
# Label (H/N): h
#
# Cluster 7:
#
# [1] هو يزيد بن عمر
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -1751757012240638549
# Question: أين عاش جورج فريدريك هانْدل المؤلف الموسيقي الكلاسيكي الإنكليزي؟
# Original Answer: لندن
#
# Cluster 0:
#
# [1] مؤلف موسيقي
# Label (H/N): h
#
# Cluster 1:
#
# [1] هانْدل هو مؤلف موسيقي كلاسيكي من أصل ألماني عاش في إنجلترا
# Label (H/N): h
#
# Cluster 2:
#
# [1] لندن
# Label (H/N): n
#
# [2] لندن
# Label (H/N): n
#
# [3] لندن
# Label (H/N): n
#
# Cluster 3:
#
# [1] برلين
# Label (H/N): h
#
# Cluster 4:
#
# [1] يعتبر من أشهر مؤلفي الموسيقى الكلاسيكية الإنكليزية، وأحد أشهر مؤلفي الموسيقى الكلاسيكية في القرن الثامن عشر
# Label (H/N): h
#
# Cluster 5:
#
# [1] قصر شاو
# Label (H/N): h
#
# Cluster 6:
#
# [1] لندن، المملكة المتحدة
# Label (H/N): n
#
# Cluster 7:
#
# [1] شوبان
# Label (H/N): h
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 813394471006118937
# Question: ما هي الياكوزا ؟
# Original Answer: مصطلح عام يطلق على المنظمات الإجرامية في اليابان
#
# Cluster 0:
#
# [1] الياكوزا هو مرض يصيب الكبد
# Label (H/N): h
#
# [2] هي حالة تصلب في الكبد
# Label (H/N): h
#
# [3] هو نوع من الالتهابات المزمنة في الكبد
# Label (H/N): h
#
# Cluster 1:
#
# [1] هي مرض يصيب الكبد
# Label (H/N): h
#
# Cluster 2:
#
# [1] الياكوزا هي حالة التهاب في الكبد الناجم عن العدوى الفيروسية
# Label (H/N): h
#
# Cluster 3:
#
# [1] هو إصابة بليغة للخلايا العصبية في الدماغ
# Label (H/N): h
#
# Cluster 4:
#
# [1] الياكوزا هو مرض مزمن يصيب الجلد، و يظهر على الجلد في شكل حباء أو سحجات، و ينتشر في الجلد و يمكن أن يصيب العينين و الأذنين و الجيوب القحفية و الكبد و الكلى و القلب و الرئتين و الأوعية الدموية و العظام و النخاع الشوكي و العصبين البطنيين و الأعصاب و الجيوب القحفية و الأنسجة الر
# Label (H/N): h
#
# Cluster 5:
#
# [1] الياكوزا هو مرض نادر يحدث في الجلد بسبب العدوى الفيروسية
# Label (H/N): h
#
# Cluster 6:
#
# [1] الياكوزا هو مرض تصلبية يصيب الكبد
# Label (H/N): h
#
# Cluster 7:
#
# [1] الياكوزا هي حالة صحية تؤدي إلى تجمع ليفي من الخلايا الالتهابية في الجسم
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 7737045113937545097
# Question: في أي عام تأسست منظمة التحرير الفلسطينية ؟
# Original Answer: 1964
#
# Cluster 0:
#
# [1] 1964
# Label (H/N): n
#
# [2] 1964
# Label (H/N): n
#
# [3] 1964
# Label (H/N): n
#
# Cluster 1:
#
# [1] العربية
# Label (H/N): h
#
# Cluster 2:
#
# [1] المقر الرئيسي لمنظمة التحرير الفلسطينية يقع في مدينة غزة
# Label (H/N): h
#
# Cluster 3:
#
# [1] تأسست
# Label (H/N): h
#
# Cluster 4:
#
# [1] منظمة التحرير الفلسطينية هي منظمة سياسية فلسطينية تأسست عام 1964
# Label (H/N): n
#
# Cluster 5:
#
# [1] سليم الزعنون
# Label (H/N): h
#
# Cluster 6:
#
# [1] محمود عباس
# Label (H/N): h
#
# Cluster 7:
#
# [1] تنص المادة 19 على أن جميع الشعوب تقدر الحق في تقرير المصير وبالتالي فإن الشعب الفلسطيني له الحق في تق
# Label (H/N): h
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 8595073093515483803
# Question: ما هي تميمة كأس العالم لكرة القدم 2018؟
# Original Answer: زابيفاكا
#
# Cluster 0:
#
# [1] تميمة كأس العالم لكرة القدم 2018 هي زابيتا، وهي زبابة روسية
# Label (H/N): ا
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): h
#
# [2] تميمة كأس العالم 2018 هي زابيتا، وهو زبابة روسية
# Label (H/N): h
#
# Cluster 1:
#
# [1] تميمة كأس العالم لكرة القدم 2018 هي زابيفا
# Label (H/N): n
#
# [2] تميمة كأس العالم لكرة القدم 2018 هي زابيفا
# Label (H/N): n
#
# Cluster 2:
#
# [1] تميمة كأس العالم لكرة القدم 2018 هي زابيفا، وهي خروفة روسية، تم اختيارها من قبل اللجنة المنظمة لكأس العالم 2018
# Label (H/N): n
#
# Cluster 3:
#
# [1] تميمة كأس العالم لكرة القدم 2018 هي زابيتا، وهي قطة روسية
# Label (H/N): n
#
# Cluster 4:
#
# [1] تميمة كأس العالم لكرة القدم 2018 هي زابيتا
# Label (H/N): n
#
# [2] تميمة كأس العالم لكرة القدم 2018 هي زابيتا
# Label (H/N): n
#
# Cluster 5:
#
# [1] تميمة كأس العالم لكرة القدم 2018 هي زابيتا، وهي فهد من نوع القطط البرية، تم إطلاق اسمها في 28 أكتوبر 2017
# Label (H/N): n
#
# Cluster 6:
#
# [1] تميمة كأس العالم لكرة القدم 2018 هي زابيتا، وهي كلب روسي من نوع لابريتا
# Label (H/N): n
#
# Question Label: Non-Hallucinated (based on 8/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -7471664031658550253
# Question: ما هو النَيزَك؟
# Original Answer: جسيم يوجد في النظام الشمسي ويتكون من حطام الصخور وقد يكون في حجم حبيبات الرمل الصغيرة أو في حجم صخرة كبيرة
#
# Cluster 0:
#
# [1] هو نبات يُستَخْدَم في الأطباق الخضراء
# Label (H/N): h
#
# Cluster 1:
#
# [1] النيزك هو هطول من قطرات الماء الصغيرة تتراكم في الهواء، وتتجمع في هيئة قطرات صغيرة تتراكم في الهواء، وتتجمع في هيئة قطرات صغيرة تتراكم في الهواء، وتتجمع في هيئة قطرات صغيرة تتراكم في الهواء، وتتجمع في هيئة قطرات صغيرة تتراكم في الهواء، وتتجمع في هيئة قطرات صغيرة تتراكم في الهواء، وتتجمع في هيئة قطرات صغيرة تتر
# Label (H/N): h
#
# [2] هو الطَيرُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ المُتَوَقِّعُ الم
# Label (H/N): h
#
# [3] النَيزَك هو الطَرف الأَوسط من الرأس
# Label (H/N): h
#
# [4] النَيزَك هو أحد أسماء الله الحسنى
# Label (H/N): h
#
# Cluster 2:
#
# [1] النَيزَك هو نبات يُعتبر من أهم النباتات الطبية في البلدان العربية
# Label (H/N): h
#
# Cluster 3:
#
# [1] النَيزَك هو نبات معمر يُستخدم في الأدوية
# Label (H/N): h
#
# Cluster 4:
#
# [1] هو الحشرات التي تُغذيها الحشرات الأخرى وتنمو داخلها
# Label (H/N): h
#
# Cluster 5:
#
# [1] النَيزَك هو نبات يُعد من النباتات العطرية والرائحة، ويُستخدم في صنع العطور والبخور
# Label (H/N): h
#
# Cluster 6:
#
# [1] النَيزَك هو جنس من النباتات الزهرية تتبع فصيلة النجمية، يضم أكثر من 400 نوعًا، ويتواجد في جميع أنحاء العالم، ويعتبر من النباتات المزهرة، ويعتبر من أهم أنواع النباتات المزهرة التي تنتج الزهور في مختلف الألوان
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -2782021396727815704
# Question: متى تأسس الحزب الشيوعي الصيني؟
# Original Answer: 1921
#
# Cluster 0:
#
# [1] تأسس الحزب الشيوعي الصيني في 1 يوليو 1921
# Label (H/N): n
#
# [2] تأسس الحزب الشيوعي الصيني في 1 تموز/يوليو 1921م
# Label (H/N): n
#
# Cluster 1:
#
# [1] تأسس الحزب الشيوعي الصيني في عام 1921
# Label (H/N): n
#
# [2] تأسس الحزب الشيوعي الصيني في عام 1921
# Label (H/N): n
#
# [3] تأسس الحزب الشيوعي الصيني في عام 1921
# Label (H/N): n
#
# [4] تأسس الحزب الشيوعي الصيني في عام 1921
# Label (H/N): n
#
# [5] تأسس الحزب الشيوعي الصيني في عام 1921
# Label (H/N): n
#
# [6] تأسس الحزب الشيوعي الصيني في عام 1921
# Label (H/N): n
#
# Cluster 2:
#
# [1] 1921
# Label (H/N): n
#
# Cluster 3:
#
# [1] المبادئ الأساسية للحزب الشيوعي الصيني هي الماركسية اللينينية والشيوعية والاشتراكية والعلمانية
# Label (H/N): h
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 2619371864438605103
# Question: هل تسبب اشعة الـيو في مرض سرطان الجلد؟
# Original Answer: نعم
#
# Cluster 0:
#
# [1] نعم
# Label (H/N): n
#
# [2] نعم
# Label (H/N): n
#
# [3]
# Label (H/N): h
#
# Cluster 1:
#
# [1] تكون الأعراض في بداية الأمر غير واضحة، وتشمل: الآفات الجلدية غير الطبيعية، والآفات الصلبة، والآفات الخدج، والآفات التي تسبب إحمرار الجلد، والآفات التي تسبب تغير لون الجلد
# Label (H/N): h
#
# Cluster 2:
#
# [1] يمكن أن تسبب اشعة الـيو مرض سرطان الجل
# Label (H/N): n
#
# Cluster 3:
#
# [1] يتم تشخيص مرض السرطان
# Label (H/N): h
#
# Cluster 4:
#
# [1] أعراض سرطان الجلد تتضمن:
# Label (H/N): h
#
# Cluster 5:
#
# [1] الأورام أو الخباثات الموجودة على الجلد، والتغيرات في لون الجلد أو الشعر، والاحمرار أو البقع السوداء على الجلد، وعدم انتظام نمو الشعر
# Label (H/N): h
#
# Cluster 6:
#
# [1] يعتمد العلاج على مرحلة المرض ويمكن أن يشمل الجراحة أو العلاج الإشعاعي أو العلاج الكيميائي أو العلاج الإقليمي
# Label (H/N): h
#
# Cluster 7:
#
# [1] الاشعة فوق البنفسجية
# Label (H/N): h
#
# Question Label: Hallucinated (based on 3/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -2856996124258223997
# Question: كم  عدد أسفار موسى؟
# Original Answer: خمسة
#
# Cluster 0:
#
# [1]
# Label (H/N): h
#
# [2]
# Label (H/N): h
#
# Cluster 1:
#
# [1] 1 سفر
# Label (H/N): h
#
# Cluster 2:
#
# [1] سبع أسفار
# Label (H/N): h
#
# Cluster 3:
#
# [1] 27
# Label (H/N): h
#
# Cluster 4:
#
# [1] 40 سفرا
# Label (H/N): h
#
# Cluster 5:
#
# [1] 24 سفراً
# Label (H/N): h
#
# Cluster 6:
#
# [1] 1 سفر (سفر صلاه)
# Label (H/N): h
#
# Cluster 7:
#
# [1] 32 سفراً
# Label (H/N): h
#
# Cluster 8:
#
# [1] 40 سفراً
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 351298879969738607
# Question: هل حيازة الأسلحة قانوني في ولاية أوكلاهوما الأمريكية ؟
# Original Answer: نعم
#
# Cluster 0:
#
# [1] نعم، في ولاية أوكلاهوما الأمريكية قانونية حيازة الأسلحة، حيث يعتبر قانون الولاية "قانون حق حمل الأسلحة النارية" (Firearms Act) عام 1911 هو القانون الرئيسي الذي يُحدد حقوق حمل الأسلحة في الولاية
# Label (H/N): n
#
# Cluster 1:
#
# [1] تُعتبر ولاية أوكلاهوما واحدة من الولايات التي تتيح حماية حقوق
# Label (H/N): h
#
# Cluster 2:
#
# [1] Oui, la possession d'arm
# Label (H/N): n
#
# Cluster 3:
#
# [1] نعم، وهي قانونية بموجب قانون ولاية أوكلاهوما
# Label (H/N): n
#
# Cluster 4:
#
# [1] تتمتع ولاية أو
# Label (H/N): h
#
# Cluster 5:
#
# [1] نعم، حيازة الأسلحة قانونية في ولاية أوكلاهوما الأمريكية
# Label (H/N): n
#
# [2] نعم، حيازة الأسلحة قانوني في ولاية أوكلاهوما الأمريكية
# Label (H/N): n
#
# [3] نعم،حيازة الأسلحة قانوني في ولاية أوكلاهوما الأمريكية
# Label (H/N): n
#
# Cluster 6:
#
# [1] نعم، في ولاية أوكلاهوما الأمريكية، يحق لمن يصل إلى سن 21 عامًا شراء الأسلحة النارية والذخائر، ولكن يجب أن يكون قد اجتاز فحصًا للتحقق من عدم وجود أي مشاكل صحية أو جنائية
# Label (H/N): n
#
# ...
# Label (H/N): h
#
# [2] الوُهام هي إحساس خاطئ بالرؤية، بينما الهلوسة هي إحساس خاطئ بالسمع
# Label (H/N): h
#
# Cluster 4:
#
# [1] الوَهام هي ظاهرة تتسم بها إدراك الشخص لوجود أشياء أو أحداث غير موجودة أو غير حقيقية، في حين أن الحُلوسة هي ظ
# Label (H/N): h
#
# Cluster 5:
#
# [1] الوُهام هي الخواطر التي تمنحها الوحي، بينما الهلوسة هي الخواطر التي تمنحها الشيطان
# Label (H/N): h
#
# Cluster 6:
#
# [1] الوُهام هي فكرة أو تصور غير واقعي
# Label (H/N): h
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 8356218940339708460
# Question: من هو مؤلف كتاب يوتوبيا ؟
# Original Answer: وسياسية كت
#
# Cluster 0:
#
# [1] توم مور
# Label (H/N): h
#
# [2] توم مور
# Label (H/N): h
#
# [3] توم مور
# Label (H/N): h
#
# [4] توم مور
# Label (H/N): h
#
# [5] توم مور
# Label (H/N): h
#
# [6] توم مور
# Label (H/N): h
#
# Cluster 1:
#
# [1] تشارلز ديكنز
# Label (H/N): h
#
# Cluster 2:
#
# [1] غابرييل جارسيا
# Label (H/N): h
#
# Cluster 3:
#
# [1] توماس مور
# Label (H/N): h
#
# Cluster 4:
#
# [1] يوتوبيا
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 5161593989323403223
# Question: متى توفي إدوارد الثالث؟
# Original Answer: عام 1377
#
# Cluster 0:
#
# [1] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# [2] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# [3] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# [4] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# [5] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# [6] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# [7] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# [8] توفي إدوارد الثالث في 21 يونيو 1377
# Label (H/N): n
#
# Cluster 1:
#
# [1] 140
# Label (H/N): h
#
# Cluster 2:
#
# [1] إدوارد الثالث ملك إنجلترا، كان ملك إنجلترا من 1327 حتى وفاته في 1377
# Label (H/N): n
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -509964456301759951
# Question: ماهو عدد الضحايا المدنيين اليابانيين خلال أحداث الحرب العالمية الثانية ؟
# Original Answer: بين 129000 و 226000
#
# Cluster 0:
#
# [1] يُقدر عدد الضحايا المد
# Label (H/N): h
#
# Cluster 1:
#
# [1] أكثر من 3
# Label (H/N): n
#
# Cluster 2:
#
# [1] 300 ألف
# Label (H/N): h
#
# [2] 3000000
# Label (H/N): h
#
# Cluster 3:
#
# [1] الغزو الألماني لتشيكوسلوفاكيا في عام 1939، والغزو الألماني ل بولندا في عام 1939، والغزو الياباني لمنشوريا في عام 1931، ووحدة ألمانيا في عام 1933، ووحدة إيطاليا في عام 1922، ووحدة اليابان
# Label (H/N): h
#
# Cluster 4:
#
# [1] يُقدر عدد الضحايا المدنيين اليابانيين خلال أحداث الحرب العالمية الثانية بحوالي 3
# Label (H/N): h
#
# [2] يُقدر عدد الضحايا المدنيين اليابانيين خلال الحرب العالمية الثانية ب 3
# Label (H/N): h
#
# [3] يُقدر عدد الضحايا المدنيين اليابانيين خلال أحداث الحرب العالمية الثانية بحوالي 3
# Label (H/N): h
#
# [4] يُقدر عدد الضحايا المدنيين اليابانيين خلال أحداث الحرب العالمية الثانية بحوالي 3
# Label (H/N): h
#
# Cluster 5:
#
# [1] 3100000
# Label (H/N): h
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -7956541290734369116
# Question: متى تم الإطاحة بالملكية الروسية ؟
# Original Answer: 1917
#
# Cluster 0:
#
# [1] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [2] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [3] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [4] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [5] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [6] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [7] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [8] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# [9] تم الإطاحة بالملكية الروسية في عام 1917
# Label (H/N): n
#
# Cluster 1:
#
# [1] أورسولا فون دير لاين
# Label (H/N): h
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -1735436817117004580
# Question: متى تم إبتكار السيجارة الإلكترونية ؟
# Original Answer: عام 1963
#
# Cluster 0:
#
# [1] Imperial Brands
# Label (H/N): h
#
# Cluster 1:
#
# [1] تتكون السيجارة
# Label (H/N): h
#
# Cluster 2:
#
# [1] هونغ كونغ
# Label (H/N): h
#
# Cluster 3:
#
# [1] تم ابتكار السيجارة الإلكترونية في عام 2003
# Label (H/N): h
#
# Cluster 4:
#
# [1] إعطاء رائحة للشخص
# Label (H/N): h
#
# Cluster 5:
#
# [1] هو هونغ كينج
# Label (H/N): h
#
# Cluster 6:
#
# [1] 2003
# Label (H/N): h
#
# [2] 2003
# Label (H/N): h
#
# Cluster 7:
#
# [1] تم ابتكار السيجارة الإلكت
# Label (H/N): h
#
# Cluster 8:
#
# [1] تتكون السيجارة الإلكترونية من: بطارية، ومحول، ومصدر للبرق، ومحول، ومحول، ومصدر
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -5284199809954703149
# Question: أين ولدة فيفيان ماري هارتلي ؟
# Original Answer: الهند البريطانية
#
# Cluster 0:
#
# [1] فيفيان ماري هارتلي من أستراليا
# Label (H/N): h
#
# Cluster 1:
#
# [1] 1973
# Label (H/N): h
#
# Cluster 2:
#
# [1] فيفيان ماري هارتلي هي امرأة بريطانية اعتُقلت في 2019 بتهمة التجسس لصالح روسيا في المملكة المتحدة
# Label (H/N): h
#
# Cluster 3:
#
# [1] وُلدت فيفيان هارتلي في 26 مارس 1923
# Label (H/N): h
#
# Cluster 4:
#
# [1] نانا أكونو
# Label (H/N): h
#
# Cluster 5:
#
# [1] شغلت فيفيان ماري هارتلي مهنة طبيبة نفسية
# Label (H/N): h
#
# Cluster 6:
#
# [1] 24 ديسمبر 1912
# Label (H/N): h
#
# Cluster 7:
#
# [1] فيفيان ماري هارتلي (1899-1990) كانت عالمة فيزياء بريطانية، وُلدت في لندن
# Label (H/N): h
#
# Cluster 8:
#
# [1] ولدت فيفيان ماري هارتلي في 26 مارس 1907
# Label (H/N): h
#
# Cluster 9:
#
# [1] وُلِ
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -6312809904614780376
# Question: ما هي الأنا العليا كما وصفها فرويد؟
# Original Answer: شخصية المرء في صورتها الأكثر تحفظاً وعقلانية
#
# Cluster 0:
#
# [1] الأ
# Label (H/N): h
#
# [2] هي القدرة على التحكم في مشاعرنا وتصرفاتنا، والتفكير في الأشياء بشكل مستقل عن عواطفنا، ويمكن أن تكون الأنا العليا مركبة من عدة عناصر، مثل: الأنا العليا التي تحكم الأفعال، والأنا العليا التي تحكم العواطف، والأنا العليا التي تحكم التفكير
# Label (H/N): n
#
# [3] الأنا العليا هي النفس الحقيقية، وهي هيئة إدراكية تنطوي على جميع مكونات النفس، وتقوم بتفهم العالم الخارجي والشخص الداخلي، وتساعد في تكوين القيم والهوايات، وتتألف من مشاعر الإيجابية والسلطة والذكاء، وهي الهيئة التي تتمتع بالتفكير والذكاء والشخصية، وهي الهيئة التي تتمتع بالذكاء
# Label (H/N): n
#
# Cluster 1:
#
# [1] وفقًا لفرويد، الأنا العليا هي جزء من النفس يرتبط بالواقع والهوية، وهو يُعتبر هوية الشخص في المجتمع
# Label (H/N): h
#
# Cluster 2:
#
# [1] هي النفس البشرية التي تتمتع بوعي أكبر وتتجاوز الأنا العادية
# Label (H/N): n
#
# Cluster 3:
#
# [1] الأنا العليا هي جزء من النفس البشرية الذي يتحكم
# Label (H/N): h
#
# [2] تعرف فرويد على "الأنا العليا" أو "الأنا الحقيقية" أو "الأنا الحقيقية" (true self) أو "الذات الحقيقية"، وهي مصطلح يستخدمه فرويد لوصف جزء من النفس البشرية الذي يعتبر أكثر استقراراً وثباتاً
# Label (H/N): n
#
# Cluster 4:
#
# [1] هي نواة ذاتية تقع في الجزء الخلفي من الدماغ، تعتبر مركزاً للوعي، وتسمح للشخص بالتفكير في نفسه
# Label (H/N): h
#
# Cluster 5:
#
# [1] تتميز بالاستقلالية والقدرة على التحكم في الأنا الضعيفة، حيث تتمكن من اتخاذ القرارات وتحديد الأولويات دون أي تأثير من الأنا الضعيفة
# Label (H/N): n
#
# Cluster 6:
#
# [1] هي الأنا التي تتوافق مع القيم الأخلاقية والاجتماعية في المجتمع
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 2349306340288882189
# Question: متى عاش  ديكارت؟
# Original Answer: القرن17
#
# Cluster 0:
#
# [1] عاش رينيه ديكارت في الفترة ما بين 31 مارس 1596 و11 نوفمبر 1650
# Label (H/N): n
#
# [2] عاش رينيه ديكارت في الفترة من 31 مارس 1596 إلى 11 نوفمبر 1650
# Label (H/N): n
#
# Cluster 1:
#
# [1] كانت والدته جين بروكارت
# Label (H/N): h
#
# Cluster 2:
#
# [1] 1612م
# Label (H/N): n
#
# Cluster 3:
#
# [1] عاش رينيه ديكارت في القرن السابع عشر
# Label (H/N): n
#
# Cluster 4:
#
# [1] كان رينيه ديكارت فيلسوفًا فرنسيًا، ويعتبر واحدًا من أهم الفلاسفة في العصر الحديث
# Label (H/N): h
#
# Cluster 5:
#
# [1] رينيه ديكارت
# Label (H/N): h
#
# Cluster 6:
#
# [1] كان إيمانويل كانت (1724-1804) من مؤسسي الفلسفة الحديثة، وهو من أشهر الفلاسفة الألمان
# Label (H/N): h
#
# Cluster 7:
#
# [1] رنه ديكارت (31 مارس 1596 – 11 نوفمبر 1650) كان فيلسوفًا فرنسيًا، ويعتبر من أهم الفلاسفة في تاريخ الفلسفة، ويعتبر من مؤسسي الفلسفة الحديثة، ويعتبر من أهم الفلاسفة في القرن السابع عشر
# Label (H/N): n
#
# Cluster 8:
#
# [1] له تأثير كبير
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 3084391360477548770
# Question: ما هو عزم الدوران ؟
# Original Answer: قيمة متجهة  لقياس مدى قدرة قوة على تدوير المجســّـم حول محور ما
#
# Cluster 0:
#
# [1] عزم الدوران هو عزم القوة حول محور دوران
# Label (H/N): n
#
# [2] عزم دوران أو عزم دوران المحرك هو كمية الطاقة المتبعة لتحقيق دوران أو دوران المحرك
# Label (H/N): n
#
# [3] هو عزم القوة المطبقة على الجسم في اتجاه دوران الجسم
# Label (H/N): n
#
# [4] عزم دوران أو عزم دوران حول محور دوران هو حاصل دوران المادة حول محور دوران
# Label (H/N): n
#
# [5] عزم الدوران هو عزم دوران محوري حول محور دوران معين
# Label (H/N): n
#
# Cluster 1:
#
# [1] هو حاصل ضرب القوة المتعامدة على المسار عن بعد المسافة
# Label (H/N): h
#
# Cluster 2:
#
# [1] عزم دوران أو عزم دوران محوري هو حاصل ضرب القوة المحورية (التي تؤثر على جسم في محوره) عن مسافة دوران الجسم، يرمز له ب "L" أو "τ" ووحدته هي نيوتن متر متر (N·m)
# Label (H/N): n
#
# Cluster 3:
#
# [1] عزم الدوران هو كمية الدوران التي يحدثها عزم القوة على جسم ما
# Label (H/N): n
#
# Cluster 4:
#
# [1] هو عزم القوة المطبقة على جسم حول نقطة مرجعية
# Label (H/N): n
#
# Cluster 5:
#
# [1] هو القوة المطبقة على جسم لتحويل دورانها في المدار إلى دوران حول نفسه
# Label (H/N): n
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -5179042881936433712
# Question: أين تقع مدينة الشطرة؟
# Original Answer: محافظة ذي قار
#
# Cluster 0:
#
# [1] تقع مدينة الشطرة في محافظة البصرة جنوب العراق
# Label (H/N): h
#
# [2] تقع مدينة الشطرة في محافظة البصرة في جنوب العراق
# Label (H/N): h
#
# Cluster 1:
#
# [1] تقع مدينة الشطرة في محافظة
# Label (H/N): h
#
# [2] تقع مدينة الشطرة في منطقة الباطنة
# Label (H/N): h
#
# [3] تقع مدينة الشطرة في محافظة الق
# Label (H/N): h
#
# Cluster 2:
#
# [1] تقع مدينة الشطرة في محافظة كركوك، العراق
# Label (H/N): h
#
# Cluster 3:
#
# [1] تقع مدينة الشطرة في محافظة ديالى في العراق
# Label (H/N): h
#
# Cluster 4:
#
# [1] تقع مدينة الشطرة في العراق، وتقع في محافظة صلاح الدين
# Label (H/N): h
#
# Cluster 5:
#
# [1] تقع مدينة الشطرة في ولاية ميسان في شمال شرق العراق
# Label (H/N): h
#
# Cluster 6:
#
# [1]
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -5447507915882225698
# Question: أين قامت مملكة فالنسيا؟
# Original Answer: الساحل الشرقي من شبه جزيرة ايبيريا
#
# Cluster 0:
#
# [1] من اللغات الرومنسية
# Label (H/N): h
#
# Cluster 1:
#
# [1] المدن الرئيس
# Label (H/N): h
#
# Cluster 2:
#
# [1] ألي
# Label (H/N): h
#
# Cluster 3:
#
# [1] الكاتالونية
# Label (H/N): h
#
# [2] الكتالانية
# Label (H/N): h
#
# Cluster 4:
#
# [1] في شمال إسبانيا
# Label (H/N): ا
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): h
#
# Cluster 5:
#
# [1] قامت مملكة فالنسيا في شمال شرق إسبانيا
# Label (H/N): h
#
# Cluster 6:
#
# [1] في وسط إسبانيا
# Label (H/N): h
#
# Cluster 7:
#
# [1] في شمال غرب إسبانيا
# Label (H/N): h
#
# Cluster 8:
#
# [1] الموانئ الرئيسية لمملكة فالنسيا هي الموانئ البحرية في أليكانتي و فالنسيا
# Label (H/N): h
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 8265254802677741591
# Question: متي تأسست الولايات المتحدة الامريكية ؟
# Original Answer: الرابع من يوليو عام 1776
#
# Cluster 0:
#
# [1] يبلغ عدد سكان الولايات المتحدة الأمريكية 331
# Label (H/N): h
#
# Cluster 1:
#
# [1] تأسست الولايات المتحدة الامريكية في 4 تموز 1776
# Label (H/N): n
#
# [2] تأسست الولايات المتحدة الأمريكية في 4 يوليو عام 1776م
# Label (H/N): n
#
# [3] تأسست الولايات المتحدة الأمريكية في 4 يوليو 1776
# Label (H/N): n
#
# [4] تأسست الولايات المتحدة الامريكية في 4 يوليو 1776
# Label (H/N): n
#
# [5] تأسست الولايات المتحدة الأمريكية في 4 يوليو 1776
# Label (H/N): n
#
# Cluster 2:
#
# [1] جيمس ماد
# Label (H/N): h
#
# Cluster 3:
#
# [1] دونالد ترامب هو الرئيس السابق للولايات المتحدة الامريكية
# Label (H/N): h
#
# Cluster 4:
#
# [1] جو بايدن هو الرئيس الحالي للولايات المتحدة الامريكية
# Label (H/N): h
#
# Cluster 5:
#
# [1] تأسست إيطاليا في 1861 م
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 7290345093150933182
# Question: متى تمّ أول إستعمال شبكة محلية لاسلكية ؟
# Original Answer: 1971
#
# Cluster 0:
#
# [1] 1971م
# Label (H/N): n
#
# [2] 1971م
# Label (H/N): n
#
# [3] 1971م
# Label (H/N): n
#
# [4] 1971
# Label (H/N): n
#
# Cluster 1:
#
# [1] تمّ أول إستعمال شبكة محلية لاسلكية في 1971
# Label (H/N): n
#
# [2] تمّ أول إستعمال شبكة محلية لاسلكية في عام 1971
# Label (H/N): n
#
# Cluster 2:
#
# [1]
# Label (H/N): h
#
# Cluster 3:
#
# [1] شبكة محلية لاسلكية (Wireless LAN)
# Label (H/N): h
#
# Cluster 4:
#
# [1] في عام 1973
# Label (H/N): h
#
# Cluster 5:
#
# [1] شبكة محلية لاسلكية هي شبكة من أجهزة الكمبيوتر التي تتصل ببعض
# Label (H/N): h
#
# Question Label: Non-Hallucinated (based on 6/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: -1662869598183391807
# Question: ماهى اللغة المتكلم بها في ليبيا ؟
# Original Answer: اللغة العربية الفصحى الحديثة
#
# Cluster 0:
#
# [1] منطقة الشرق
# Label (H/N): h
#
# Cluster 1:
#
# [1] العربية
# Label (H/N): n
#
# [2] العربية
# Label (H/N): n
#
# [3] العربية
# Label (H/N): n
#
# [4] العربية
# Label (H/N): n
#
# Cluster 2:
#
# [1]
# Label (H/N): h
#
# [2]
# Label (H/N): h
#
# Cluster 3:
#
# [1] اللغة العربية هي اللغة المتكلم بها في لي
# Label (H/N): n
#
# Cluster 4:
#
# [1] ليبيا
# Label (H/N): h
#
# Cluster 5:
#
# [1] Libyen
# Label (H/N): h
#
# Question Label: Hallucinated (based on 5/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 3989000223354134411
# Question: هل الغثيان  واليرقان من أعراض  التهاب الكبد الفيروسي ج؟
# Original Answer: نعم
#
# Cluster 0:
#
# [1] نعم
# Label (H/N): n
#
# [2] نعم
# Label (H/N): n
#
# Cluster 1:
#
# [1] أعراض
# Label (H/N): h
#
# Cluster 2:
#
# [1] زيدوفوين
# Label (H/N): h
#
# Cluster 3:
#
# [1] هو فيروس يصيب الكبد، ويتسبب في التهاب الكبد، وينتقل عن طريق الاتصال الجسدي مع الفيروس، ويمكن علاجه بالدواء، ويتسبب في أعراض مثل الغثيان، واليرقان، والصداع، والطفح الجلدي، والتهاب البنكرياس
# Label (H/N): h
#
# Cluster 4:
#
# [1] الفيروس
# Label (H/N): h
#
# Cluster 5:
#
# [1] الاسم العلمي للفيروس التسبب في مرض التهاب الكبد الفيروسي ج هو: هبتا فيروس التهاب الكبد ج
# Label (H/N): h
#
# Cluster 6:
#
# [1] العدوى المنجلية
# Label (H/N): h
#
# Cluster 7:
#
# [1] مرض فيروسي يصيب الك
# Label (H/N): h
#
# Cluster 8:
#
# [1] العدوى الجنسية
# Label (H/N): h
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
#
# Question ID: 7944045111033539297
# Question: أين دفنت مارغريت هيلدا ثاتشر ؟
# Original Answer: لندن
#
# Cluster 0:
#
# [1] الحزب الليبرالي
# Label (H/N): h
#
# Cluster 1:
#
# [1] دُفنت
# Label (H/N): h
#
# Cluster 2:
#
# [1] دفنت مارغريت هيلدا ثاتشر في كاتدرائية سانت بول في لندن
# Label (H/N): n
#
# Cluster 3:
#
# [1] تم دفن مارغريت هيلدا ثاتشر في الكنيسة القديمة في تشينغفورد
# Label (H/N): h
#
# Cluster 4:
#
# [1] تُوفي جاكي كينيدي في 22 مايو 1994، وتم دفنها في مقبرة الأقصى في واشنطن العاصمة
# Label (H/N): h
#
# Cluster 5:
#
# [1] دُفِنَت مارغريت هيلدا ثاتشر في دار الأباء في تشيشير
# Label (H/N): h
#
# Cluster 6:
#
# [1] في دار السير في لندن
# Label (H/N): h
#
# Cluster 7:
#
# [1] دارسي باي
# Label (H/N): h
#
# Cluster 8:
#
# [1] دُفِنت مارغريت هيلدا ثاتشر في قبرة
# Label (H/N): h
#
# Cluster 9:
#
# [1] دفنت مارغريت هيلدا ثاتشر في كنيسة سانت ماري إدوينستون في لندن
# Label (H/N): h
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to entailment_clusters_Llama3.1-8b-xor_tydiqa_sample.json
#
# Answer labeling complete!
