# %% [markdown]
# <a href="https://colab.research.google.com/github/Reemaalt/Detection-of-Hallucination-in-Arabic/blob/main/RougeL_Labeling_of_Answers_XOR_ISRI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##QA pairs generated using llama8b on xquad

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=7be474d11d8b08b36c50c1e7061474aa459f667ca37e26acfb92a95ef5f4ec8d
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %% [markdown]
# #Test RougeL

# %%
from huggingface_hub import login
login()

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
from transformers import AutoTokenizer
from rouge_score import rouge_scorer
from nltk.stem.isri import ISRIStemmer  # Import ISRI stemmer

# Load tokenizer
model_name = "core42/jais-13b"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Initialize ISRI Stemmer
stemmer = ISRIStemmer()

# Define a custom tokenizer class that applies both tokenization and stemming
class CustomTokenizer:
    def __init__(self, tokenizer, stemmer):
        self.tokenizer = tokenizer
        self.stemmer = stemmer

    def tokenize(self, text):
        words = text.split()  # Split into words first
        stemmed_words = [self.stemmer.stem(word) for word in words]  # Apply stemming
        print("Stemmed Words:", stemmed_words)  # Debugging line to check the stemmed words
        return self.tokenizer.tokenize(" ".join(stemmed_words))  # Tokenize the stemmed text

# Create an instance of our custom tokenizer
custom_tokenizer = CustomTokenizer(tokenizer, stemmer)

# Create the ROUGE scorer with our custom tokenizer
scorer = rouge_scorer.RougeScorer(['rougeL'], tokenizer=custom_tokenizer)

# Example strings
pred_str = 'السلام عليكم كيف حالك'
label_str = 'السلام عليكم صديقي كيف حالك'

# Compute ROUGE scores
scores = scorer.score(label_str, pred_str)

# Print the stemmed words to check if stemming occurs
for key, value in scores.items():
    print(f'{key}: {value}')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Stemmed Words: ['سلم', 'علي', 'صدق', 'كيف', 'حلك']
# Stemmed Words: ['سلم', 'علي', 'كيف', 'حلك']
# rougeL: Score(precision=1.0, recall=0.8333333333333334, fmeasure=0.9090909090909091)

# %% [markdown]
# #Use RougeL on data

# %%
import json
# Load data from JSON file
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# Save labeled data to a new JSON file
def save_labels(output_data, output_file_path):
    with open(output_file_path, 'w', encoding='utf-8') as file:
        json.dump(output_data, file, ensure_ascii=False, indent=4)

# Process hallucination detection efficiently (no inheritance of labels)
def check_hallucination(data, rouge_threshold=0.3, min_non_hallucinated=6):

    updated_data = {}

    for question_id, item in data.items():
        original_answer = item["original_answer"].strip()  # Ground truth
        non_hallucinated_count = 0  # Count for the number of non-hallucinated answers

        # Process each cluster
        for cluster in item["clusters"]:
            for answer_entry in cluster["answers"]:
                answer = answer_entry[0].strip()  # Extract answer text

                if answer:
                    # Compute ROUGE-L score for each individual answer
                    scores = scorer.score(original_answer, answer)
                    rouge_l_f1 = scores["rougeL"].fmeasure

                    # Determine hallucination label based on ROUGE score
                    cluster_label = "Non-Hallucinated" if rouge_l_f1 >= rouge_threshold else "Hallucinated"

                    # Append ROUGE details for the answer
                    answer_entry.append({
                        "rouge_l_f1": round(rouge_l_f1, 2),
                        "rouge_label": cluster_label
                    })

                    # Count the non-hallucinated answers
                    if cluster_label == "Non-Hallucinated":
                        non_hallucinated_count += 1

        # Determine question-level label based on the number of non-hallucinated answers
        question_label = "Non-Hallucinated" if non_hallucinated_count >= min_non_hallucinated else "Hallucinated"

        # Store updated data with the question label
        updated_data[question_id] = {
            **item,
            "computed_question_label": question_label
        }

    return updated_data

# File paths
input_file_path = "/content/human_sample_xor_tydiqa.json"
output_file_path = "labeled_data_XORsample_rougel_isri.json"

# Load data
data = load_data(input_file_path)

# Process and add labels
updated_data = check_hallucination(data)

# Save updated data
save_labels(updated_data, output_file_path)

print(f"Labeled data has been saved to {output_file_path}")
# Out:
# Stemmed Words: ['329']
# Stemmed Words: ['329', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['325', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'قعد']
# Stemmed Words: ['329']
# Stemmed Words: ['1925']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['طرز', 'كلس']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['طر']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['سمى']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['طرز', 'بار']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['برك']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['طرز', 'عمر', 'روم', 'سمى', 'طرز', 'كلس']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['طرز', 'عمر', 'روم', 'سمى', 'طرز', 'كلس']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['سمى', 'طرز', 'عمر', 'روم', '"الطراز', 'روكي"']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['هو', 'طرز', 'عمر', 'عمد', 'على', 'خدم', 'مبا', 'كلاسيكية', 'يون']
# Stemmed Words: ['عمر', 'قوط']
# Stemmed Words: ['امبراطوري']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'في', '21', 'نير', '1924', 'بعد', 'ان', 'عرض', 'عدى', 'سمم', 'نات']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'سبب', 'تهب', 'سحا', 'في', '21', 'نير', '1924']
# Stemmed Words: ['غيل']
# Stemmed Words: ['تم', 'غيل', 'فلاديمير', 'لين', 'في', '21', 'نير', '1924،', 'بعد', 'ان', 'تم', 'صبت', 'جرح', 'في', 'رأس', 'من', 'قبل', 'وند', 'نيكولايف،', 'وهو', 'ضبط', 'من', 'شرط', 'سوفيتية،', 'في', 'موسكو،', 'روس']
# Stemmed Words: ['غيل']
# Stemmed Words: ['فلاديمير', 'لين', 'هو', 'ؤسس', 'تحد', 'يت،', 'ولد', 'في', '22', 'برل', '1870', 'في', 'سيمبيرسك،', 'روس']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'في', '21', 'نير', '1924']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'في', '21', 'نير', '1924']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'في', '21', 'نير', '1924', 'سبب', 'سكت', 'دمغ']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'في', '21', 'نير', '1924', 'سبب', 'هجم', 'من', 'قبل', 'احد', 'مرافقيه،', 'حيث', 'طلق', 'عليه', 'نار', 'في', 'رأس']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'عام', '1924', 'سبب', 'نزف', 'في', 'دمغ', 'نتج', 'فجر', 'عدى', 'في', 'دمغ', 'نتج', 'تشو', 'في', 'دمغ', 'نتج', 'لاص']
# Stemmed Words: ['غيل']
# Stemmed Words: ['توف', 'فلاديمير', 'لين', 'في', '21', 'نير', '1924', 'نتج', 'مرض', 'سرط']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['كانت', 'همة', 'سبر', 'يند', 'فضي', 'هي', 'درس', 'اشع', 'كون', 'راديو', 'نجم']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['درس', 'تكو', 'ككب']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['12', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['20', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['في', '11', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['تم', 'طلق', 'سبر', 'يند', 'فضي', 'في', '12', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['24', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['15', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشر', 'ثني', 'عام', '1994']
# Stemmed Words: ['يتم', 'رسل', 'بين', 'من', 'سبر', 'ووي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم', 'حكم', 'قلي', 'في', 'نظم', 'ديكتاتوري']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'في', 'نظم', 'ديكتاتوري', 'حكم', 'قلي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['لا']
# Stemmed Words: ['نعم']
# Stemmed Words: ['لا']
# Stemmed Words: ['نعم']
# Stemmed Words: ['لا']
# Stemmed Words: ['نعم']
# Stemmed Words: ['هناك', 'عدة', 'سبب', 'قد', 'تؤد', 'الى', 'ان']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عمل', 'جهز', 'ضغط', 'لدم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['لا،', 'لأن', 'دستور', 'لا', 'عرف', 'قلية،', 'حصر', 'حكم', 'في', 'يد', 'رئس']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'حكم', 'قلي', 'في', 'نظم']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['صدر', 'لبم', '"ذا', 'مونكيز"', 'لأل', 'مرة', 'في', 'ملك', 'تحد']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['اول', 'لبم', 'فرق', 'مونكيز', 'هو', 'لبم', '(I', 'Am', 'Me)', 'الذي', 'صدر', 'في', '2007']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['صدر', 'فرق', 'مونكيز', '11', 'لبو']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['اول', 'لبم', 'فرق', 'مونكيز', 'هو', 'The', 'Monkees', '(1966)']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['اول', 'لبم', 'فرق', 'مونكيز', 'هو', '"The', 'Monkees"،', 'الذي', 'صدر', 'في', '10', 'ونو', '1966']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['لبم', 'اول', 'هو', 'The', 'Monkees', '(1966)']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['Le', 'premier', 'album', 'des', 'Monkees', 'est', '"The', 'Monkees"']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['The', 'Star']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['لبم', '"بيتش', 'بوز', 'اند', 'ذا', 'اونستوب"', '(Beach', 'Boys', 'and', 'the', 'Unstoppable)']
# Stemmed Words: ['هما', 'يقل', 'ناس', 'عن،', 'انا', 'لست', 'كذلك']
# Stemmed Words: ['اول', 'لبم', 'فرق', 'مونكيز', 'هو', '"The', 'Monkees"']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'ركب', 'كيميائية', 'من', 'يتم', 'التي', 'وجد', 'في', 'طعم', 'مثل', 'ططس', 'لفل', 'خضرو', 'خضراء', 'فكه', 'حمراء', 'رتقال،', 'ألف', 'من', 'ركب', 'كيميائية', 'تؤد', 'دور', 'هما', 'في', 'صحة', 'انس']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'ركب', 'عضي', 'تعدد', 'جزئ', 'شتق', 'من', 'يتم', 'ا']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'فصل', 'من', 'فيتامينات،', 'شمل', 'يتم', 'ا', '(لب', 'كاروتين)', 'يتم', 'ا', '(ألف', 'كاروتين)', 'يتم', 'ا', '(بت', 'كاروتين)', 'يتم', 'ا', '(جا', 'كاروتين)']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'ركب', 'ك']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'ركب', 'عضي', 'من', 'يتم', 'وجد', 'في', 'خضر', 'فكه']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'ركب', 'كيميائية', 'تعدد', 'ظائف،', 'ألف', 'من', 'ركب', 'كيميائية', 'سمى', 'بيريداز،', 'وهي', 'ركب', 'كيميائية', 'عمد', 'على', 'هيدروج', 'كرب', 'نيتروجين،', 'وهي', 'وجد', 'في', 'عدد', 'من', 'طعمة،', 'مثل', 'فكه', 'خضروات،', 'وهي', 'تؤد', 'دور', 'هما', 'في', 'حفظ', 'على', 'صحة', 'جسم،', 'عبر', 'ركب', 'كيميائية', 'قوية،', 'تؤد', 'دور']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'جمع', 'من', 'ركب', 'عضي', 'التي', 'وجد', 'في', 'عدد', 'من', 'طعم', 'مثل', 'فكه', 'خضروات،', 'عبر', 'صدر', 'رئس', 'يتم', 'A', 'في', 'نظم', 'غذي', 'بشر']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'ركب', 'كيميائية', 'وجد', 'في', 'نبت', 'حيوانات،', 'شمل', 'بتا', 'كرو', 'يتم', 'ا']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'جمع', 'من', 'واد', 'كيميائية', 'التي', 'تكون', 'وجد', 'في', 'بعض', 'تت،', 'وهي', 'عبر', 'من', 'صدر', 'رئس', 'يتم', 'ا', 'يتم', 'د', 'في', 'نظم', 'غذي', 'بشر']
# Stemmed Words: ['صبغ', 'عضي', 'تيتراتيربينويدية', '(tetraterpenoid)', 'صفراء', 'لون', '،', 'وجد', 'شكل', 'طبع', 'في', 'خضرو', 'فكه']
# Stemmed Words: ['كرت', 'هي', 'ركب', 'كيميائية', 'عبر', 'صدر', 'رئس', 'يتم', 'ا،', 'وهي', 'وجد', 'شكل', 'طبع', 'في', 'عدد', 'من', 'طعم', 'مثل', 'فكه', 'خضرو', 'بذر']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قبل', 'ان', 'ينت']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرم', 'عاش', 'في', 'ورب', 'غرب', 'في', 'عصر', 'طى،', 'كان', 'عبر', 'من', 'قبل', 'جرم', 'التي', 'هجر', 'الى', 'ورب', 'غرب']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'جمع', 'عرق', 'جرم', 'قدم', 'من', 'اصل', 'ورب', 'شرقي،', 'نشأ', 'في', 'وخر', 'عصر', 'روم', 'وبد', 'عصر', 'طى،', 'في', 'نطق', 'بحر', 'قزو', 'شمل', 'بحر', 'اسد']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرم', 'عاش', 'في', 'ورب', 'غرب', 'في', 'عصر', 'سطى']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'جمع', 'من', 'شعب', 'ورب', 'التي', 'نشأ', 'في', 'نطق', 'قوقاز', 'في', 'قرن', 'خمس', 'ميلادي،', 'زعم', 'نهم', 'من', 'نسل', 'قوط،', 'وهم', 'من', 'اهم', 'قبل', 'ورب', 'التي', 'هجر', 'الى', 'ورب', 'غربية،', 'وهم', 'من', 'اهم', 'قبل', 'التي', 'هجر', 'الى', 'ورب', 'غرب', 'في', 'عصر', 'سطى']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرم', 'قديم،', 'كان', 'يعش', 'في', 'ورب', 'شرق', 'في', 'عصر', 'قدم', 'سطى']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'قبل', 'جرم', 'من', 'شعب', 'جرمانية،', 'وهم', 'من', 'اصل', 'اوروبية،', 'وهم', 'من', 'اصل', 'جرماني،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'اصل', 'جرمانية،', 'وهم', 'من', 'ا']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرمانية،', 'وهم', 'من', 'اصل', 'عرق', 'قرب', 'من', 'عرق', 'لمن', 'دانية،', 'وهم', 'صلعون،', 'وهم', 'يعش', 'في', 'ورب', 'غربية،', 'وهم', 'يعش', 'في', 'ورب', 'غربية،', 'وهم', 'يعش', 'في', 'ورب', 'غربية،', 'وهم', 'يعش', 'في', 'ورب', 'غربية،', 'وهم', 'يعش', 'في', 'ورب', 'غربية،', 'وهم', 'يعش', 'في', 'ورب', 'غربية،', 'وهم', 'يعش', 'في', 'ورب', 'الغ']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'جمع', 'من', 'شعب', 'ورب', 'غرب', 'التي', 'نشأ', 'في', 'وئل', 'قرن', 'خمس', 'يلد', 'في', 'نطق', 'قن،', 'وكانت', 'تعش', 'في', 'قلم', 'قوطية،', 'متد', 'من', 'نهر', 'دنب', 'في', 'شمل', 'الى', 'بحر', 'ادرياتيكي', 'في', 'جنوب،', 'متد', 'من', 'نهر', 'دنب', 'الى', 'بحر', 'اسد', 'في', 'شرق،', 'متد', 'الى', 'بحر', 'ابض', 'توسط', 'في', 'غرب']
# Stemmed Words: ['قبل', 'جرم', 'شرق']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرم', 'نشأ', 'في', 'وخر', 'عصر', 'قدم', 'وبد', 'عصر', 'سطى', 'في', 'نطق', 'برابانتيا،', 'التي', 'تقع', 'في', 'شمل', 'روبا،', 'وهم', 'عبر', 'من', 'قرب', 'شعب', 'جرم', 'الى', 'رومان،', 'وقد', 'سكن', 'في', 'غلب', 'في', 'نطق', 'وقع', 'جنب', 'نهر', 'راين،', 'وبالتالي', 'كان', 'على', 'تمس', 'وثق', 'مع', 'رومان،', 'وهم', 'كان', 'من', 'اهم', 'شعب', 'التي', 'سهم', 'في', 'تكو', 'ورب']
# Stemmed Words: ['4']
# Stemmed Words: ['تسع', 'عضل', 'ربط', 'لسن', 'بلف']
# Stemmed Words: ['4']
# Stemmed Words: ['عضل', 'التي', 'ربط', 'لسن', 'بلف', 'هي:']
# Stemmed Words: ['4']
# Stemmed Words: ['عضل', 'ستة', 'التي', 'ربط', 'لسن', 'بلف', 'هي:', 'عضل', 'بلعومية،', 'عضل', 'لعم', 'ية،', 'عضل', 'لعم', 'كية،', 'عضل', 'لعم', 'فكة', 'ية،', 'عضل', 'لعم', 'فكة', 'ذقنية،', 'عضل', 'لعم', 'ذقن']
# Stemmed Words: ['4']
# Stemmed Words: ['ثلث', 'عضل', 'ترب']
# Stemmed Words: ['4']
# Stemmed Words: ['ثلث', 'عضل', 'ربط', 'ال']
# Stemmed Words: ['4']
# Stemmed Words: ['12', 'عضل']
# Stemmed Words: ['4']
# Stemmed Words: ['4', 'عضل']
# Stemmed Words: ['4']
# Stemmed Words: ['8']
# Stemmed Words: ['4']
# Stemmed Words: ['عضل', 'لعب', 'هي', 'عضل', 'خيطية،', 'تصل', 'لسن', 'في', 'لجز']
# Stemmed Words: ['4']
# Stemmed Words: ['عضل', 'جرر']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['خدم', 'صامويل', 'ورس', 'طرق', 'اشع', 'صدع', 'خرع', 'فكس']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['وظف', 'سسي', 'فكس', 'هي', 'رسل', 'رسل', 'وال']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['يمك', 'نقل', 'صور', 'رسل', 'وثق', 'سرع']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['فكس', 'سمى']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['كنولوج', 'رقم']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['في', 'جال', 'عمل', 'وصل']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['اليكسندر', 'جره']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['مصر']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['نتو', 'سكت']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['صامويل', 'ورس']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['حزب', 'سلم']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['ضطراب', 'سيس', 'صرع', 'بين', 'حكم']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['ارخ', 'وفة', 'علي', 'حيدر', 'غير', 'عرف']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['2003']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['2003']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['ماف']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['2006']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['هدي']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['سيد', 'علي', 'حيدر']
# Stemmed Words: ['تشر', 'اول', 'عام', '2004']
# Stemmed Words: ['حزب', 'وطن', 'عرق']
# Stemmed Words: ['لا']
# Stemmed Words: ['عم،', 'هناك', 'قبل', 'طوراق', 'في', 'ورت']
# Stemmed Words: ['لا']
# Stemmed Words: ['قبل', 'ورت', 'تضم', 'قبل', 'ديل،', 'زب،', 'زاوة،', 'رل،', 'زنغ،', 'واركينين،', 'رل،', 'واركينين،', 'واركينين،', 'واركينين،', 'واركينين،', 'واركينين،', 'واركينين،', 'ورك']
# Stemmed Words: ['لا']
# Stemmed Words: ['عم،', 'وجد', 'قبل', 'طوراق', 'في', 'ورت']
# Stemmed Words: ['لا']
# Stemmed Words: ['وجد', 'في', 'ورت', 'عدد', 'من', 'قبائل،', 'ثل:', 'لن،', 'وف،', 'بيزانجا،', 'ربر،', 'ماسال،', 'اسل،', 'اسل،', 'اسل،', 'اسل،', 'اسل،', 'اسل،', 'اسل،', 'اسل،', 'اسل،', 'لسم']
# Stemmed Words: ['لا']
# Stemmed Words: ['عم،', 'وجد', 'قبل', 'طوراق', 'في', 'ورت']
# Stemmed Words: ['لا']
# Stemmed Words: ['عم،', 'وجد', 'قبل', 'طوراق', 'في', 'ورت']
# Stemmed Words: ['لا']
# Stemmed Words: ['قبل', 'طرق', 'هي', 'جمع', 'قبل', 'بدي', 'تعش', 'في', 'صحراء', 'صحرى', 'في', 'شمل', 'افريقيا،', 'وهم', 'يعش']
# Stemmed Words: ['لا']
# Stemmed Words: ['قبل', 'طوراق', 'هي', 'قبل', 'عرب', 'تعش', 'في', 'ورت']
# Stemmed Words: ['لا']
# Stemmed Words: ['لغة', 'رسم', 'في', 'ورت', 'هي', 'لغة', 'عرب']
# Stemmed Words: ['لا']
# Stemmed Words: ['طوراق', 'هي', 'قبل', 'من', 'قبل', 'صحراء', 'غرب', 'وموريتان']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['2014']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['2012']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['عبر', 'حلف', 'جزء', 'من', 'حرك', 'كرد', 'في']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['2003']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['2003']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['2003']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['2003']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['2003']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['تم', 'أسس', 'حلف', 'ديمقراطي', 'كرد', 'في', 'سور', 'في', 'عام', '2003']
# Stemmed Words: ['13', 'شبط', 'عام', '2016']
# Stemmed Words: ['The', 'Kurdish', 'Democratic', 'Alliance', 'in', 'Syria', 'was', 'founded', 'in', '2003']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['في', 'مصر']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['سمت', 'حضر', 'صرة', 'قدم', 'اول', 'حضر', 'في', 'علم']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['في', 'كان', 'ما', 'في', 'فرق']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['في', 'فرق']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['في', 'فرق']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['قهر']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['منس']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['في', 'ودي', 'هومو', 'هابيليس']
# Stemmed Words: ['عرف', 'انس', 'جرم', 'منذ', 'فجر', 'بشر', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'اول', 'جرم', 'قتل', 'في', 'ارخ', 'انس']
# Stemmed Words: ['في', 'شلل', 'نهر', 'نيل']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'عظم', 'دين', 'وحد', 'نظر', 'تطر']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'عظم', 'دين', 'وحد', 'نظر', 'تطر']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'دين', 'وحد', 'نظر', 'تطر', 'شكل', 'بشر']
# Stemmed Words: ['لا']
# Stemmed Words: ['بهي', 'هي', 'دين', 'وحد', 'أسس', 'في', 'قرن', 'تسع', 'عشر', 'في', 'رن،', 'دعو', 'الى', 'وحد', 'جمع', 'ادي', 'و']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'دين', 'وحد', 'نظر', 'تطر']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'دين', 'وحد', 'نظر', 'تطر']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'دين', 'وحد', 'نظر', 'طور،', 'حيث', 'عبر', 'حية', 'بكل', 'ما', 'فيه', 'من', 'تنع', 'تطر', 'كخلق', 'من', 'له،', 'ولا', 'تؤم', 'تطر', 'التي', 'حدث', 'صطفاء', 'طبع']
# Stemmed Words: ['لا']
# Stemmed Words: ['رائيل', 'هي', 'بلد', 'سيح']
# Stemmed Words: ['لا']
# Stemmed Words: ['عم،', 'دعم', 'عظم', 'دين', 'وحد', 'نظر', 'طور،', 'حيث', 'تؤم', 'هذه', 'دين', 'وحد', 'تنع', 'في', 'خليقة،', 'دعم', 'فكر', 'تطر', 'من', 'خلل', 'نظر', 'علم']
# Stemmed Words: ['لا']
# Stemmed Words: ['بعض', 'دين', 'وحد', 'هي', 'هودية،', 'مسيحية،', 'لم،', 'هائية،', 'هندوس']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'الص']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'رائيل', 'في', 'عام', '1948']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['دول', 'عرب']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'قرن', 'تسع', 'عشر', 'في', 'امر', 'شمل']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['دول', 'نجح', 'هي', 'دول', 'متع', 'زدهار', 'قصد', 'جمع']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'ورب']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'رائيل']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'رائيل']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'سنو', 'ال', '12', 'خير', 'في', 'دول', 'تقدم']
# Stemmed Words: ['زبد', 'في', 'نطق', 'هام', '(الأراضي', 'منخفضة)', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دول', 'نجح', 'في', 'يفر']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر', 'بدن', 'بول']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر', 'بدن', 'بول']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر', 'بدن', 'بول']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر', 'بدن', 'بول']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر', 'بدن', 'بول']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر', 'بدن', 'بول']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر', 'بدن', 'بول']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['ثقة،', 'خلص،', 'صدق،', 'مسؤولية،', 'ليق', 'دنية،', 'ضامن،', 'لزم', 'وعد']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['سرج', 'سبب']
# Stemmed Words: ['ورد', 'روبر', 'فنس', 'سمث', 'بدن', 'بول']
# Stemmed Words: ['روبر']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['امم', 'بخر']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['شرف', 'رضي', 'هو', 'وحد', 'من', 'شهر', 'لسف', 'عزل', 'في', 'مصر']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['في', 'قرن', 'ربع', 'هجر']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['في', 'قرن', 'تسع', 'هجر']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['عبر', 'عزل', 'من', 'لسف', 'مسلمين،', 'وهم', 'عرف', 'بإم', 'بال']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['نشر', 'فكر', 'عزل', 'في', 'مصر', 'في', 'قرن', 'ربع', 'هجر']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['كتب', '"المنطق"', 'لأب', 'حسن', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن', 'حسن', 'بن', 'علي', 'بن']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['خلل']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['يعن', 'اسم', 'عزل', '"لم']
# Stemmed Words: ['قرن', 'ثني', 'هجر']
# Stemmed Words: ['اهم', 'ما', 'يمز', 'عزل', 'هو', 'عرف', 'كلم', 'عقل', 'هم،', 'حيث', 'عقد', 'ان', 'كلم', 'عن']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بعد', 'دين', 'دار', 'يضء', 'عن', 'دين', 'ط']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بعد', 'دين', 'دار', 'يضء', 'عن', 'دين', 'ف']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بعد', 'دين', 'دار', 'يضء', 'عن', 'دين', 'طنج']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بلغ', 'عدد', 'سكن', 'دين', 'دار', 'يضء', '3,359,000', 'نسم']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['2,655', 'كم']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['تب']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['يضم', 'ا']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['دين', 'دار']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بعد', 'دين', 'دار', 'يضء', 'عن', 'دين', 'كادير', '513', 'كم']
# Stemmed Words: ['1637']
# Stemmed Words: ['فكر', 'التي', 'طرح', 'ديكار', 'هي', 'ان', 'عرف', 'يمكن', 'ان', 'تكون', 'قلة', 'عن', 'خبر', 'قة،', 'وأن']
# Stemmed Words: ['1637']
# Stemmed Words: ['في', 'عام', '1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['في', 'عام', '1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['في', 'عام', '1637م']
# Stemmed Words: ['1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['قام', 'رين', 'ديكار', 'نشر', 'قال', 'عن', 'نهج', 'في', 'عام', '1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['قال', 'عن', 'نهج']
# Stemmed Words: ['1637']
# Stemmed Words: ['عرف', 'ناس', 'نهج', 'علم']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', 'هو', 'رجل', 'عمل', 'غريقي،', 'وهو', 'ؤسس', 'شرك', 'كندر', 'افروديسي،', 'وهي', 'شرك', 'علم', 'بقل']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', '(باللغ', 'اغريقية:', 'Ἀλέξανδρος', 'ὁ', 'Ἀφροδισεύς)', 'هو', 'ساذ', 'في', 'لسف', 'في', 'اكاديمية', 'اثي']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', 'هو', 'طبب', 'يون', 'قديم،', 'اسم', 'كمل', 'كندر', 'فرج', 'افروديسي']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', '(الاسم', 'ان:', 'Ἀλέξανδρος', 'ὁ', 'Ἀφροδισεύς)', 'هو', 'ملك', 'بحر', 'قديم،', 'من', 'اطر', 'يون']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', 'هو', 'علم', 'زيئ', 'وفل', 'يون', 'من', 'قرن', 'ربع', 'قبل', 'ميلاد،', 'عبر', 'من', 'شهر', 'علماء', 'فلك', 'زيء', 'في', 'عصر', 'هلي', 'قدم']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', '(الاسم', 'ان:', 'Ἀλέξανδρος', 'Ἀφροδίσεος)', 'هو', 'كتب', 'سخر', 'قدم', 'من', 'نن،', 'عبر', 'من', 'برز', 'كتب', 'سخر', 'في', 'عصر', 'قدم']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', 'هو', 'بحث', 'لسف', 'يون', 'قديم،', 'شهر', 'بحث', 'في', 'جال', 'ريض', 'زيء']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', 'هو', 'قئد', 'بحر', 'طلم', 'الذي', 'قاد', 'حمل', 'ضد', 'كندر', 'كبر']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', 'هو', 'علم', 'زيئ', 'علم', 'ريض', 'من', 'اسكندريه،', 'شهر', 'عدد', 'من', 'سهم', 'في', 'جال', 'ريض', 'زيء،', 'ومن', 'شهر', 'هذه', 'سهم', 'طور', 'لما', 'عرف', 'ب', '"نظر', 'شعة"', 'او', '"نظر', 'شعع"']
# Stemmed Words: ['لسف', 'جدل', 'ومن', 'كبر', 'شرح', 'رسطو', 'في', 'عصر', 'يون', 'روم']
# Stemmed Words: ['كندر', 'افروديسي', '(أو', 'كندر', 'ثيني)', '(350-330', 'ق']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['خرج', 'يلم', 'شغف', 'سيح', 'هو', 'كريستوفر', 'نول']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['دير', 'برت']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['خرج', 'يلم', 'شغف', 'سيح', 'هو', 'جيف', 'ثنس']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['كريستوف', 'نول', 'هو', 'خرج', 'نمئ', 'رنس', 'من', 'مواليد', '11', 'مبر', '1964']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['جيف', 'ثنس']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['ريتشارد', 'كينس']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['روبر', 'زيميكس']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['يتر', 'جكس']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['يطل']
# Stemmed Words: ['ميل', 'غيبس']
# Stemmed Words: ['كريستوفر', 'نول']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['رلم', 'كند']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['رلم', 'كند']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['رلم', 'كند']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['جلس', 'عمم', 'كند']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['لكة', 'في', 'كند']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['لكة']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['رئس', 'زرء', 'كند']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['رئس', 'زرء', 'كند']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['لكة', 'اليزابيث', 'ثني']
# Stemmed Words: ['جلس', 'عمم']
# Stemmed Words: ['حكم', 'عام']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['هيروز', 'كيرز']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['جيمس', 'م']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['من', 'هو', 'رانكل', 'روزفل']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['لوس', 'وكر']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['ولف', 'هاميل']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['رانكل', 'روزفل']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['سيد', 'رانكل', 'كيز']
# Stemmed Words: ['هرف', 'شنط', 'ويل']
# Stemmed Words: ['Francis', 'Kelsey']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'ماء', 'خدم', 'في', 'صلة،', 'وهو', 'ماء', 'خدم', 'في', 'غسل', 'يدي', 'ؤمن', 'قبل', 'صلة']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['هو', 'صلصل', 'ذكى', 'في', 'طود', 'من', 'خطب', 'خصب', 'شعث', 'حجر', 'زلج', 'خضر', 'ابض', 'حمر', 'اسد', 'سمر', 'صفر']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'جسم', 'يكون', 'من', 'خيل،', 'خدم', 'حمل', 'عرب', 'رجل', 'في', 'سفر']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'حجر', 'صخر', 'صلب', 'حفر', 'ناس', 'لتك', 'له', 'قيم', 'خوطئ']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمرك:', 'هو', 'جسم', 'خدم', 'في', 'جوز', 'ماء', 'على', 'فن،', 'وهو', 'صصع', 'سمر', 'متوقعة،', 'خدم', 'جوز', 'خاف']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'مخز', 'من', 'عسل', 'خدم', 'في', 'علل', 'تخز']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'قسم', 'من', 'جسم', 'انس', 'ي']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'شجر']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'نوع', 'من', 'خضرو']
# Stemmed Words: ['صلح', 'ذات', 'طبع', 'قصد', 'وأم', 'كلف', 'رقب', 'بدل', 'جرة', 'على', 'حدد', 'وجب', 'ضرب', 'على', 'ورد']
# Stemmed Words: ['جمر', 'هو', 'نبت', 'من', 'نبت', 'قطب']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['يمكن', 'مم']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['كبر', 'دين', 'في', 'كسك', 'هي']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['تقع', 'دين', 'كنك']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['تقع', 'دين', 'كنك', 'في', 'ولي', 'كين', 'رو', 'في', 'كسك']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['تقع', 'دين', 'كنك', 'في', 'ولي', 'كين', 'رو', 'في', 'كسك']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['تقع', 'دين', 'كنك', 'في', 'ولي', 'كين', 'رو', 'في', 'كسك']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['تقع', 'دين', 'كنك', 'في', 'ولي', 'كين', 'رو', 'في', 'كسك']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['نشط', 'شهر', 'في', 'دين', 'كنك', 'هي', 'سيح', 'جمم', 'ريض', 'ندق', 'نجع']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['تقع', 'دين', 'كنك', 'في', 'كسك']
# Stemmed Words: ['شمل', 'شرق', 'لول', 'كون', 'رو', 'في', 'كسك']
# Stemmed Words: ['دين', 'كنك', 'هي', 'دين', 'كثر', 'زير', 'في', 'كسك']
# Stemmed Words: ['291']
# Stemmed Words: ['"جزير', 'قطرى:', 'ارخ', 'علق', 'مع', 'من"']
# Stemmed Words: ['291']
# Stemmed Words: ['29', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['29', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['29', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['43', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['195', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['وجد', 'في', 'جزر', 'قطرى', '44', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['30', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['كثر', 'من', '50', 'نوع']
# Stemmed Words: ['291']
# Stemmed Words: ['وجد', 'في', 'جزر', 'قطرى', '44', 'نوع', 'من', 'طيور،', 'عبر', 'هذا', 'عدد', 'من', 'رقم', 'طير', 'وجد', 'في', 'جزر', 'من', 'على', 'رقم', 'في', 'علم']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['يتل', 'هي', 'كبر', 'مدن', 'ولي', 'شنط']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بيترزبورغ', 'هي', 'كبر', 'مدن', 'ولي', 'ورغ']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['مينيابوليس', 'هي', 'كبر', 'مدن', 'ولي', 'مينيسوتا']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['هي', 'بورتلاند']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['رمنغ']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بور']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['رتل']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['دين', 'يرب']
# Stemmed Words: ['مصر']
# Stemmed Words: ['شهر', 'فند']
# Stemmed Words: ['مصر']
# Stemmed Words: ['تقع', 'دين', 'اسكندرية', 'على', 'سحل', 'بحر', 'ابض', 'توسط']
# Stemmed Words: ['مصر']
# Stemmed Words: ['تقع', 'اسكندرية', 'على', 'سحل', 'بحر', 'ابض', 'توسط', 'في', 'مصر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['لغة', 'عرب']
# Stemmed Words: ['مصر']
# Stemmed Words: ['تقع', 'اسكندرية', 'على', 'سحل', 'بحر', 'ابض', 'توسط', 'في', 'شمل', 'مصر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['بعض', 'علم', 'سيح', 'في', 'اسكندرية', 'شمل', 'قلع', 'قايتب', 'محط', 'قطر', 'اسكندرية', 'محط', 'قطر', 'اسكندرية', 'وم']
# Stemmed Words: ['مصر']
# Stemmed Words: ['تقع', 'دين', 'اسكندرية', 'في', 'مصر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['دين', 'اسكندرية', 'هي', 'دين', 'سحل', 'تقع', 'في', 'شمل', 'صر،', 'عبر', 'ثني', 'كبر', 'دين', 'في', 'مصر', 'بعد', 'قهر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['همي', 'كندر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['اسكندرية', 'هي', 'دين', 'سحل', 'صرة', 'تقع', 'على', 'سحل', 'بحر', 'ابض', 'توسط']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['غار', 'جع']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['تقع', 'مغ']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['غار', 'عبر', 'من', 'اهم', 'علم', 'ثري', 'في', 'نن،', 'تمز', 'غرف', 'كبر', 'تقن', 'التي', 'تم', 'شاؤ', 'يد،', 'كما', 'انه', 'شهد', 'على', 'ارخ', 'لبن', 'قدم']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['تقع', 'غار', 'جعت', 'في', 'نن،', 'على', 'بعد', '8', 'كيلومتر', 'من', 'روت،', 'عبر', 'من', 'اهم', 'علم', 'سيح', 'في', 'نطق']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['تقع', 'غار', 'جعت', 'في', 'لبن']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['تقع', 'غار', 'جعت', 'في', 'لبن']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['تقع', 'غار', 'جعت', 'في', 'لبن']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['تقع', 'غار', 'جعت', 'في', 'لبن']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['ماز', 'غار', 'جعت', 'وجد']
# Stemmed Words: ['قضء', 'كسرو']
# Stemmed Words: ['ادة', 'التي', 'خدم', 'في', 'بن']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['مصر', 'قدم']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['12', 'برج']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['12', 'برج']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['12', 'برج']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['12', 'برج']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['هناك', '12', 'برج', 'في', 'علم', 'نجم']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['كول']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['برج', 'اسد']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['برج', 'قوس']
# Stemmed Words: ['اثن', 'عشر']
# Stemmed Words: ['عذراء،', 'حوت،', 'ميزان،', 'دل،', 'عقرب،', 'قوس،', 'رطن،', 'سد،', 'ماء']
# Stemmed Words: ['نعم']
# Stemmed Words: ['همي', 'حفظ', 'قرآ', 'كرم', 'للغ', 'عرب', 'تكم', 'في', 'حفظ', 'علي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'قرآ', 'من', 'حفظ', 'لغة', 'عربية،', 'فإن', 'حفظ', 'على', 'قعد', 'واصطلاحاته', 'ورا']
# Stemmed Words: ['نعم']
# Stemmed Words: ['لأن', 'قرآ', 'كرم', 'هو', 'كتب', 'قدس', 'سلم', 'و', 'هو', 'كتب', 'الذي', 'كتب', 'لغة', 'عرب']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم', 'قرآ', 'حفظ', 'علي', 'لغة', 'عرب']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'قرآ', 'حفظ', 'علي', 'لغة', 'عرب']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عزز', 'قرآ', 'لغة', 'عرب', 'من', 'خلل', 'خدم', 'كلم', 'جدد', 'فرد', 'غ']
# Stemmed Words: ['نعم']
# Stemmed Words: ['قرآ', 'هو', 'صدر', 'عدد', 'من', 'فرد', 'التي', 'عمل', 'عرب', 'في', 'لغة']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'قرآ', 'حفظ', 'علي', 'لغة', 'عربية،', 'عرب', 'قبل', 'سلم', 'كان', 'لعب', 'بعض', 'كلم', 'التي', 'لا', 'احد', 'عرف', 'معناها،', 'ولكن', 'بعد', 'نزل', 'قرآ', 'صبح', 'عرف', 'عنى', 'كل', 'كلم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم', 'قرآ', 'من', 'حفظ', 'علي', 'لغة', 'عرب', 'ليم', 'هذا']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['تم', 'كشف', 'اشع', 'تحت', 'حمراء', 'في', 'عام', '1800', 'من', 'قبل', 'ليم', 'هييرشل']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['كشف', 'زيئ', 'برط', 'ليم', 'هيرشل', 'اشع', 'تحت', 'حمراء', 'في', 'عام', '1800']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['كشف', 'اشع', 'تحت', 'حمراء', 'في', 'عام', '1800م', 'من', 'قبل', 'ليم', 'هيرشل']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['كشف', 'اشع', 'تحت', 'حمراء', 'في', 'عام', '1800م', 'من', 'قبل', 'ولم', 'هيرشل']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['كشف', 'علم', 'برط', 'ليم', 'هيرشل', 'اشع', 'تحت', 'حمراء', 'في', 'عام', '1800م']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['طيف']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['كشف', 'اشع', 'تحت', 'حمراء', 'في', 'عام', '1800م']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['تم', 'كشف', 'اشع', 'تحت', 'حمراء', 'في', 'عام', '1800م']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['طبق', 'عمل', 'اشع', 'تحت', 'حمراء', 'شمل', 'خدم', 'في', 'طب،', 'ضء،', 'وال']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['كشف', 'ليم', 'هيرشل', 'في', 'عام', '1801']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['Keratin', 'is', 'a', 'protein', 'found', 'in', 'bacteria,', 'fungi,', 'and']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['كيت', 'هو', 'ركب', 'كيميائ', 'حوي', 'على', 'كربون،', 'هيدروجين،', 'نتروجين،', 'ور،', 'كبريت،', 'كالكوج', 'هو', 'ركب', 'كيميائ', 'حوي', 'على', 'كربون،', 'هيدروجين،', 'نتروجين،', 'ور،', 'كبريت،', 'كالكوج', 'هو', 'ركب', 'كيميائ', 'حوي', 'على', 'كربون،', 'هيدروجين،', 'نتروجين،', 'ور،', 'كبر']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['كيت', 'هو', 'برو', 'وجد', 'في', 'جدر', 'خلا', 'نبت', 'حيو', 'كتر']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['هو', 'برو', 'وجد', 'في', 'خلا', 'نبت', 'وهو', 'من', 'اهم', 'واد', 'كون', 'غذء']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['كيت', 'هو', 'برو', 'نجه', 'جسم', 'من', 'ليف', 'بروتينية', 'في', 'طعم']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['كيت', 'هو', 'برو', 'عبر', 'من', 'برت', 'دهنية،', 'وهو', 'لعب', 'دور', 'هما', 'في', 'قلل', 'فقد', 'ليف', 'عضلية،', 'عبر', 'من', 'برت', 'التي', 'ظهر', 'في', 'جسم', 'عند', 'فقد', 'نسج', 'عضلية،', 'يتم', 'ناج', 'كيت', 'في', 'جسم', 'شكل', 'طبع', 'عند', 'أثر', 'ية:', 'فقد', 'نسج', 'عضلية،', 'او', 'صبة', 'نة،', 'او', 'دهر', 'نسج', 'عضلية،', 'او', 'صبة', 'مرض']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['هو', 'برو', 'لعب', 'دور', 'هما', 'في', 'بنء', 'جلد', 'شعر', 'حجب']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['كيت', 'هو', 'برو', 'صنع', 'من', 'قبل', 'بعض', 'واع', 'طريات،', 'خدم', 'كعمل', 'آزر', 'في', 'عدد', 'من', 'مرض', 'طرية،', 'مثل', 'مرض', 'جلد', 'فطر']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['هو', 'برو', 'وجد', 'في', 'جلد']
# Stemmed Words: ['ادة', 'حيئ', 'من', 'عدد', 'كاريد', 'وهي', 'عبر', 'ركب', 'سسي', 'جنب', 'خلة', 'فطر', 'وهي', 'هيكل', 'صلب', 'الذي', 'يغط', 'جسم', 'حشر', 'عدد', 'من', 'فصل', 'رجل', 'بعض', 'حيو']
# Stemmed Words: ['هو', 'برو', 'وجد', 'في', 'جلد', 'يحم', 'جلد', 'من', 'حرق']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['علم', 'رنس', '"جاكوب', 'كولاس', 'بيرنارد"', 'هو', 'اول', 'من', 'قام', 'شخص', 'مرض', 'كسح', 'لدى', 'طفل']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['ليم', 'سلر']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['شخص', 'مرض', 'كسح', 'لدى', 'طفل', 'اول', 'مرة', 'تم', 'شخص', 'لها', 'من', 'قبل', 'طبب', 'الم', 'كسندر', 'اوم', '(Alexander', 'Ombredanne)', 'عام', '1898']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['شخص', 'مرض', 'كسح', 'لدى', 'طفل', 'هو', 'من', 'عمل', 'طبب', 'جلز', '"إدو', 'كينيون"', 'عام', '1889']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['شخص', 'مرض', 'كسح', 'لدى', 'طفل', 'يعد', 'الى', 'طبب', 'رنس', 'بير', '(Pierre', 'Marie', 'Béclard)', 'الذي', 'عاش', 'في', 'قرن', 'تسع', 'عشر']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['شخص', 'مرض', 'كسح', 'لدى', 'طفل', 'تم', 'حدد', 'لأل', 'مرة', 'من', 'قبل', 'طبب', 'يطل', 'ستر', 'جيلاردو', 'عام', '1822']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['دولف']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['دكتور', 'يلس', 'كراندال', 'روبنز']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['علم', 'برط', 'ادو', 'كلر']
# Stemmed Words: ['دانيال', 'سلر']
# Stemmed Words: ['جيمس', 'هات']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['لا']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['لا', 'بنى', 'نبي', 'سلم', 'قدس']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['لا', 'بنى', 'نبي', 'سلم', 'قدس']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['بنه', 'نبي', 'دود']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['ولي']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['عم،', 'بنى', 'نبي', 'سلم', 'قدس']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['نعم', 'بنى', 'نبي', 'سلم', 'قدس']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['سحق']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['بنى', 'الن']
# Stemmed Words: ['يعط', 'كتب', 'قدس', 'عبر', 'فضل', 'في', 'بنء', 'هيكل', 'اول', 'في', 'قدس']
# Stemmed Words: ['ان', 'بنء', 'قدس', 'يعد', 'الى', 'عهد', 'سلم', 'بن', 'داود،', 'حيث', 'بنى', 'سلم', 'بن', 'دود', 'دين', 'قدس،', 'التي', 'كانت', 'سمى', 'ذاك', 'اورشليم،', 'على', 'هضب', 'زيت']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['كان', 'الس']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['في', '19', 'ديسمبر', '1914']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['نيكفوروس', 'باسيلاجيوس']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['نشب', 'عرك', 'رعش', 'في', 'عام', '1071م']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['زعم', 'الذي', 'قاد', 'جيش', 'زنط', 'في', 'عرك', 'رعش', 'هو', 'روبر', 'جيسكاس']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['نشب', 'عرك', 'رعش', 'في', 'عام', '1517']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['كان', 'ياس', 'باي', 'من', 'بين', 'قدة', 'جيش', 'ملي', 'في', 'عرك', 'رعش']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['سابق', 'ريض', 'صري']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['نشب', 'عرك', 'رعش', 'في', '24', 'ديسمبر']
# Stemmed Words: ['7', 'تمز', 'عام', '1742']
# Stemmed Words: ['في', '25', 'نير', '151']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['يتم', 'نفذ']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'طبق', 'في', 'بعض', 'احي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['طبق', 'حكم', 'عدم', 'في', 'سعد', 'في', 'قضا', 'تعلق', 'جرم', 'خلة', 'عرض', 'عم،', 'جرم', 'ضد', 'امن', 'قومي،', 'جرم', 'ضد', 'امن', 'عم،', 'جرم', 'ضد', 'رد،', 'جرم', 'ضد', 'ممتلكات،', 'جرم', 'ضد', 'فس،']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'طبق', 'حكم', 'عدم', 'في', 'سعد']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'طبق', 'حكم', 'عدم', 'في', 'سعد']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عم،', 'عبر', 'عدم', 'عقب', 'مكن', 'في', 'سعد']
# Stemmed Words: ['نعم']
# Stemmed Words: ['طبق', 'حكم', 'عدم', 'في', 'سعد', 'في', 'حال', 'جرم', 'حدد', 'في', 'قان', 'جني', 'عودي،', 'مثل', 'قتل', 'عمد،', 'خين', 'عظمى،', 'زن،', 'رقة،', 'تعد', 'على', 'امن', 'عام']
# Stemmed Words: ['نعم']
# Stemmed Words: ['قسم', 'خاص', 'سجن']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'هود']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'супيريور']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'супيريور']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'супيريور']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'پيريور']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'супيريور']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'عظمى']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'رير', 'هي', 'كبر', 'بحر', 'في', 'كندا،', 'تقع', 'في', 'جزء', 'شمل', 'غرب', 'من', 'ولي', 'تحد']
# Stemmed Words: ['بحر', 'سوبيريور']
# Stemmed Words: ['بحر', 'رير']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'ونس', 'في', '20', 'ارس', '1956']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'ونس', 'في', '20', 'ارس', '1956']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'ونس', 'في', '20', 'ارس', '1956']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'ونس', 'في', '20', 'ارس', '1956']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'ونس', 'في', '20', 'ارس', '1956']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'ونس', 'في', '20', 'ارس', '1956']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'غرب', 'في', '2', 'ارس', '1956']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['قلت', 'جزر', 'في', '5', 'ولو', '1962']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['الع']
# Stemmed Words: ['ارس', '1956']
# Stemmed Words: ['20', 'ارس', '1956']
# Stemmed Words: ['ابن', 'عطء', 'الل', 'كندر']
# Stemmed Words: ['ؤلف', 'كتب', '"', 'حكم', 'عطي', '"', 'هو', 'ابو', 'عثم', 'عمرو', 'بن', 'بشر', 'بن', 'عثم', 'عطر']
# Stemmed Words: ['ابن', 'عطء', 'الل', 'كندر']
# Stemmed Words: ['هو', '"', 'عطء', 'الل', 'كندر', '"']
# Stemmed Words: ['ابن', 'عطء', 'الل', 'كندر']
# Stemmed Words: ['حكم', 'عطي']
# Stemmed Words: ['ابن', 'عطء', 'الل', 'كندر']
# Stemmed Words: ['ابو', 'سحق', 'راهيم', 'بن', 'حمد', 'بن', 'سحق', 'بن', 'راهيم', 'بن', 'سلم', 'بن', 'عطء', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن', 'سلم', 'بن']
# ...
# Stemmed Words: ['عام', '1377']
# Stemmed Words: ['توف', 'درد', 'ثلث', 'في', '21', 'ونو', '1377']
# Stemmed Words: ['عام', '1377']
# Stemmed Words: ['توف', 'درد', 'ثلث', 'في', '21', 'ونو', '1377']
# Stemmed Words: ['عام', '1377']
# Stemmed Words: ['توف', 'درد', 'ثلث', 'في', '21', 'ونو', '1377']
# Stemmed Words: ['عام', '1377']
# Stemmed Words: ['140']
# Stemmed Words: ['عام', '1377']
# Stemmed Words: ['درد', 'ثلث', 'ملك', 'انجلترا،', 'كان', 'ملك', 'جلتر', 'من', '1327', 'حتى', 'وفت', 'في', '1377']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['قدر', 'عدد', 'ضحا', 'لمد']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['كثر', 'من', '3']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['300', 'الف']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['3000000']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['غزو', 'الم', 'لتشيكوسلوفاك', 'في', 'عام', '1939،', 'غزو', 'الم', 'ل', 'لند', 'في', 'عام', '1939،', 'غزو', 'يبا', 'نشر', 'في', 'عام', '1931،', 'وحد', 'لمن', 'في', 'عام', '1933،', 'وحد', 'يطل', 'في', 'عام', '1922،', 'وحد', 'ياب']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['قدر', 'عدد', 'ضحا', 'دني', 'ياب', 'خلل', 'حدث', 'حرب', 'علم', 'ثني', 'حول', '3']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['قدر', 'عدد', 'ضحا', 'دني', 'ياب', 'خلل', 'حرب', 'علم', 'ثني', 'ب', '3']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['قدر', 'عدد', 'ضحا', 'دني', 'ياب', 'خلل', 'حدث', 'حرب', 'علم', 'ثني', 'حول', '3']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['قدر', 'عدد', 'ضحا', 'دني', 'ياب', 'خلل', 'حدث', 'حرب', 'علم', 'ثني', 'حول', '3']
# Stemmed Words: ['بين', '129000', 'و', '226000']
# Stemmed Words: ['3100000']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['تم', 'طحة', 'لكة', 'روس', 'في', 'عام', '1917']
# Stemmed Words: ['1917']
# Stemmed Words: ['رسل', 'فون', 'دير', 'لين']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['Imperial', 'Brands']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['تتك', 'يجر']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['هونغ', 'كونغ']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['تم', 'بكر', 'يجر', 'الكترونية', 'في', 'عام', '2003']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['عطء', 'رئح', 'شخص']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['هو', 'هونغ', 'كينج']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['2003']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['2003']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['تم', 'بكر', 'يجر', 'الك']
# Stemmed Words: ['عام', '1963']
# Stemmed Words: ['تتك', 'يجر', 'الكترونية', 'من:', 'طارية،', 'حول،', 'صدر', 'رق،', 'حول،', 'حول،', 'صدر']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['فيف', 'اري', 'هارتل', 'من', 'رال']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['1973']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['فيف', 'اري', 'هارتل', 'هي', 'مرأ', 'بريطانية', 'عقل', 'في', '2019', 'تهم', 'جسس', 'صلح', 'روس', 'في', 'ملك', 'تحد']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['ولد', 'فيف', 'هارتل', 'في', '26', 'ارس', '1923']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['ننا', 'كونو']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['شغل', 'فيف', 'اري', 'هارتل', 'هنة', 'طبب', 'نفس']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['24', 'ديسمبر', '1912']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['فيف', 'اري', 'هارتل', '(1899-1990)', 'كانت', 'علم', 'زيء', 'بريطانية،', 'ولد', 'في', 'لند']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['ولد', 'فيف', 'اري', 'هارتل', 'في', '26', 'ارس', '1907']
# Stemmed Words: ['هند', 'بريطانية']
# Stemmed Words: ['ول']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['الأ']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['هي', 'قدر', 'على', 'حكم', 'في', 'شعر', 'وتصرفاتنا،', 'فكر', 'في', 'شيء', 'شكل', 'سقل', 'عن', 'عواطفنا،', 'ويم', 'ان', 'تكون', 'انا', 'علا', 'ركب', 'من', 'عدة', 'عناصر،', 'ثل:', 'انا', 'علا', 'التي', 'حكم', 'عل،', 'انا', 'علا', 'التي', 'حكم', 'عواطف،', 'انا', 'علا', 'التي', 'حكم', 'فكر']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['انا', 'علا', 'هي', 'نفس', 'حقيقية،', 'وهي', 'هيئ', 'درك', 'نطو', 'على', 'جمع', 'كون', 'فس،', 'تقم', 'بتف', 'علم', 'خرج', 'شخص', 'داخلي،', 'سعد', 'في', 'تكو', 'قيم', 'هوايات،', 'ألف', 'من', 'شعر', 'يجب', 'سلط', 'ذكء،', 'وهي', 'هيئ', 'التي', 'متع', 'فكر', 'ذكء', 'شخصية،', 'وهي', 'هيئ', 'التي', 'متع', 'ذكء']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['وفق', 'رويد،', 'انا', 'علا', 'هي', 'جزء', 'من', 'نفس', 'ربط', 'وقع', 'هوية،', 'وهو', 'عبر', 'هوة', 'شخص', 'في', 'جمع']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['هي', 'نفس', 'بشر', 'التي', 'متع', 'بوع', 'كبر', 'جوز', 'انا', 'عدي']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['انا', 'علا', 'هي', 'جزء', 'من', 'نفس', 'بشر', 'الذي', 'يتح']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['عرف', 'رود', 'على', '"لأ', 'عليا"', 'او', '"لأ', 'حقيقية"', 'او', '"لأ', 'حقيقية"', '(true', 'self)', 'او', '"لذ', 'حقيقية"،', 'وهي', 'صطلح', 'خدم', 'رود', 'وصف', 'جزء', 'من', 'نفس', 'بشر', 'الذي', 'عبر', 'كثر', 'استقرارا', 'وثب']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['هي', 'نوة', 'ذتي', 'تقع', 'في', 'جزء', 'خلف', 'من', 'دمغ،', 'عبر', 'ركز', 'وع،', 'سمح', 'شخص', 'فكر', 'في', 'نفس']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['تمز', 'استقلالية', 'قدر', 'على', 'حكم', 'في', 'انا', 'ضعيفة،', 'حيث', 'تتم', 'من', 'تخذ', 'قرر', 'حدد', 'ولو', 'دون', 'اي', 'أثر', 'من', 'انا', 'ضعف']
# Stemmed Words: ['شخص', 'مرء', 'في', 'صور', 'كثر', 'حفظ', 'وعقلانية']
# Stemmed Words: ['هي', 'انا', 'التي', 'وفق', 'مع', 'قيم', 'خلق', 'اجتماعية', 'في', 'جمع']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['عاش', 'رين', 'ديكار', 'في', 'فتر', 'ما', 'بين', '31', 'ارس', '1596', 'و11', 'مبر', '1650']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['عاش', 'رين', 'ديكار', 'في', 'فتر', 'من', '31', 'ارس', '1596', 'الى', '11', 'مبر', '1650']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['كانت', 'دته', 'جين', 'روكار']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['1612م']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['عاش', 'رين', 'ديكار', 'في', 'قرن', 'سبع', 'عشر']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['كان', 'رين', 'ديكار', 'لسف', 'رنسيا،', 'عبر', 'وحد', 'من', 'اهم', 'لسف', 'في', 'عصر', 'حدث']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['رين', 'ديكار']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['كان', 'ايمانويل', 'كانت', '(1724-1804)', 'من', 'ؤسس', 'لسف', 'حديثة،', 'وهو', 'من', 'شهر', 'لسف', 'الم']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['رنه', 'ديكار', '(31', 'ارس', '1596', '–', '11', 'مبر', '1650)', 'كان', 'لسف', 'رنسيا،', 'عبر', 'من', 'اهم', 'لسف', 'في', 'ارخ', 'فة،', 'عبر', 'من', 'ؤسس', 'لسف', 'حديثة،', 'عبر', 'من', 'اهم', 'لسف', 'في', 'قرن', 'سبع', 'عشر']
# Stemmed Words: ['قرن17']
# Stemmed Words: ['له', 'أثر', 'كبر']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['عزم', 'دور', 'هو', 'عزم', 'قوة', 'حول', 'حور', 'دور']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['عزم', 'دور', 'او', 'عزم', 'دور', 'حرك', 'هو', 'كمة', 'طقة', 'تبع', 'حقق', 'دور', 'او', 'دور', 'حرك']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['هو', 'عزم', 'قوة', 'طبق', 'على', 'جسم', 'في', 'تجه', 'دور', 'جسم']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['عزم', 'دور', 'او', 'عزم', 'دور', 'حول', 'حور', 'دور', 'هو', 'حصل', 'دور', 'ادة', 'حول', 'حور', 'دور']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['عزم', 'دور', 'هو', 'عزم', 'دور', 'حور', 'حول', 'حور', 'دور', 'عين']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['هو', 'حصل', 'ضرب', 'قوة', 'عامد', 'على', 'سار', 'عن', 'بعد', 'ساف']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['عزم', 'دور', 'او', 'عزم', 'دور', 'حور', 'هو', 'حصل', 'ضرب', 'قوة', 'حور', '(لت', 'ؤثر', 'على', 'جسم', 'في', 'محوره)', 'عن', 'ساف', 'دور', 'جسم،', 'رمز', 'له', 'ب', '"L"', 'او', '"τ"', 'وحد', 'هي', 'نيو', 'متر', 'متر', '(N·m)']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['عزم', 'دور', 'هو', 'كمة', 'دور', 'التي', 'حدث', 'عزم', 'قوة', 'على', 'جسم', 'ما']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['هو', 'عزم', 'قوة', 'طبق', 'على', 'جسم', 'حول', 'نقط', 'رجع']
# Stemmed Words: ['قيم', 'تجه', 'قيس', 'مدى', 'قدر', 'قوة', 'على', 'دور', 'مجســـم', 'حول', 'حور', 'ما']
# Stemmed Words: ['هو', 'قوة', 'طبق', 'على', 'جسم', 'حول', 'دور', 'في', 'دار', 'الى', 'دور', 'حول', 'نفس']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'حفظ', 'بصر', 'جنب', 'عرق']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'حفظ', 'بصر', 'في', 'جنب', 'عرق']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'حفظ']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'نطق', 'بطن']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'حفظ', 'الق']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'حفظ', 'كركوك،', 'عرق']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'حفظ', 'ديلى', 'في', 'عرق']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'عرق،', 'تقع', 'في', 'حفظ', 'صلح', 'دين']
# Stemmed Words: ['حفظ', 'ذي', 'قار']
# Stemmed Words: ['تقع', 'دين', 'شطر', 'في', 'ولي', 'ميس', 'في', 'شمل', 'شرق', 'عرق']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['من', 'لغت', 'رومنس']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['مدن', 'رئس']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['الي']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['كاتالونية']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['كتالانية']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['في', 'شمل', 'سبن']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['قمت', 'ملك', 'لنس', 'في', 'شمل', 'شرق', 'سبن']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['في', 'وسط', 'سبن']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['في', 'شمل', 'غرب', 'سبن']
# Stemmed Words: ['سحل', 'شرق', 'من', 'شبه', 'جزر', 'يبر']
# Stemmed Words: ['ونئ', 'رئس', 'ممل', 'لنس', 'هي', 'ونئ', 'بحر', 'في', 'اليكانتي', 'و', 'لنس']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['بلغ', 'عدد', 'سكن', 'ولي', 'تحد', 'امر', '331']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['أسس', 'ولي', 'تحد', 'امر', 'في', '4', 'تمز', '1776']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['أسس', 'ولي', 'تحد', 'امر', 'في', '4', 'ولو', 'عام', '1776م']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['أسس', 'ولي', 'تحد', 'امر', 'في', '4', 'ولو', '1776']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['أسس', 'ولي', 'تحد', 'امر', 'في', '4', 'ولو', '1776']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['أسس', 'ولي', 'تحد', 'امر', 'في', '4', 'ولو', '1776']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['جيمس', 'ماد']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['دونالد', 'رمب', 'هو', 'رئس', 'سبق', 'ولي', 'تحد', 'امر']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['جو', 'بيد', 'هو', 'رئس', 'الحالي', 'ولي', 'تحد', 'امر']
# Stemmed Words: ['ربع', 'من', 'ولو', 'عام', '1776']
# Stemmed Words: ['أسس', 'يطل', 'في', '1861', 'م']
# Stemmed Words: ['1971']
# Stemmed Words: ['1971م']
# Stemmed Words: ['1971']
# Stemmed Words: ['1971م']
# Stemmed Words: ['1971']
# Stemmed Words: ['1971م']
# Stemmed Words: ['1971']
# Stemmed Words: ['1971']
# Stemmed Words: ['1971']
# Stemmed Words: ['تم', 'اول', 'عمل', 'شبك', 'حلة', 'لسل', 'في', '1971']
# Stemmed Words: ['1971']
# Stemmed Words: ['تم', 'اول', 'عمل', 'شبك', 'حلة', 'لسل', 'في', 'عام', '1971']
# Stemmed Words: ['1971']
# Stemmed Words: ['شبك', 'حلة', 'لسل', '(Wireless', 'LAN)']
# Stemmed Words: ['1971']
# Stemmed Words: ['في', 'عام', '1973']
# Stemmed Words: ['1971']
# Stemmed Words: ['شبك', 'حلة', 'لسل', 'هي', 'شبك', 'من', 'جهز', 'كمبيوتر', 'التي', 'تصل', 'بعض']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['نطق', 'شرق']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['عرب']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['عرب']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['عرب']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['عرب']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['لغة', 'عرب', 'هي', 'لغة', 'تكلم', 'بها', 'في', 'لي']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['ليب']
# Stemmed Words: ['لغة', 'عرب', 'صحى', 'حدث']
# Stemmed Words: ['Libyen']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عرض']
# Stemmed Words: ['نعم']
# Stemmed Words: ['زيدوفو']
# Stemmed Words: ['نعم']
# Stemmed Words: ['هو', 'يرس', 'يصب', 'كبد،', 'سبب', 'في', 'تهب', 'كبد،', 'نقل', 'عن', 'طرق', 'تصل', 'جسد', 'مع', 'روس،', 'ويم', 'علج', 'دء،', 'سبب', 'في', 'عرض', 'مثل', 'غثيان،', 'رقن،', 'صدع،', 'طفح', 'جلدي،', 'تهب', 'كرياس']
# Stemmed Words: ['نعم']
# Stemmed Words: ['يرس']
# Stemmed Words: ['نعم']
# Stemmed Words: ['اسم', 'علم', 'يرس', 'سبب', 'في', 'مرض', 'تهب', 'كبد', 'يرس', 'ج', 'هو:', 'هبت', 'يرس', 'تهب', 'كبد', 'ج']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عدى', 'جلي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['مرض', 'يرس', 'يصب', 'الك']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عدى', 'جنس']
# Stemmed Words: ['لند']
# Stemmed Words: ['حزب', 'برل']
# Stemmed Words: ['لند']
# Stemmed Words: ['دفن']
# Stemmed Words: ['لند']
# Stemmed Words: ['دفن', 'ارغر', 'هيلد', 'ثاتشر', 'في', 'كاتدرائية', 'سنت', 'بول', 'في', 'لند']
# Stemmed Words: ['لند']
# Stemmed Words: ['تم', 'دفن', 'ارغر', 'هيلد', 'ثاتشر', 'في', 'كنس', 'قدم', 'في', 'تشينغفورد']
# Stemmed Words: ['لند']
# Stemmed Words: ['توف', 'جكي', 'كينيد', 'في', '22', 'ايو', '1994،', 'وتم', 'دفن', 'في', 'قبر', 'قصى', 'في', 'شنط', 'عصم']
# Stemmed Words: ['لند']
# Stemmed Words: ['دفن', 'ارغر', 'هيلد', 'ثاتشر', 'في', 'دار', 'ابء', 'في', 'شيشير']
# Stemmed Words: ['لند']
# Stemmed Words: ['في', 'دار', 'سير', 'في', 'لند']
# Stemmed Words: ['لند']
# Stemmed Words: ['درس', 'باي']
# Stemmed Words: ['لند']
# Stemmed Words: ['دفن', 'ارغر', 'هيلد', 'ثاتشر', 'في', 'قبر']
# Stemmed Words: ['لند']
# Stemmed Words: ['دفن', 'ارغر', 'هيلد', 'ثاتشر', 'في', 'كنس', 'سنت', 'اري', 'دوينس', 'في', 'لند']
# Labeled data has been saved to labeled_data_XORsample_rougel_isri.json

# %%
import json

# Load data from JSON file
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# Compare the computed labels with the human-provided labels and count non-hallucinated answers
def compare_labels(data):
    correct_count = 0
    incorrect_count = 0
    non_hallucinated_human = 0  # Count of non-hallucinated human labels
    non_hallucinated_computed = 0  # Count of non-hallucinated computed labels

    # Iterate through the data to compare computed and human labels
    for question_id, item in data.items():
        human_label = item["question_label"]  # Human-provided label
        computed_label = item["computed_question_label"]  # Computed label from ROUGE scores

        # Count non-hallucinated answers for the current question
        non_hallucinated_count = 0
        for cluster in item["clusters"]:
            for answer_entry in cluster["answers"]:
                # answer_entry[2] holds the label; ensure it's in the correct format (index-based)
                if len(answer_entry) > 2 and "rouge_label" in answer_entry[2] and answer_entry[2]["rouge_label"] == "Non-Hallucinated":
                    non_hallucinated_count += 1

        # Increment the appropriate counts based on human and computed labels
        if human_label == "Non-Hallucinated":
            non_hallucinated_human += 1
        if computed_label == "Non-Hallucinated":
            non_hallucinated_computed += 1

        # Compare the labels for correctness
        if human_label == computed_label:
            correct_count += 1
        else:
            incorrect_count += 1

    # Calculate accuracy
    total_count = correct_count + incorrect_count
    accuracy = correct_count / total_count if total_count > 0 else 0

    return correct_count, incorrect_count, accuracy, non_hallucinated_human, non_hallucinated_computed

# File path to your labeled data
input_file_path = "/content/labeled_data_XORsample_rougel_isri.json"

# Load data from the file
data = load_data(input_file_path)

# Compare the labels and get the non-hallucinated counts
correct, incorrect, accuracy, non_hallucinated_human, non_hallucinated_computed = compare_labels(data)

# Print results
print(f"Correct labels: {correct}")
print(f"Incorrect labels: {incorrect}")
print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Non-Hallucinated Human Labels: {non_hallucinated_human}")
print(f"Non-Hallucinated Computed Labels: {non_hallucinated_computed}")
# Out:
# Correct labels: 81
# Incorrect labels: 19
# Accuracy: 81.00%
# Non-Hallucinated Human Labels: 19
# Non-Hallucinated Computed Labels: 4
