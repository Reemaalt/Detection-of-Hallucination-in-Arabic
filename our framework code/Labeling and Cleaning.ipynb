# %% [markdown]
# #ُTranslate Groundtruths

# %%
import json
import random
import re
import os

def is_english(text):
    #this checks if the text contains more English characters than non-English
    english_char_pattern = re.compile(r'[a-zA-Z]')
    non_english_char_pattern = re.compile(r'[^\x00-\x7F]')

    english_chars = len(english_char_pattern.findall(text))
    non_english_chars = len(non_english_char_pattern.findall(text))

    return english_chars > non_english_chars

def annotate_data():
    input_file = input("Enter your file path: ")
    output_file = input_file.replace('.json', '_modified.json')
    sample_file = input_file.replace('.json', '_sample.json')

    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    print(f"Loaded {len(data)} questions from file.")

    #create a copy for modification
    modified_data = data.copy()

    #adding placeholders for labels and handle English answers
    english_groundtruths = []
    for question_id, content in data.items():
        # Check if original answer is in English
        if "original_answer" in content and is_english(content["original_answer"]):
            english_groundtruths.append(question_id)

        #add placeholders regardless of language
        if "question_label" not in content:
            modified_data[question_id]["question_label"] = ""

        for cluster in modified_data[question_id].get("clusters", []):
            for answer_item in cluster.get("answers", []):
                if len(answer_item) == 2:  # If it's [answer, score]
                    answer_item.append("")  # Add answer label placeholder

    # Handle English original answers if any exist
    if english_groundtruths:
        print(f"\nFound {len(english_groundtruths)} questions with English original answers.")

        for question_id in english_groundtruths:
            content = modified_data[question_id]
            print(f"\nQuestion ID: {question_id}")
            print(f"Question: {content['question']}")
            print(f"Current Original Answer: {content['original_answer']}")

            new_answer = input("Enter translated original answer (or press Enter to keep current): ")
            if new_answer:
                modified_data[question_id]["original_answer"] = new_answer
                print("Answer updated")
            else:
                print("Answer unchanged")
    else:
        print("No questions with English original answers found.")

    #select 100 random questions for the sample file
    sample_keys = random.sample(list(data.keys()), 100)
    sample_data = {k: modified_data[k] for k in sample_keys}


    # Remove sampled questions from the main data (not anymore)
    for k in sample_keys:
      """
        #modified_data.pop(k)
    #save sampled data
    with open(sample_file, 'w', encoding='utf-8') as f:
        json.dump(sample_data, f, ensure_ascii=False, indent=4)
    print(f"\nSaved 100 random questions to {sample_file}")
"""
    #save modified data
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(modified_data, f, ensure_ascii=False, indent=4)
    print(f"Saved modified data to {output_file}")

# %%
annotate_data()

# %% [markdown]
# # Human Labeling for new file structure
# ###it wont remove the human labeled questions from the og file
# ###To continue labeling from where run time disconnected, add og file and labeled file, and when prompted to add the file path insert the og file path

# %%
def huamn_labeling():
    import json
    import os

    # Get input and output file paths
    sample_file = input("Enter your sample file path: ")
    output_file = input("Enter your output file path (or press Enter to use 'labeled_' prefix): ")

    if not output_file:
        file_dir = os.path.dirname(sample_file)
        file_name = os.path.basename(sample_file)
        output_file = os.path.join(file_dir, f"labeled_{file_name}")

    print("For each answer, enter 'H' for Hallucinated or 'N' for Non-Hallucinated")

    # Load sample data
    with open(sample_file, 'r', encoding='utf-8') as f:
        sample_data = json.load(f)

    # Load labeled data if it already exists
    if os.path.exists(output_file):
        with open(output_file, 'r', encoding='utf-8') as f:
            labeled_data = json.load(f)
        print(f"Resuming from existing labeled file: {output_file}")
    else:
        # Initialize labeled_data with empty labels
        labeled_data = []
        for question in sample_data:
            labeled_question = question.copy()
            new_answers = []
            for answer_group in question.get("answers", []):
                new_group = []
                for answer_text in answer_group:
                    new_group.append({
                        "text": answer_text,
                        "RougeL_label": "",
                        "human_label": ""  # Initially empty
                    })
                new_answers.append(new_group)
            labeled_question["answers"] = new_answers
            labeled_data.append(labeled_question)

    # Start labeling
    for i, question_data in enumerate(labeled_data):
        print(f"\n\nQuestion #{i + 1}")
        print(f"Question: {question_data['question']}")
        print(f"Original Answer: {question_data['original_answer']}")

        non_hallucinated_count = 0
        total_answers = 0

        for group_idx, group in enumerate(question_data["answers"]):
            for ans_idx, answer_obj in enumerate(group):
                if answer_obj.get("human_label"):  # Already labeled
                    continue

                answer_text = answer_obj["text"]
                print(f"\nGroup [{group_idx + 1}], Answer [{ans_idx + 1}]: {answer_text}", end=" ")

                while True:
                    label = input("Label (H/N): ").strip().upper()
                    if label in ['H', 'N']:
                        break
                    print("Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.")

                answer_label = "Non-Hallucinated" if label == 'N' else "Hallucinated"
                answer_obj["human_label"] = answer_label
                print(f"=> {answer_label}")

        # Count non-hallucinated answers for question label
        for group in question_data["answers"]:
            for answer_obj in group:
                if answer_obj.get("human_label") == "Non-Hallucinated":
                    non_hallucinated_count += 1
                if answer_obj.get("human_label"):
                    total_answers += 1

        if non_hallucinated_count >= 6:
            question_label = "Non-Hallucinated"
        else:
            question_label = "Hallucinated"

        question_data["computed_question_label"] = question_label
        print(f"\nQuestion Label: {question_label} (based on {non_hallucinated_count}/{total_answers} non-hallucinated answers)")

        # Save after each question
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(labeled_data, f, ensure_ascii=False, indent=4)
        print(f"Progress saved to {output_file}")

    print("\nAnswer labeling complete!")

# %%
huamn_labeling()
# Out:
# Enter your sample file path: /content/semantic_entropy_allam_arabicaqa_results.json
# Enter your output file path (or press Enter to use 'labeled_' prefix):
# For each answer, enter 'H' for Hallucinated or 'N' for Non-Hallucinated
# Resuming from existing labeled file: /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #1
# Question: ما هو مركز لعب دميترو زوزوليا في كرة القدم؟
#
# Original Answer: الوسط
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #2
# Question: مع أي نادي لعب دميترو زوزوليا في مسيرته الرياضية؟
#
# Original Answer:  لعب مع نادي فولين لوتسك
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #3
# Question: ما هي عاصمة غرب يوركشير في إنجلترا؟
# Original Answer: ليدز
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #4
# Question: ما هي المسافة التي تبعد عن مدينة يورك؟
# Original Answer: تبعد عن مدينة يورك حوالي 40 كم.
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #5
# Question: ما هو عدد سكان مدينة ليدز وفقًا لإحصاءات عام 2016؟
# Original Answer: يبلغ عدد سكانها حوالي 781,700 نسمة
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #6
# Question: ما هي الصناعات الرئيسية الموجودة في مدينة ليدز؟
# Original Answer: صناعات المنسوجات، والأثاث، والورق، والجلد، والإلكترونيات
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #7
# Question: كم عدد الموظفين في القطاع العام بمدينة ليدز؟
# Original Answer:  يعمل 108,000 موظف في القطاع العام
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #8
# Question: ما هي القطاعات الحكومية  الموجودة في مدينة ليدز؟
# Original Answer: للقطاعات الصحية العامة.
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #9
# Question: ما هي القطاعات المنظمات الموجودة في مدينة ليدز؟
# Original Answer: تشمل قطاعات العمل والمعاشات
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #10
# Question: ما هي وسائل النقل المتاحة في مدينة ليدز؟
# Original Answer: الطريق السريع 621 القصير
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #11
# Question: ما هو اسم المطار الذي يقع في مدينة ليدز؟
# Original Answer: برادفورد
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #12
# Question: ما هي الجاليات الرئيسية المتواجدة في مدينة ليدز؟
# Original Answer: جاليات جنوب آسيا
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #13
# Question: ما هو المركز الأساسي لمركز السرطان في مدينة ليدز؟
# Original Answer: بمقاطعة اليوركشير
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #14
# Question: ما هو روتشيلد وشركاه؟
#
#
# Original Answer: مصرف استثماري متعدد الجنسيات، وشركة خدمات مالية
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #15
# Question: ما هي الشركة التي تمثل مجموعة روتشيلد في القطاع المصرفي؟
#
#
# Original Answer: الفرعان الفرنسي، والبريطاني
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #16
# Question: من يمتلك مجموعة روتشيلد؟
#
#
# Original Answer: لعائلة روتشيلد
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #17
# Question: ما هي الخدمات التي يقدمها روتشيلد وشركاه؟
#
#
# Original Answer: شركة خدمات مالية
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #18
# Question: ما هو الدور البارز الذي يلعبه روتشيلد وشركاه في المجال المصرفي؟
#
#
# Original Answer: ورائد مجموعة روتشيلد المصرفية التي يستحوذ عليها الفرعان الفرنسي، والبريطاني
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #19
# Question: متى أُجريت الانتخابات العامة في باراغواي؟
#
# Original Answer:  في 30 أبريل 2023
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #20
# Question: من كان الرئيس الحالي في باراغواي قبل الانتخابات؟
#
# Original Answer: ماريو أبدو بينيتيز
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #21
# Question: من فاز في الانتخابات العامة في باراغواي؟
#
# Original Answer: مرشح حزب كولورادو سانتياغو بينيا
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #22
# Question: متى سيتولى الرئيس الجديد كولورادو سانتياغو بينيا ونائبه بيدرو مناصبهما؟
#
#
#
#
# Original Answer: في 15 أغسطس 2023
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #23
# Question: كم عدد أعضاء مجلس النواب في باراغواي؟
#
# Original Answer: 80 عضوًا
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #24
# Question: كم عدد أعضاء مجلس الشيوخ في باراغواي؟
#
# Original Answer:  45 عضوًا
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #25
# Question: من هو الفائز في انتخابات الرئاسة الأخيرة في باراغواي؟
#
# Original Answer: سانتياغو بينيا
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #26
# Question: ما هو النادي الذي تعمل فيه إيتيري توتبيريدزي كمدربة رئيسية؟
# ما هو النادي الذي تعمل فيه إيتيري توتبيريدزي كمدربة رئيسية؟
#
# Original Answer:  نادي التزلج سامبو 70 في موسكو
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #27
# Question: ما هي الإنجازات البارزة لإيتيري جورجيفنا توتبيريدزي كمدربة للتزلج؟
#
# Original Answer:  دربت العديد من المتزلجين لتحقيق النجاح في المسابقات الدولية
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #28
# Question: من هم بعض المتزلجين البارزين الذين تم تدريبهم بواسطة إيتيري توتبيريدزي؟
#
# Original Answer:  البطل الأولمبي والعالمي ألينا زاغيتوفا
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #29
# Question: ما هو عام عرض فيلم "أيام بلا حب"؟
#
#
# Original Answer: عام 1962
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #30
# Question: من هم أبطال فيلم "أيام بلا حب"؟
#
#
# Original Answer:  نادية لطفي وكمال الشناوي
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #31
# Question: من هو مخرج فيلم "أيام بلا حب"؟
#
#
# Original Answer: حسام الدين مصطفى
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #32
# Question: ما هو اسم الشخصية التي تلعب دورها نادية لطفي في الفيلم؟
#
#
# Original Answer:  (نادية) ابنة (شاكر) الثري
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #33
# Question: ما هو اسم الشخصية التي يجسدها كمال الشناوي في القصة؟
#
#
# Original Answer: (حسني) المهندس ابن الصياد الفقير
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #34
# Question: ما هي الخطة التي تقررها (نادية) و(حسني) لمواجهة الظلم؟
#
#
# Original Answer: تقرر (نادية) الهرب مع (حسني) والزواج في القاهرة
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #35
# Question:  ما هي متلازمة توريت؟
# Original Answer: هي أحد أنواع اضطرابات النمو العصبي الوراثية التي تبدأ في مرحلة الطفولة أو المراهقة
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #36
# Question: ما هو التدبير المستخدم لمتلازمة توريت؟
# Original Answer: يهدف تدبير متلازمة توريت إلى تدبير أعراضها للوصول إلى الحد الأمثل من الأداء الوظيفي عوضًا عن القضاء على هذه الأعراض
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #37
# Question:  هل يحتاج جميع المصابين بمتلازمة توريت إلى العلاج؟
# Original Answer:  لا يتطلب جميع المصابين بمتلازمة توريت العلاج
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #38
# Question: ما هي الأولويات في التدبير لمتلازمة توريت؟
# Original Answer:  يمكن تقسيم تدبير متلازمة توريت إلى علاج العرات وعلاج الحالات المرضية المرافقة
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #39
# Question: من هو توليو كيارينى؟
# Original Answer:  مونتير ومصور إيطالي
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #40
# Question: ما هو دور توليو كيارينى في السنيما المصرية؟
# Original Answer: أول من أرسى أسلوب الإضاءة الناعمة في تصوير المشاهد السينمائية في السينما المصرية
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #41
# Question: ما هي أول أعمال توليو كياريني في تصوير الأفلام؟
#
#
# Original Answer: «أنشودة الفؤاد»
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #42
# Question: من هو مخرج فيلم  "أنشودة الفؤاد"؟
# Original Answer: الإيطالي ماريو فولبي
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #43
# Question: متي صدر فيلم  "أنشودة الفؤاد"؟
# Original Answer: عام 1932
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #44
# Question: ما هي أحدث أعمال توليو كياريني في التصوير السينمائي؟
#
#
# Original Answer:  فتاة متمردة (1940)
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #45
# Question: ما هي أعماله في المونتاج؟
#
#
# Original Answer:  فيلم «أنشودة الراديو» عام 1936 فيلم «بائعة التفاح (بياعة التفاح)» عام 1939
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #46
# Question: كيف يتم تحديد اليوم التاسع والثلاثون بعد المئة في السنوات البسيطة؟
#
# Original Answer: اليوم الأربعون بعد المئة (140) من السنوات الكبيسة وفقًا للتقويم الميلادي الغربي
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #47
# Question: كم يومًا يبقى لانتهاء السنة بعد اليوم التاسع عشر من الشهر الخامس؟
#
# Original Answer: يبقى بعده 226 يوما
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #48
# Question: كم يومًا يبقى على انتهاء السنة بعد يوم 25 نوفمبر؟
#
# Original Answer: يبقى بعده 36 يومًا
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #49
# Question: ما هي مكلنبورغ فوربومرن؟
#
# Original Answer: إحدى ولايات ألمانيا الست عشرة.
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #50
# Question: في أي منطقة تقع مكلنبورغ فوربومرن؟
#
# Original Answer: في شمال ألمانيا على بحر البلطيق.
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #51
# Question: ما هي طبيعة مكلنبورغ فوربومرن؟
#
# Original Answer: سهلية بشكل عام. أعلى مرتفعات هي جبال هالبيتر (179 متراً). أهم الجزر التابعة للولاية روغن واوزيهدوم.
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #52
# Question: ما هي المدن الرئيسية في مكلنبورغ فوربومرن؟
#
# Original Answer:
# مدينة روستوك الساحلية
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #53
# Question: ما هي مدينة روستوك الساحلية ؟
# Original Answer: هي أكبر مدن ولاية مكلنبورغ فوربومرن (198.303 نسمة في عام 2003
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #54
# Question: كم عدد سكان مدينة روستوك الساحلية؟
# Original Answer: 198.303
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #55
# Question: ما هي الدوائر الإدارية في مكلنبورغ فوربومرن؟
#
# Original Answer: تقسم الولاية إلى 12 دائرة قروية و 6 دوائر مدنية
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #56
# Question: ما هي الأماكن السياحية الرئيسية في مكلنبورغ فوربومرن؟
#
#
#
#
# Original Answer: في المدن والمنجعات الساحلية
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #57
# Question: ما هو أحد أهم موانئ ألمانيا ؟
# Original Answer:
# ميناء روستوك
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #58
# Question: ما هو مركز اللاعب عمر سيديبيه؟
# Original Answer: الوسط
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #59
# Question: متي ولد عمر سيديبيه؟
# Original Answer:  25 مارس 1990
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #60
# Question: في أي منتخب لعب عمر سيديبيه؟
# Original Answer: منتخب مالي لكرة القدم
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #61
# Question: ما هي النوادي التي لعب معها عمر سيديبيه؟
# Original Answer: الملعب المالي وريال باماكو وفيتا كلوب ونادي الهلال.
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #62
# Question: من هو عمر سيديبيه؟
# Original Answer:  لاعب كرة قدم مالي
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #63
# Question: من هو إدوارد وديع سعيد؟
# Original Answer: مُنظر أدبي فلسطيني-أمريكي. يعد أحد أهم المثقفين الفلسطينيين وحتى العرب في القرن العشرين
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #64
# Question:
# ما هي أهمية إدوارد سعيد في العالم العربي والغربي؟
# Original Answer: يعتبره واحداً من أهم عشرة مفكرين تأثيراً في القرن العشرين
#
# Question Label: Non-Hallucinated (based on 8/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #65
# Question: ما وظيفة  إدوارد سعيد ؟
# Original Answer: كان أستاذاً جامعياً للنقد الأدبي والأدب المقارن في جامعة كولومبيا في نيويورك ومن الشخصيات المؤسسة لدراسات ما بعد الاستعمارية
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #66
# Question: ما هو دور إدوارد سعيد في دراسات ما بعد الاستعمارية؟
# Original Answer: مدافعاً عن حقوق الإنسان للشعب الفلسطيني
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #67
# Question: ما هي الأفكار التي قدمها إدوارد سعيد في كتابه "الاستشراق"؟
# Original Answer: عن دراسات الاستشراق الغربية المختصة بدراسة الشرق والشرقيين. قامت أفكاره على تبيان وتأكيد ارتباط الدراسات
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #68
# Question: كيف وصف روبرت فيسك إدوارد سعيد؟
# Original Answer: أنه أكثر صوتٍ فعالٍ في الدفاع عن القضية الفلسطينية
#
# Question Label: Non-Hallucinated (based on 6/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #69
# Question: متى نشر ادوارد سعيد كتابه "الاستشراق"؟
# Original Answer: سنة 1978
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #70
# Question: متى ولد إدوارد سعيد؟
# Original Answer: في الأول من نوفمبر/تشرين الثاني 1935.
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #71
# Question: اين  ولد إدوارد سعيد؟
# Original Answer: في القدس
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #72
# Question: ما الذي اثبته كتاب «الاستشراق» ومؤلفاته اللاحقة؟
# Original Answer: في الأدب والنقد الأدبي فضلاً عن تأثيرها في العلوم الإنسانية، وقد أثر في دراسة الشرق الأوسط
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #73
# Question: ما الفترة التي كان إدوارد سعيد عضواً مستقلاً في المجلس الوطني الفلسطيني؟
# Original Answer: الفترة (77-1991
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #74
# Question: متى من المتوقع حدوث كسوف كلي للشمس عام 2100؟
#
# Original Answer:  4 سبتمبر 2100
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #75
# Question: ما هو تعريف الكسوف الشمسي؟
#
#
# Original Answer: يحدث كسوف الشمس عندما يمر القمر بين الأرض والشمس، وبالتالي يحجب صورة الشمس كليًا أو جزئيًا عن مشاهد على الأرض
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #76
# Question: ما هو الكسوف الكلي للشمس؟
# Original Answer:  يكون القطر الظاهري للقمر أكبر من قطر الشمس، مما يحجب كل ضوء الشمس المباشر، ويحول النهار إلى ظلام
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #77
# Question: ما هي السلسلة التي ينتمي اليها هذا الكسوف؟
# Original Answer: الفصل
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #78
# Question: متي يتكرر الخسوف في سلسلة الفصل من الكسوف الشمسي؟
# Original Answer:  كل 177 يومًا تقريبًا و4 ساعات (فصل) في العقد المتناوبة من مدار القمر
#
# Question Label: Hallucinated (based on 2/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #79
# Question: كم مرة تم تدمير كاتانيا في تاريخها بسبب الثورات البركانية والزلازل؟
#
# Original Answer: سبع مرات
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #80
# Question: ما هي أكبر ثورة بركانية وأعنف زلزال حدث في كاتانيا؟
#
# Original Answer: الثورات البركانية (أكبرها سنة 1669) والزلازل (أعنفها عامي 1169 و 1693).
#
# Question Label: Hallucinated (based on 3/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #81
# Question: متى تم إدراج وسط كاتانيا التاريخي ضمن مواقع التراث العالمي؟
#
# Original Answer: في عام 2002.
#
# Question Label: Non-Hallucinated (based on 8/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #82
# Question: ما هي الجغرافيا الطبيعية لكاتانيا؟
#
# Original Answer:
# تقع على الساحل الشرقي لها في متنصف المسافة بين ميسينا شمالا وسيراقوسة جنوبا، مطلةً على البحر
#
# Question Label: Non-Hallucinated (based on 7/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #83
# Question: ما هو الموقع الجغرافي لكاتانيا؟
#
# Original Answer: يمر بها نهر أمينانو وساحلها صخري شمالاً ورملي جنوباً، يقع بالقرب منها بركان إتنا.
#
# Group [1], Answer [1]: كاتانيا هي مدينة في صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [2]: كاتانيا هي مدينة في شرق صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [3]: كاتانيا هي مدينة في صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [4]: كاتانيا هي مدينة في شرق صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [5]: كاتانيا هي مدينة في شرق صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [6]: كاتانيا هي مدينة في شرق صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [7]: كاتانيا هي مدينة في صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [8]: كاتانيا تقع في شرق صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [9]: كاتانيا تقع في شرق صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [10]: كاتانيا هي مدينة في صقلية، إيطاليا Label (H/N): n
# => Non-Hallucinated
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #84
# Question: في أي مركز يلعب ميغيل أنخيل لييس في كرة القدم؟
#
# Original Answer: في مركز حراسة المرمى
#
# Group [1], Answer [1]: يلعب ميغيل أنخيل لييس كوسط ميدان Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: يلعب ميغيل أنخيل لييس في مركز الوسط الأيمن في كرة القدم Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [2]: يلعب ميغيل أنخيل لييس كمدافع مركزي في كرة القدم Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [3]: يلعب ميغيل أنخيل لييس في مركز لاعب وسط مركزي في كرة القدم Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: يلعب ميغيل أنخيل لييس عادةً كمدافع مركزي Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: يلعب ميغيل أنخيل لييس كمهاجم في كرة القدم Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [2]: يلعب ميغيل أنخيل لييس كمهاجم في كرة القدم Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [3]: يلعب ميغيل أنخيل لييس كمهاجم في كرة القدم Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: يلعب ميغيل أنخيل لييس في مركز الوسط الأيسر في كرة القدم Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: ميغيل أنخيل لييس يلعب كجناح أيسر في كرة القدم Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #85
# Question: ما هي الأندية التي لعب فيها ميغيل أنخيل لييس؟
#
# Original Answer: مع كولو-كولو ونادي أونيفرسيداد كاتوليك
#
# Group [1], Answer [1]: لعب ميغيل أنخيل لييس لأندية مثل خيمناستيك تاراغونا وريال مورسيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [2]: لعب ميغيل أنخيل لييس لأندية مثل ريال مورسيا، ريال بيتيس، إشبيلية، وريال مدريد Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: لعب ميغيل أنخيل لييس لأندية مثل ريال مدريد، أتلتيكو مدريد، إشبيلية، وريال سوسيداد Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [2]: لعب ميغيل أنخيل لييس لأندية مثل أتلتيكو مدريد وريال سوسيداد Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [3]: لعب ميغيل أنخيل لييس لأندية مثل ريال مدريد وسيفيليا وأتلتيكو مدريد Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: تألّق لاعب كرة القدم الإسباني ميغيل أنخيل لييس في صفوف أندية ريال مدريد، أتلتيكو مدريد، ديبورتيفو لا كورونيا، وريال سرقسطة Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: لعب ميغيل أنخيل لييس لأندية مثل ريال مدريد ويوفنتوس وبرشلونة ومانشستر يونايتد وإنتر ميلان Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: لعب ميغيل أنخيل لييس لأندية مثل ريال مدريد، راسينغ سانتاندير، إشبيلية، وريال سوسيداد Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: لعب ميغيل أنخيل لييس لأندية مثل ريال مورسيا، مورسيا، وريال بيتيس Label (H/N): h
# => Hallucinated
#
# Group [7], Answer [1]: لعب ميغيل أنخيل لييس لأندية مثل ريال مدريد، راسينغ سانتاندير، وليفانتي Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #86
# Question: ما هو ميغيل أنخيل لييس؟
#
# Original Answer: هو لاعب كرة قدم ومدرب كرة قدم تشيلي وأرجنتيني في مركز حراسة المرمى
#
# Group [1], Answer [1]: ميغيل أنخيل لييس كان مهندس معماري إسباني Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: مغامر إسباني Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: كان عالم اجتماع إسباني Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: هو متسلق جبال إسباني Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: أنا عالم حاسوب إسباني Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: ميغيل أنخيل لييس (1869-1938) كان مهندسًا إسبانيًا ومخترعًا للقطار الكهربائي Label (H/N): h
# => Hallucinated
#
# Group [7], Answer [1]: كان مهندسًا إسبانيًا Label (H/N): h
# => Hallucinated
#
# Group [8], Answer [1]: هو كاتب إسباني Label (H/N): h
# => Hallucinated
#
# Group [9], Answer [1]: ميغيل أنخيل لييس هو كاتب إسباني Label (H/N): h
# => Hallucinated
#
# Group [10], Answer [1]: ميغيل أنخيل لييس (1908-1993) كان مهندسًا إسبانيًا وعالمًا في علم الأحياء الدقيقة Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #87
# Question: متى وُلد ميغيل أنخيل لييس؟
#
# Original Answer: في 5 فبراير 1952
#
# Group [1], Answer [1]: ميغيل أنخيل لييس وُلد في 15 أبريل 1880 Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: وُلد ميغيل أنخيل لييس في 21 يونيو 1955 Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: وُلد ميغيل أنخيل لييس في 17 مارس 1890 Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: وُلد ميغيل أنخيل لييس في 21 يناير 1975 Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: وُلد ميغيل أنخيل لييس في 19 يونيو 1975 Label (H/N):
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: وُلد ميغيل أنخيل لييس في 28 مارس 1973 Label (H/N): h
# => Hallucinated
#
# Group [7], Answer [1]: وُلد ميغيل أنخيل لييس في 19 أبريل 1975 Label (H/N): h
# => Hallucinated
#
# Group [8], Answer [1]: وُلد ميغيل أنخيل لييس في 15 أبريل 1970 Label (H/N): h
# => Hallucinated
#
# Group [9], Answer [1]: وُلد ميغيل أنخيل لييس في 28 فبراير 1836 Label (H/N): h
# => Hallucinated
#
# Group [10], Answer [1]: وُلد ميغيل أنخيل لييس في 27 أكتوبر 1975 Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #88
# Question: اين وُلد ميغيل أنخيل لييس؟
#
# Original Answer: في بوينس آيرس في الأرجنتين
#
# Group [1], Answer [1]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [2]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [3]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [4]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [5]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [6]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [7]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [8]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [9]: وُلد ميغيل أنخيل لييس في إسبانيا Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: مدريد، إسبانيا Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #89
# Question: متى وقع إطلاق النار في مدرسة ساندي هوك الابتدائية؟
#
#
# Original Answer: وقع إطلاق النار على مدرسة ساندي هوك الابتدائية في 14 ديسمبر 2012
#
# Group [1], Answer [1]: في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [2]: في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [3]: وقع إطلاق النار في مدرسة ساندي هوك الابتدائية في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [4]: 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [5]: في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [6]: وقع إطلاق النار في مدرسة ساندي هوك الابتدائية في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [7]: وقعت حادثة إطلاق النار في مدرسة ساندي هوك الابتدائية في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [8]: وقع إطلاق النار في مدرسة ساندي هوك الابتدائية في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [9]: في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [10]: في 14 ديسمبر 2012 Label (H/N): n
# => Non-Hallucinated
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #90
# Question: من كان الجاني الذي قام بإطلاق النار في مدرسة ساندي هوك؟
#
#
# Original Answer:  أطلق الجاني، آدم لانزا
#
# Group [1], Answer [1]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [2]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [3]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [4]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [5]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [6]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [7]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [8]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [9]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [10]: آدم لانزا Label (H/N): n
# => Non-Hallucinated
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #91
# Question: كم عدد الأشخاص الذين قتلهم الجاني في هذا الحادث؟
#
#
# Original Answer: قبل أن يقتل 20 طالبًا وستة موظفين في مدرسة ساندي هوك الابتدائية
#
# Group [1], Answer [1]: قتل الجاني ثلاثة أشخاص في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: قتل الجاني 13 شخصًا في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: قتل الجاني 10 أشخاص في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [2]: قتل الجاني 10 أشخاص في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [3]: قتل الجاني 10 أشخاص في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: قتل الجاني 17 شخصًا في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [2]: قتل الجاني 17 شخصاً في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [3]: قتل الجاني 17 شخصاً في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: الجاني قتل 12 شخصاً في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: قتل الجاني 5 أشخاص في هذا الحادث Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #92
# Question: ما هي موقع بحيرة شالا وأي دول تقع على حدودها؟
#
# Original Answer: ،هي بحيرة فوهية تمتد على الحدود بين كينيا وتنزانيا.
#
# Group [1], Answer [1]: بحيرة شالا هي بحيرة مالحة تقع بين الجزائر وموريتانيا Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: بحيرة شالا تقع في شمال شرق الأرجنتين وتحدها بوليفيا وباراغواي Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: تقع بحيرة شالا في منطقة الجوف في المملكة العربية السعودية، وتحدها الأردن من الشرق وسوريا من الغرب Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: تقع بحيرة شالا في محافظة العلا في المملكة العربية السعودية، وتحدها الأردن من الشمال الشرقي Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: بحيرة شالا تقع في منطقة الجوف في المملكة العربية السعودية، وتحدها الأردن من الشمال Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [2]: تقع بحيرة شالا في منطقة الجوف في المملكة العربية السعودية، وتحدها الأردن من الشمال والعراق من الشرق Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: تقع بحيرة شالا في منطقة الجوف في المملكة العربية السعودية، وتحدها الأردن من الغرب والعراق من الشرق Label (H/N): h
# => Hallucinated
#
# Group [7], Answer [1]: بحيرة شالا تقع في صحراء أتاكاما في تشيلي، وتحدها بيرو من الشرق Label (H/N): h
# => Hallucinated
#
# Group [8], Answer [1]: تقع بحيرة شالا في مقاطعة كرمانشاه في غرب إيران، وتحدها تركيا والعراق Label (H/N): h
# => Hallucinated
#
# Group [9], Answer [1]: تقع بحيرة شالا في مقاطعة فارس في إيران، وتحدها تركيا من الشمال والعراق من الغرب Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #93
# Question: ما هو متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا؟
#
# Original Answer:  ما يقرب من 80 في المائة من تدفق البحيرة من المياه الجوفية والمُشتقة في الغالب
#
# Group [1], Answer [1]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 250 ملم Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 200 ملم Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [2]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 200 ملم Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [3]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 200 ملم Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [4]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 200 ملم Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [5]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 200 ملم Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا يبلغ حوالي 280 ملم Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 210 ملم Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 100 ملم Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [2]: يبلغ متوسط سقوط الأمطار السنوي في منطقة بحيرة شالا حوالي 100 ملم Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #94
# Question: من أين تأتي معظم مياه بحيرة شالا؟
#
# Original Answer:  من تدفق البحيرة من المياه الجوفية والمُشتقة في الغالب من سقوط الأمطار في منطقة الغابات الجبلية
#
# Group [1], Answer [1]: مياه بحيرة شالا تأتي بشكل رئيسي من نهر شالا Label (H/N): n
# => Non-Hallucinated
#
# Group [2], Answer [1]: معظم مياه بحيرة شالا تأتي من نهر الأردن Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [2]: معظم مياه بحيرة شالا تأتي من نهر الأردن Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [3]: معظم مياه بحيرة شالا تأتي من نهر الأردن Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [4]: معظم مياه بحيرة شالا تأتي من نهر الأردن Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [5]: معظم مياه بحيرة شالا تأتي من نهر الأردن Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: معظم مياه بحيرة شالا تأتي من نهر النيل Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [2]: تأتي معظم مياه بحيرة شالا من نهر النيل Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [3]: معظم مياه بحيرة شالا تأتي من نهر النيل Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [4]: معظم مياه بحيرة شالا تأتي من نهر النيل Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 1/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #95
# Question: كيف يمكن وصف الأسماك الموجودة في بحيرة شالا؟
#
# Original Answer: عدد أنواع البلطي
#
# Group [1], Answer [1]: الأسماك الموجودة في بحيرة شالا تتميز بكونها جميعها من الأنواع العذبة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [2]: الأسماك الموجودة في بحيرة شالا هي نوع من الأسماك التي تعيش في المياه العذبة، وتتميز بحجمها المتوسط ولونها الفضي Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [3]: الأسماك الموجودة في بحيرة شالا هي نوع من أنواع الأسماك التي تعيش في المياه العذبة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [4]: الأسماك في بحيرة شالا تتميز بتنوعها الكبير Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [5]: تتميز أسماك بحيرة شالا بكونها أسماك مياه عذبة ومفترسة Label (H/N): ر
# Invalid input. Enter 'H' for Hallucinated or 'N' for Non-Hallucinated.
# Label (H/N): n
# => Non-Hallucinated
#
# Group [2], Answer [1]: الأسماك في بحيرة شالا تتميز بكونها من نوع "Gambusia affinis"، وهي أسماك قزمة Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: الأسماك في بحيرة شالا هي من نوع السلمون Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: الأسماك في بحيرة شالا كبيرة وملونة Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: الأسماك الموجودة في بحيرة شالا هي أساساً من نوع السمك المرقط Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: الأسماك الموجودة في بحيرة شالا هي في الأساس من نوع السيكليد Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 4/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #96
# Question: ما هي الحادثة التي وقعت في بحيرة شالا عام 2002 وماذا قالت الشهود عنها؟
#
#
#
#
# Original Answer:  قُتلت امرأة بريطانية تبلغ من العمر 18 عامًا في عام 2002 على يد تمساح نيلي صغير نسبيًا أثناء السباحة ليلًا في البحيرة.
#
# Group [1], Answer [1]: في 12 سبتمبر 2002، تحطمت طائرة نقل عسكرية من طراز سي-130 هيركوليس تابعة للقوات الجوية الملكية المغربية في بحيرة شالا، وقالت الشهود إنها كانت تحمل 28 شخصاً على متنها Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: في عام 2002، اختفت قارب شالا، مما أسفر عن مقتل 15 شخصًا Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: وقع انفجار في بحيرة شالا عام 2002، حيث قال الشهود إنه كان يشبه صوت إطلاق النار Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [2]: وقع انفجار في بحيرة شالا عام 2002، وأفادت الشهود بأن الحادث كان نتيجة انفجار صهريج وقود Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [3]: في 19 سبتمبر 2002، شهدت بحيرة شالا في المكسيك حادثة اختفاء الطائرة الخاصة "إمبيريال إيروايز" التي كانت تقل 10 ركاب وطاقم مكون من شخصين، حيث أفاد الشهود برؤية حريق كبير في السماء ثم اختفاء الطائرة فجأة دون أي أثر Label (H/N): h
# => Hallucinated
#
# Group [4], Answer [1]: وقع انفجار في بحيرة شالا عام 2002، حيث تم العثور على سيارة مفخخة في موقف سيارات مصنع للأسمدة الكيماوية، وذكرت الشهود أنهم شاهدوا أشخاصًا يهربون من المكان Label (H/N): h
# => Hallucinated
#
# Group [5], Answer [1]: في 12 أبريل 2002، وقعت حادثة بحيرة شالا حيث تم العثور على حطام الطائرة في قاع البحيرة، وأفاد الشهود برؤية طائرة تقلع من البحيرة قبل الحادث Label (H/N): h
# => Hallucinated
#
# Group [6], Answer [1]: في 13 أبريل 2002، سقطت طائرة تدريب عسكرية سعودية من طراز هوك في بحيرة شالا بالقرب من قاعدة الملك عبد العزيز الجوية في الظهران Label (H/N): h
# => Hallucinated
#
# Group [7], Answer [1]: في عام 2002، وقعت حادثة اختفاء 56 شخصاً في بحيرة شالا في الأرجنتين، وأفادت الشهود برؤية قارب يختفي فجأة Label (H/N): h
# => Hallucinated
#
# Group [8], Answer [1]: حادثة بحيرة شالا عام 2002 وقعت عندما هاجمت القوات الإسرائيلية قاربين يحملان نشطاء فلسطينيين، مما أسفر عن مقتل تسعة أشخاص Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #97
# Question: ما هي تدمر؟
#
# Original Answer: هي مدينة أثريَّة ذات أهمية تاريخية كبيرة،
#
# Group [1], Answer [1]: تدمر هي مدينة أثرية قديمة تقع في سوريا، وتشتهر بعمارتها الرومانية الفريدة وآثارها المحفوظة بشكل جيد Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [2]: تدمر هي مدينة أثرية في سوريا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [3]: مدينة أثرية في سوريا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [4]: مدينة تاريخية في سوريا، مشهورة بعمارتها الرومانية القديمة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [5]: تدمر هي مدينة أثرية قديمة تقع في سوريا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [6]: تدمر هي مدينة أثرية تقع في سوريا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [7]: تدمر هي مدينة أثرية قديمة تقع في سوريا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [8]: تدمر هي مدينة تاريخية قديمة في سوريا Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [9]: مدينة تدمر الأثرية هي مدينة سورية تقع في وسط البلاد، وتشتهر بآثارها الرومانية القديمة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [10]: تدمر هي مدينة تاريخية في سوريا Label (H/N): n
# => Non-Hallucinated
#
# Question Label: Non-Hallucinated (based on 10/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #98
# Question: في أي محافظة تقع تدمر؟
#
# Original Answer: محافظة حمص
#
# Group [1], Answer [1]: محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [2]: محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [3]: محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [4]: تدمر تقع في محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [5]: تدمر تقع في محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [6]: تدمر تقع في محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [7]: محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [8]: محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [9]: محافظة حمص Label (H/N): n
# => Non-Hallucinated
#
# Group [2], Answer [1]: محافظة تدمر Label (H/N): h
# => Hallucinated
#
# Question Label: Non-Hallucinated (based on 9/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #99
# Question: ما هو تاريخ تدمر القديم؟
#
# Original Answer: إلى العصر الحجري الحديث
#
# Group [1], Answer [1]: تقع تدمر في محافظة حمص في سوريا، وكانت مركزًا تجاريًا رئيسيًا بين الشرق والغرب، وكانت تحت حكم الإمبراطورية الرومانية من 106م إلى 273م Label (H/N): h
# => Hallucinated
#
# Group [1], Answer [2]: كانت تدمر مدينة قديمة في سوريا Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [1]: كانت تدمر مدينة قديمة في سوريا ازدهرت من القرن الأول قبل الميلاد حتى القرن السابع الميلادي Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [2]: كانت تدمر مدينة قديمة في سوريا ازدهرت من القرن الأول قبل الميلاد حتى القرن السابع الميلادي Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [3]: كانت تدمر مدينة قديمة في سوريا، ازدهرت من القرن الأول قبل الميلاد حتى القرن السابع الميلادي Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [4]: كانت تدمر مدينة قديمة في سوريا ازدهرت من القرن الأول قبل الميلاد حتى القرن السابع الميلادي Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [5]: كانت تدمر القديمة مدينة قديمة في سوريا Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [6]: كانت تدمر مدينة قديمة في سوريا ازدهرت من القرن الأول قبل الميلاد حتى القرن السابع الميلادي Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [7]: كانت تدمر مدينة قديمة في سوريا ازدهرت من القرن الأول قبل الميلاد حتى القرن السابع الميلادي Label (H/N): h
# => Hallucinated
#
# Group [2], Answer [8]: كانت تدمر مدينة قديمة في سوريا، ازدهرت من القرن الأول قبل الميلاد حتى القرن السابع الميلادي Label (H/N): h
# => Hallucinated
#
# Question Label: Hallucinated (based on 0/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #100
# Question: كيف كانت تدمر مدينة كبيرة الثراء؟
#
# Original Answer: الذي كان يقعُ عند نقطة تقاطع عِدَّة طرق تجارية في العالم القديم.
#
# Group [1], Answer [1]: كانت تدمر مدينة كبيرة الثراء بسبب موقعها الاستراتيجي على طرق التجارة التي ربطت البحر الأبيض المتوسط بالعالمين الفارسي والعربي Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [2]: كانت تدمر مدينة كبيرة الثراء بفضل موقعها الاستراتيجي والتجارة المزدهرة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [3]: كانت تدمر مدينة كبيرة الثراء بسبب موقعها الاستراتيجي على طرق التجارة التي ربطت البحر الأبيض المتوسط بعالم الشرق Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [4]: كانت تدمر مدينة كبيرة الثراء بسبب موقعها الاستراتيجي على طرق التجارة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [5]: كانت تدمر مدينة كبيرة الثراء بفضل موقعها الاستراتيجي على طرق التجارة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [6]: كانت تدمر مدينة كبيرة الثراء بسبب موقعها الاستراتيجي على طرق التجارة الرئيسية Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [7]: كانت تدمر مدينة كبيرة الثراء بسبب موقعها الاستراتيجي على طرق التجارة Label (H/N): n
# => Non-Hallucinated
#
# Group [1], Answer [8]: كانت تدمر مدينة كبيرة الثراء بسبب موقعها الاستراتيجي على طرق التجارة Label (H/N): n
# => Non-Hallucinated
#
# Group [2], Answer [1]: كانت تدمر مدينة كبيرة الثراء بسبب موقعها الاستراتيجي على طريق الحرير والتجارة بين الشرق والغرب Label (H/N): h
# => Hallucinated
#
# Group [3], Answer [1]: ازدهرت تدمر كمدينة كبيرة الثراء من خلال التجارة، وخاصة في التوابل والحرير والبورسلين Label (H/N): h
# => Hallucinated
#
# Question Label: Non-Hallucinated (based on 8/10 non-hallucinated answers)
# Progress saved to /content/labeled_semantic_entropy_allam_arabicaqa_results.json
#
#
# Question #101
# Question: ما هي طريق الحرير؟
#
# Original Answer: هو أحد أهم الطرق التجارية القديمة (والذي امتدَّ من الصين غرباً إلى أوروبا شرقاً)،
#
# Group [1], Answer [1]: طريق الحرير هو شبكة من طرق التجارة التي ربطت الصين والهند والشرق الأوسط وأوروبا
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-048bd1336828> in <cell line: 0>()
# ----> 1 huamn_labeling()
#
# <ipython-input-3-cd5bab823119> in huamn_labeling()
#      59
#      60                 while True:
# ---> 61                     label = input("Label (H/N): ").strip().upper()
#      62                     if label in ['H', 'N']:
#      63                         break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
