# %% [markdown]
# <a href="https://colab.research.google.com/github/Reemaalt/Detection-of-Hallucination-in-Arabic/blob/main/RougeL_Labeling_of_Answers_XOR_Farasa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##QA pairs generated using llama8b on xquad

# %%
# !pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)

# %% [markdown]
# #Test RougeL

# %%
from huggingface_hub import login
login()

# %%
pip install farasapy
# Out:
# Requirement already satisfied: farasapy in /usr/local/lib/python3.11/dist-packages (0.0.14)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from farasapy) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from farasapy) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->farasapy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->farasapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->farasapy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->farasapy) (2025.1.31)

# %%
from transformers import AutoTokenizer
from rouge_score import rouge_scorer
from farasa.stemmer import FarasaStemmer

# Load tokenizer
model_name = "core42/jais-13b"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Initialize Farasa Stemmer
stemmer = FarasaStemmer()

# Define a custom tokenizer class that applies both tokenization and stemming
class CustomTokenizer:
    def __init__(self, tokenizer, stemmer):
        self.tokenizer = tokenizer
        self.stemmer = stemmer

    def tokenize(self, text):
        words = text.split()  # Split into words first
        stemmed_words = [self.stemmer.stem(word) for word in words]  # Apply stemming
        print("Stemmed Words:", stemmed_words)  # Debugging line to check the stemmed words
        return self.tokenizer.tokenize(" ".join(stemmed_words))  # Tokenize the stemmed text

# Create an instance of our custom tokenizer
custom_tokenizer = CustomTokenizer(tokenizer, stemmer)

# Create the ROUGE scorer with our custom tokenizer
scorer = rouge_scorer.RougeScorer(['rougeL'], tokenizer=custom_tokenizer)

# Example strings
pred_str = 'السلام عليكم كيف حالك'
label_str = 'السلام عليكم صديقي كيف حالك'

# Compute ROUGE scores
scores = scorer.score(label_str, pred_str)

# Print the stemmed words to check if stemming occurs
for key, value in scores.items():
    print(f'{key}: {value}')
# Out:
# Stemmed Words: ['سلام', 'على', 'صديق', 'كيف', 'حال']
# Stemmed Words: ['سلام', 'على', 'كيف', 'حال']
# rougeL: Score(precision=1.0, recall=0.8, fmeasure=0.888888888888889)

# %% [markdown]
# #Use RougeL on data

# %%
# Load data from JSON file
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# Save labeled data to a new JSON file
def save_labels(output_data, output_file_path):
    with open(output_file_path, 'w', encoding='utf-8') as file:
        json.dump(output_data, file, ensure_ascii=False, indent=4)

# Process hallucination detection efficiently
def check_hallucination(data, rouge_threshold=0.3, min_non_hallucinated=6):

    updated_data = {}

    for question_id, item in data.items():
        original_answer = item["original_answer"].strip()  # Ground truth
        non_hallucinated_count = 0


        # Process each cluster
        for cluster in item["clusters"]:
            first_answer_processed = False  # Track first answer in the cluster
            cluster_label = "Hallucinated"  # Default label for the cluster
            rouge_l_f1 = None  # Default F1 score

            for answer_entry in cluster["answers"]:
                answer = answer_entry[0].strip()  # Extract answer text

                if not first_answer_processed and answer:
                    # Compute ROUGE-L score only for the first answer in the cluster
                    scores = scorer.score(original_answer, answer)
                    rouge_l_f1 = scores["rougeL"].fmeasure

                    # Determine hallucination label based on ROUGE score
                    cluster_label = "Non-Hallucinated" if rouge_l_f1 >= rouge_threshold else "Hallucinated"
                    first_answer_processed = True  # Mark first answer as processed

                # Append ROUGE details for all answers in the cluster (inherit the label)
                answer_entry.append({
                    "rouge_l_f1": round(rouge_l_f1, 2) if rouge_l_f1 is not None else "Inherited",
                    "rouge_label": cluster_label
                })

                # Count non-hallucinated answers
                if cluster_label == "Non-Hallucinated":
                    non_hallucinated_count += 1

        # Final question-level labeling
        computed_question_label = "Non-Hallucinated" if non_hallucinated_count >= min_non_hallucinated else "Hallucinated"

        # Store updated data while preserving structure
        updated_data[question_id] = {
            **item,
            "computed_question_label": computed_question_label
        }

    return updated_data

# File paths
input_file_path = "/content/human_sample_xor_tydiqa.json"
output_file_path = "labeled_data_XORsample_rougel_farasa.json"

# Load data
data = load_data(input_file_path)

# Process and add labels
updated_data = check_hallucination(data)

# Save updated data
save_labels(updated_data, output_file_path)

print(f"Labeled data has been saved to {output_file_path}")
# Out:
# Stemmed Words: ['329']
# Stemmed Words: ['329', 'مقعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'مقعد']
# Stemmed Words: ['329']
# Stemmed Words: ['328', 'مقعد']
# Stemmed Words: ['329']
# Stemmed Words: ['1925']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['طراز', 'كلاسيكي']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['طر']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['سمى']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['طراز', 'بار']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['طراز', 'معماري', 'روماني', 'سمى', 'طراز', 'كلاسيكي']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['سمى', 'طراز', 'معماري', 'روماني', '" طراز', 'باروكي "']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['هو', 'طراز', 'معمار', 'اعتمد', 'على', 'استخدام', 'مبنى', 'كلاسيكي', 'يوناني']
# Stemmed Words: ['عمارة', 'قوطي']
# Stemmed Words: ['إمبراطوري']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['توفى', 'فلاديمير', 'لين', 'في', '21', 'يناير', '1924', 'بعد', 'أن', 'تعرض', 'عدوى', 'تسممية', 'نات']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['تم', 'اغتيال', 'فلاديمير', 'لين', 'في', '21', 'يناير', '1924 ،', 'بعد', 'أن', 'تم', 'إصابة', 'جرح', 'في', 'رأس', 'من', 'قبل', 'ليونيد', 'نيكولايف ،', 'هو', 'ضابط', 'من', 'شرطة', 'سوفيتي ،', 'في', 'موسكو ،', 'روسيا']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['فلاديمير', 'لين', 'هو', 'مؤسس', 'اتحاد', 'سوفيتي ،', 'ولد', 'في', '22', 'أبريل', '1870', 'في', 'سيمبيرسك ،', 'روسيا']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['توفى', 'فلاديمير', 'لين', 'في', '21', 'يناير', '1924']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['توفى', 'فلاديمير', 'لين', 'في', '21', 'يناير', '1924', 'سبب', 'سكتة', 'دماغ']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['توفى', 'فلاديمير', 'لين', 'في', '21', 'يناير', '1924', 'سبب', 'هاجم', 'من', 'قبل', 'أحد', 'مرافق ،', 'حيث', 'أطلق', 'على', 'نار', 'في', 'رأس']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['توفى', 'فلاديمير', 'لين', 'عام', '1924', 'سبب', 'نزيف', 'في', 'دماغ', 'نتيجة', 'تفجر', 'عدوى', 'في', 'دماغ', 'نتيجة', 'تشوه', 'في', 'دماغ', 'نتيجة', 'لاص']
# Stemmed Words: ['اغتيال']
# Stemmed Words: ['توفى', 'فلاديمير', 'لين', 'في', '21', 'يناير', '1924', 'نتيجة', 'مرض', 'سرطان']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['كان', 'مهمة', 'مسبار', 'ويند', 'فضائي', 'هي', 'دراسة', 'شعاع', 'كوني', 'راديو', 'نجمي']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['دراسة', 'تكوين', 'كوكب']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['12', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['20', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['في', '11', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['تم', 'إطلاق', 'مسبار', 'ويند', 'فضائي', 'في', '12', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['24', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['15', 'ديسمبر', '2020']
# Stemmed Words: ['1', 'تشرين', 'ثاني', 'عام', '1994']
# Stemmed Words: ['تم', 'إرسال', 'بيان', 'من', 'مسبار', 'وي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم', 'حكم', 'أقلية', 'في', 'نظام', 'ديكتاتوري']
# Stemmed Words: ['نعم']
# Stemmed Words: ['لا']
# Stemmed Words: ['نعم']
# Stemmed Words: ['هناك', 'عدة', 'سبب', 'قد', 'أدى', 'إلى', 'ان']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['استعمال', 'جهاز', 'ضغط', 'دم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['لا ،', 'أن', 'دستور', 'لا', 'اعترف', 'اقلي ،', 'انحصر', 'حكم', 'في', 'يد', 'رئيس']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'حكم', 'أقلية', 'في', 'نظام']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['صدر', 'ألبوم', '" ذو', 'مونكيز "', 'أول', 'مرة', 'في', 'مملكة', 'متحد']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['أول', 'ألبوم', 'فرقة', 'مونكيز', 'هو', 'ألبوم', '( I', 'Am', 'Me )', 'الذي', 'صدر', 'في', '2007']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['أصدر', 'فرقة', 'مونكيز', '11', 'ألبوم']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['أول', 'ألبوم', 'فرقة', 'مونكيز', 'هو', 'The', 'Monkees', '( 1966 )']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['أول', 'ألبوم', 'فرقة', 'مونكيز', 'هو', '" The', 'Monkees " ،', 'الذي', 'صدر', 'في', '10', 'يونيو', '1966']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['ألبوم', 'أول', 'هو', 'The', 'Monkees', '( 1966 )']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['Le', 'premier', 'album', 'des', 'Monkees', 'est', '" The', 'Monkees "']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['The', 'Star']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['ألبوم', '" بيتش', 'بويز', 'أند', 'ذو', 'أونستوب "', '( Beach', 'Boys', 'and', 'the', 'Unstoppable )']
# Stemmed Words: ['مهما', 'قال', 'ناس', 'عن ،', 'أنا', 'ليس', 'ذلك']
# Stemmed Words: ['أول', 'ألبوم', 'فرقة', 'مونكيز', 'هو', '" The', 'Monkees "']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مركب', 'كيميائي', 'من', 'فيتامين', 'الذي', 'وجد', 'في', 'طعام', 'مثل', 'بطاطس', 'فلفل', 'خضرة', 'أخضر', 'فاكهة', 'أحمر', 'برتقال ،', 'تألف', 'من', 'مركب', 'كيميائي', 'أدى', 'دور', 'مهما', 'في', 'صحة', 'إنسان']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مركب', 'عضوية', 'متعدد', 'جزيء', 'مشتق', 'من', 'فيتامين', 'أ']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مركب', 'ك']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مركب', 'عضوية', 'من', 'فيتامين', 'موجود', 'في', 'خضار', 'فاكهة']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مجموعة', 'من', 'مركب', 'عضوية', 'الذي', 'وجد', 'في', 'عديد', 'من', 'طعام', 'مثل', 'فاكهة', 'خضرة ،', 'اعتبر', 'مصدر', 'رئيسي', 'فيتامين', 'A', 'في', 'نظام', 'غذائي', 'بشري']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مركب', 'كيميائي', 'وجد', 'في', 'نبات', 'حيوان ،', 'شمل', 'بت', 'كارو', 'فيتامين', 'أ']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مجموعة', 'من', 'مادة', 'كيميائي', 'الذي', 'كان', 'موجود', 'في', 'بعض', 'نبات ،', 'هي', 'اعتبر', 'من', 'مصدر', 'رئيسي', 'فيتامين', 'أ', 'فيتامين', 'د', 'في', 'نظام', 'غذائي', 'بشري']
# Stemmed Words: ['صبغ', 'عضوية', 'تيتراتيربينويدية', '( tetraterpenoid )', 'أصفر', 'لون', '،', 'وجد', 'شكل', 'طبيعي', 'في', 'خضرة', 'فاكهة']
# Stemmed Words: ['كاروتين', 'هي', 'مركب', 'كيميائي', 'اعتبر', 'مصدر', 'رئيسي', 'فيتامين', 'أ ،', 'هي', 'موجود', 'شكل', 'طبيعي', 'في', 'عديد', 'من', 'طعام', 'مثل', 'فاكهة', 'خضرة', 'بذر']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قبل', 'أن', 'ين']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرماني', 'عاش', 'في', 'أوربا', 'غربي', 'في', 'عصر', 'أوسط ،', 'كان', 'اعتبر', 'من', 'قبيلة', 'جرماني', 'الذي', 'هاجر', 'إلى', 'أوربا', 'غربي']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قوط', 'هم', 'مجموعة', 'عرقي', 'جرمانية', 'قديم', 'من', 'أصل', 'أوربي', 'شرقي ،', 'نشأ', 'في', 'آخر', 'عصر', 'روماني', 'بداية', 'عصر', 'أوسط ،', 'في', 'منطقة', 'بحر', 'قزوين', 'شمال', 'بحر', 'أسود']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرماني', 'عاش', 'في', 'أوربا', 'غربي', 'في', 'عصر', 'أوسط']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرماني', 'قديم ،', 'كان', 'عاش', 'في', 'أوربا', 'شرقي', 'في', 'عصر', 'قديم', 'أوسط']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قوط', 'هم', 'قبيلة', 'جرمانية', 'من', 'شعب', 'جرماني ،', 'هم', 'من', 'أصل', 'أوربي ،', 'هم', 'من', 'أصل', 'جرماني ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أصل', 'جرمانية ،', 'هم', 'من', 'أ']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قوط', 'هم', 'مجموعة', 'من', 'شعب', 'أوربي', 'غربي', 'الذي', 'نشأ', 'في', 'أوائل', 'قرن', 'خامس', 'ميلادي', 'في', 'منطقة', 'بلقان ،', 'كان', 'عاش', 'في', 'إقليم', 'قوطي ،', 'امتد', 'من', 'نهر', 'دانوب', 'في', 'شمال', 'إلى', 'بحر', 'الأدرياتيكي', 'في', 'جنوب ،', 'امتد', 'من', 'نهر', 'دانوب', 'إلى', 'بحر', 'أسود', 'في', 'شرق ،', 'امتد', 'إلى', 'بحر', 'أبيض', 'متوسط', 'في', 'غرب']
# Stemmed Words: ['قبيلة', 'جرمانية', 'شرقي']
# Stemmed Words: ['قوط', 'هم', 'شعب', 'جرماني', 'نشأ', 'في', 'آخر', 'عصر', 'قديم', 'بداية', 'عصر', 'أوسط', 'في', 'منطقة', 'برابانتيا ،', 'الذي', 'وقع', 'في', 'شمال', 'أوربا ،', 'هم', 'اعتبر', 'من', 'أقرب', 'شعب', 'جرماني', 'إلى', 'رومان ،', 'قد', 'سكن', 'في', 'غالب', 'في', 'منطقة', 'واقع', 'جنوب', 'نهر', 'راين ،', 'تالي', 'كان', 'على', 'تماس', 'وثيق', 'مع', 'رومان ،', 'هم', 'كان', 'من', 'أهم', 'شعب', 'الذي', 'ساهم', 'في', 'تكوين', 'أوربا']
# Stemmed Words: ['4']
# Stemmed Words: ['تسع', 'عضلة', 'ربط', 'لسان', 'فك']
# Stemmed Words: ['4']
# Stemmed Words: ['عضلة', 'الذي', 'ربط', 'لسان', 'فك', 'هي :']
# Stemmed Words: ['4']
# Stemmed Words: ['ثلاث', 'عضلة', 'تربة']
# Stemmed Words: ['4']
# Stemmed Words: ['12', 'عضلة']
# Stemmed Words: ['4']
# Stemmed Words: ['4', 'عضلة']
# Stemmed Words: ['4']
# Stemmed Words: ['8']
# Stemmed Words: ['4']
# Stemmed Words: ['عضلة', 'لعاب', 'هي', 'عضلة', 'خيطي ،', 'اتصل', 'لسان', 'في', 'جز']
# Stemmed Words: ['4']
# Stemmed Words: ['عضلة', 'مجرور']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['استخدم', 'صامويل', 'مارس', 'طريقة', 'شعاع', 'صادع', 'اختراع', 'فاكس']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['وظيفة', 'أساسي', 'فاكس', 'هي', 'إرسال', 'رسالة', 'والي']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['أمكن', 'نقل', 'صور', 'رسالة', 'وثيقة', 'سرعة']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['فاكس', 'سمى']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['تكنولوجيا', 'رقمي']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['في', 'مجال', 'عمل', 'تواصل']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['أليكسندر', 'جراه']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['مصر']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['أنتوني', 'سكوت']
# Stemmed Words: ['عام', '1964']
# Stemmed Words: ['صامويل', 'مارس']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['حزب', 'إسلامي']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['اضطراب', 'سياسي', 'صراع', 'بين', 'حكومة']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['تاريخ', 'وفاة', 'علي', 'الحيدري', 'غير', 'معروف']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['2003']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['مافيا']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['2006']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['مهد']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['سيد', 'علي', 'الحيدري']
# Stemmed Words: ['تشرين', 'أول', 'عام', '2004']
# Stemmed Words: ['حزب', 'وطني', 'عراقي']
# Stemmed Words: ['لا']
# Stemmed Words: ['نعم ،', 'هناك', 'قبيلة', 'طوراق', 'في', 'موريتانيا']
# Stemmed Words: ['لا']
# Stemmed Words: ['قبيلة', 'طارقة', 'هي', 'مجموعة', 'قبيلة', 'بدوي', 'عاش', 'في', 'صحراء', 'صحراء', 'في', 'شمال', 'أفريقيا ،', 'هم', 'عاش']
# Stemmed Words: ['لا']
# Stemmed Words: ['قبيلة', 'طوراق', 'هي', 'قبيلة', 'عربي', 'عاش', 'في', 'موريتانيا']
# Stemmed Words: ['لا']
# Stemmed Words: ['لغة', 'رسمي', 'في', 'موريتانيا', 'هي', 'لغة', 'عربي']
# Stemmed Words: ['لا']
# Stemmed Words: ['طوراق', 'هي', 'قبيلة', 'من', 'قبيلة', 'صحراء', 'غربي', 'موريتانيا']
# Stemmed Words: ['13', 'شباط', 'عام', '2016']
# Stemmed Words: ['2014']
# Stemmed Words: ['13', 'شباط', 'عام', '2016']
# Stemmed Words: ['2012']
# Stemmed Words: ['13', 'شباط', 'عام', '2016']
# Stemmed Words: ['اعتبر', 'تحالف', 'جزء', 'من', 'حركة', 'كردي', 'في']
# Stemmed Words: ['13', 'شباط', 'عام', '2016']
# Stemmed Words: ['2003']
# Stemmed Words: ['13', 'شباط', 'عام', '2016']
# Stemmed Words: ['تم', 'تأسيس', 'تحالف', 'ديموقراطي', 'كردي', 'في', 'سوريا', 'في', 'عام', '2003']
# Stemmed Words: ['13', 'شباط', 'عام', '2016']
# Stemmed Words: ['The', 'Kurdish', 'Democratic', 'Alliance', 'in', 'Syria', 'was', 'founded', 'in', '2003']
# Stemmed Words: ['عرف', 'إنسان', 'جريمة', 'منذ', 'فجر', 'بشرية', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'أول', 'جريمة', 'قتل', 'في', 'تاريخ', 'إنساني']
# Stemmed Words: ['في', 'مصر']
# Stemmed Words: ['عرف', 'إنسان', 'جريمة', 'منذ', 'فجر', 'بشرية', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'أول', 'جريمة', 'قتل', 'في', 'تاريخ', 'إنساني']
# Stemmed Words: ['سمى', 'حضارة', 'مصري', 'قديم', 'أول', 'حضارة', 'في', 'عالم']
# Stemmed Words: ['عرف', 'إنسان', 'جريمة', 'منذ', 'فجر', 'بشرية', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'أول', 'جريمة', 'قتل', 'في', 'تاريخ', 'إنساني']
# Stemmed Words: ['في', 'مكان', 'ما', 'في', 'أفريقيا']
# Stemmed Words: ['عرف', 'إنسان', 'جريمة', 'منذ', 'فجر', 'بشرية', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'أول', 'جريمة', 'قتل', 'في', 'تاريخ', 'إنساني']
# Stemmed Words: ['قاهرة']
# Stemmed Words: ['عرف', 'إنسان', 'جريمة', 'منذ', 'فجر', 'بشرية', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'أول', 'جريمة', 'قتل', 'في', 'تاريخ', 'إنساني']
# Stemmed Words: ['منس']
# Stemmed Words: ['عرف', 'إنسان', 'جريمة', 'منذ', 'فجر', 'بشرية', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'أول', 'جريمة', 'قتل', 'في', 'تاريخ', 'إنساني']
# Stemmed Words: ['في', 'وادي', 'هومو', 'هابيليس']
# Stemmed Words: ['عرف', 'إنسان', 'جريمة', 'منذ', 'فجر', 'بشرية', 'منذ', 'هابيل', 'قابيل', 'حيث', 'وقع', 'أول', 'جريمة', 'قتل', 'في', 'تاريخ', 'إنساني']
# Stemmed Words: ['في', 'شلال', 'نهر', 'نيل']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'معظم', 'ديانة', 'وحداني', 'نظرية', 'تطور']
# Stemmed Words: ['لا']
# Stemmed Words: ['بهائي', 'هي', 'ديانة', 'وحداني', 'تأسس', 'في', 'قرن', 'تاسع', 'عشر', 'في', 'إيران ،', 'دعا', 'إلى', 'وحدة', 'جميع', 'دين', 'و']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'ديانة', 'وحداني', 'نظرية', 'تطور']
# Stemmed Words: ['لا']
# Stemmed Words: ['لا', 'دعم', 'ديانة', 'وحداني', 'نظرية', 'تطور ،', 'حيث', 'اعتبر', 'حياة', 'كل', 'ما', 'في', 'من', 'تنوع', 'تطور', 'خلق', 'من', 'الله ،', 'لا', 'آمن', 'تطور', 'الذي', 'أحدث', 'اصطفاء', 'طبيعي']
# Stemmed Words: ['لا']
# Stemmed Words: ['إسرائيل', 'هي', 'بلد', 'مسيحي']
# Stemmed Words: ['لا']
# Stemmed Words: ['نعم ،', 'دعم', 'معظم', 'ديانة', 'وحداني', 'نظرية', 'تطور ،', 'حيث', 'آمن', 'هذا', 'ديانة', 'وحدة', 'تنوع', 'في', 'خليق ،', 'دعم', 'فكرة', 'تطور', 'من', 'خلال', 'نظرية', 'علمي']
# Stemmed Words: ['لا']
# Stemmed Words: ['بعض', 'ديانة', 'وحداني', 'هي', 'يهودي ،', 'مسيحي ،', 'إسلام ،', 'بهائي ،', 'هندوسي']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دولة', 'نجاح', 'في', 'الص']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دولة', 'نجاح', 'في', 'إسرائيل', 'في', 'عام', '1948']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['دولة', 'عرب']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دولة', 'نجاح', 'في', 'قرن', 'تاسع', 'عشر', 'في', 'أمريكا', 'شمالي']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['دولة', 'نجاح', 'هي', 'دولة', 'تمتع', 'ازدهار', 'اقتصادي', 'اجتماعي']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دولة', 'نجاح', 'في', 'أوربا']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دولة', 'نجاح', 'في', 'إسرائيل']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دولة', 'نجاح', 'في', 'سنة', 'ال', '12', 'أخير', 'في', 'دولة', 'متقدم']
# Stemmed Words: ['زبيد', 'في', 'منطقة', 'تهامة', '( أرض', 'منخفض )', 'في', 'يمن']
# Stemmed Words: ['ظهر', 'دولة', 'نجاح', 'في', 'كاليفورنيا']
# Stemmed Words: ['لورد', 'روبرت', 'ستيفنسون', 'سميث', 'بادن', 'باول']
# Stemmed Words: ['روبرت', 'بادن', 'باول']
# Stemmed Words: ['لورد', 'روبرت', 'ستيفنسون', 'سميث', 'بادن', 'باول']
# Stemmed Words: ['ثقة ،', 'إخلاص ،', 'صدق ،', 'مسؤولية ،', 'لياقة', 'بدني ،', 'تضامن ،', 'التزام', 'وعد']
# Stemmed Words: ['لورد', 'روبرت', 'ستيفنسون', 'سميث', 'بادن', 'باول']
# Stemmed Words: ['سرج', 'سبيب']
# Stemmed Words: ['لورد', 'روبرت', 'ستيفنسون', 'سميث', 'بادن', 'باول']
# Stemmed Words: ['روبر']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['إمام', 'بخاري']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['شريف', 'مرتضي', 'هو', 'واحد', 'من', 'شهر', 'فيلسوف', 'معتزل', 'في', 'مصر']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['في', 'قرن', 'رابع', 'هجري']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['في', 'قرن', 'تاسع', 'هجري']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['اعتبر', 'معتزل', 'من', 'فيلسوف', 'مسلم ،', 'هم', 'معروف', 'إيمان', 'بال']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['إنتشر', 'فكر', 'معتزل', 'في', 'مصر', 'في', 'قرن', 'رابع', 'هجري']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['كتاب', '" منطق "', 'أب', 'حسن', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'حسن', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن', 'حسين', 'ابن', 'علي', 'ابن']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['عنى', 'اسم', 'معتزل', '" الم']
# Stemmed Words: ['قرن', 'ثاني', 'هجري']
# Stemmed Words: ['أهم', 'ما', 'ميز', 'معتزل', 'هو', 'تعريف', 'كلام', 'عقل', 'فهم ،', 'حيث', 'اعتقد', 'أن', 'كلام', 'عن']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بعد', 'مدينة', 'دار', 'أبيض', 'عن', 'مدينة', 'ط']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بلغ', 'عدد', 'ساكن', 'مدينة', 'دار', 'أبيض', '3359000', 'نسمة']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['2655', 'كم']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['تب']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['مدينة', 'دار']
# Stemmed Words: ['508', 'كم']
# Stemmed Words: ['بعد', 'مدينة', 'دار', 'أبيض', 'عن', 'مدينة', 'أكادير', '513', 'كم']
# Stemmed Words: ['1637']
# Stemmed Words: ['فكرة', 'الذي', 'طرح', 'ديكارت', 'هي', 'أن', 'معرفة', 'أمكن', 'أن', 'كان', 'مستقل', 'عن', 'خبرة', 'سابق ،', 'أن']
# Stemmed Words: ['1637']
# Stemmed Words: ['في', 'عام', '1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['قام', 'رينيه', 'ديكارت', 'نشر', 'مقال', 'عن', 'منهج', 'في', 'عام', '1637']
# Stemmed Words: ['1637']
# Stemmed Words: ['مقال', 'عن', 'منهج']
# Stemmed Words: ['1637']
# Stemmed Words: ['تعريف', 'ناس', 'منهج', 'علمي']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', 'هو', 'رجل', 'عمل', 'إغريقي ،', 'هو', 'مؤسس', 'شركة', 'إسكندر', 'أفروديسي ،', 'هي', 'شركة', 'عالمي', 'بقالة']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', '( لغة', 'إغريقي :', 'Ἀ λ έ ξ α ν δ ρ ο ς', 'ὁ', 'Ἀ φ ρ ο δ ا σ ε ύ ς )', 'هو', 'أستاذ', 'في', 'فلسفة', 'في', 'أكاديمية', 'أثينا']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', 'هو', 'طبيب', 'يوناني', 'قديم ،', 'اسم', 'كامل', 'إسكندر', 'فريجاني', 'أفروديسي']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', '( اسم', 'يوناني :', 'Ἀ λ έ ξ α ν δ ρ ο ς', 'ὁ', 'Ἀ φ ρ ο δ ا σ ε ύ ς )', 'هو', 'ملك', 'بحريني', 'قديم ،', 'من', 'أسطورة', 'يوناني']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', 'هو', 'عالم', 'فيزيائي', 'كي', 'يوناني', 'من', 'قرن', 'رابع', 'قبل', 'ميلاد ،', 'اعتبر', 'من', 'شهر', 'عالم', 'فلك', 'فيزياء', 'في', 'عصر', 'هليني', 'قديم']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', '( اسم', 'يوناني :', 'Ἀ λ έ ξ α ν δ ρ ο ς', 'Ἀ φ ρ ο δ ا σ ε ο ς )', 'هو', 'كاتب', 'ساخر', 'قديم', 'من', 'يونان ،', 'اعتبر', 'من', 'أبرز', 'كتاب', 'سخرية', 'في', 'عصر', 'قديم']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', 'هو', 'باحث', 'فيلسوف', 'يوناني', 'قديم ،', 'اشتهر', 'بحث', 'في', 'مجال', 'رياضية', 'فيزياء']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', 'هو', 'قائد', 'بحري', 'بطلمي', 'الذي', 'قاد', 'حملة', 'ضد', 'إسكندر', 'أكبر']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', 'هو', 'عالم', 'فيزيائي', 'عالم', 'رياضي', 'من', 'إسكندري ،', 'اشتهر', 'عديد', 'من', 'مساهمة', 'في', 'مجال', 'رياضية', 'فيزياء ،', 'من', 'شهر', 'هذا', 'مساهمة', 'تطوير', 'ما', 'عرف', 'ب', '" نظرية', 'شعاع "', 'أو', '" نظرية', 'إشعاع "']
# Stemmed Words: ['فيلسوف', 'جدلي', 'من', 'أكبر', 'شراح', 'أرسطو', 'في', 'عصر', 'يوناني', 'روماني']
# Stemmed Words: ['إسكندر', 'أفروديسي', '( أو', 'إسكندر', 'أثيني )', '( 350-330', 'ق']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['مخرج', 'فيلم', 'شغف', 'مسيح', 'هو', 'كريستوفر', 'نول']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['ديرك', 'بارت']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['مخرج', 'فيلم', 'شغف', 'مسيح', 'هو', 'جيفة', 'ناثانسون']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['كريستوف', 'نول', 'هو', 'مخرج', 'سينمائي', 'فرنسي', 'من', 'مولود', '11', 'سبتمبر', '1964']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['جيفة', 'ناثانسون']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['ريتشارد', 'آتكينسون']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['روبرت', 'زيميكس']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['بيتر', 'جاكسون']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['إيطاليا']
# Stemmed Words: ['ميل', 'غيبسون']
# Stemmed Words: ['كريستوفر', 'نول']
# Stemmed Words: ['مجلس', 'عم']
# Stemmed Words: ['برلمان', 'كندي']
# Stemmed Words: ['مجلس', 'عم']
# Stemmed Words: ['ملك', 'في', 'كندا']
# Stemmed Words: ['مجلس', 'عم']
# Stemmed Words: ['ملك']
# Stemmed Words: ['مجلس', 'عم']
# Stemmed Words: ['رئيس', 'وزير', 'كندا']
# Stemmed Words: ['مجلس', 'عم']
# Stemmed Words: ['ملك', 'أليزابيث', 'ثاني']
# Stemmed Words: ['مجلس', 'عم']
# Stemmed Words: ['حاكم', 'عام']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['هيروزي', 'ويلكيرز']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['جيمس', 'م']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['من', 'هو', 'فرانكلين', 'روزفلت']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['لويس', 'اكر']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['سوليفان', 'هاميلتون']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['فرانكلين', 'روزفلت']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['سيد', 'فرانكلين', 'كيوز']
# Stemmed Words: ['هارفي', 'واشنطون', 'ويل']
# Stemmed Words: ['Francis', 'Kelsey']
# Stemmed Words: ['مصلحة', 'ذات', 'طابع', 'اقتصادي', 'أمني', 'مكلف', 'مراقبة', 'مبادلة', 'تجاري', 'على', 'حد', 'جباية', 'ضرائب', 'على', 'وارد']
# Stemmed Words: ['جمرك', 'هو', 'ماء', 'استخدم', 'في', 'صلاة ،', 'هو', 'ماء', 'استخدم', 'في', 'غسل', 'يد', 'مؤمن', 'قبل', 'صلاة']
# Stemmed Words: ['مصلحة', 'ذات', 'طابع', 'اقتصادي', 'أمني', 'مكلف', 'مراقبة', 'مبادلة', 'تجاري', 'على', 'حد', 'جباية', 'ضرائب', 'على', 'وارد']
# Stemmed Words: ['هو', 'صلصل', 'ذكى', 'في', 'أطواد', 'من', 'خطوب', 'خصب', 'أشعث', 'حجر', 'أزلج', 'أخضر', 'أبيض', 'أحمر', 'أسود', 'أسمر', 'أصفر']
# Stemmed Words: ['مصلحة', 'ذات', 'طابع', 'اقتصادي', 'أمني', 'مكلف', 'مراقبة', 'مبادلة', 'تجاري', 'على', 'حد', 'جباية', 'ضرائب', 'على', 'وارد']
# Stemmed Words: ['جمرك', 'هو', 'قسيم', 'من', 'جسم', 'إنسان', 'ي']
# Stemmed Words: ['مصلحة', 'ذات', 'طابع', 'اقتصادي', 'أمني', 'مكلف', 'مراقبة', 'مبادلة', 'تجاري', 'على', 'حد', 'جباية', 'ضرائب', 'على', 'وارد']
# Stemmed Words: ['جمرك', 'هو', 'شجرة']
# Stemmed Words: ['مصلحة', 'ذات', 'طابع', 'اقتصادي', 'أمني', 'مكلف', 'مراقبة', 'مبادلة', 'تجاري', 'على', 'حد', 'جباية', 'ضرائب', 'على', 'وارد']
# Stemmed Words: ['جمرك', 'هو', 'نوع', 'من', 'خضرة']
# Stemmed Words: ['مصلحة', 'ذات', 'طابع', 'اقتصادي', 'أمني', 'مكلف', 'مراقبة', 'مبادلة', 'تجاري', 'على', 'حد', 'جباية', 'ضرائب', 'على', 'وارد']
# Stemmed Words: ['جمرك', 'هو', 'نبات', 'من', 'نبات', 'قطب']
# Stemmed Words: ['شمال', 'شرقي', 'ولاية', 'كوينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['أمكن', 'من']
# Stemmed Words: ['شمال', 'شرقي', 'ولاية', 'كوينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['أكبر', 'مدينة', 'في', 'مكسيك', 'هي']
# Stemmed Words: ['شمال', 'شرقي', 'ولاية', 'كوينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['وقع', 'مدينة', 'كانكون']
# Stemmed Words: ['شمال', 'شرقي', 'ولاية', 'كوينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['وقع', 'مدينة', 'كانكون', 'في', 'ولاية', 'كينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['شمال', 'شرقي', 'ولاية', 'كوينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['نشاط', 'شهير', 'في', 'مدينة', 'كانكون', 'هي', 'سياحة', 'استجمام', 'رياضة', 'فندق', 'منتجع']
# Stemmed Words: ['شمال', 'شرقي', 'ولاية', 'كوينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['وقع', 'مدينة', 'كانكون', 'في', 'مكسيك']
# Stemmed Words: ['شمال', 'شرقي', 'ولاية', 'كوينتانا', 'رو', 'في', 'مكسيك']
# Stemmed Words: ['مدينة', 'كانكون', 'هي', 'مدينة', 'أكثر', 'زيارة', 'في', 'مكسيك']
# Stemmed Words: ['291']
# Stemmed Words: ['" جزيرة', 'سقطرى :', 'تاريخ', 'علاقة', 'مع', 'يمن "']
# Stemmed Words: ['291']
# Stemmed Words: ['29', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['43', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['195', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['وجد', 'في', 'جزيرة', 'سقطرى', '44', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['30', 'نوع', 'من', 'طير']
# Stemmed Words: ['291']
# Stemmed Words: ['أكثر', 'من', '50', 'نوع']
# Stemmed Words: ['291']
# Stemmed Words: ['وجد', 'في', 'جزيرة', 'سقطرى', '44', 'نوع', 'من', 'طير ،', 'اعتبر', 'هذا', 'عدد', 'من', 'رقم', 'طير', 'موجود', 'في', 'جزيرة', 'من', 'أعلى', 'رقم', 'في', 'عالم']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['سياتل', 'هي', 'أكبر', 'مدينة', 'ولاية', 'واشنطون']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بيترزبورغ', 'هي', 'أكبر', 'مدينة', 'ولاية', 'أوريغون']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['مينيابوليس', 'هي', 'أكبر', 'مدينة', 'ولاية', 'مينيسوتا']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['برمنغ']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['بورت']
# Stemmed Words: ['بورتلاند']
# Stemmed Words: ['مدينة', 'نايروبي']
# Stemmed Words: ['مصر']
# Stemmed Words: ['شهر', 'نادي']
# Stemmed Words: ['مصر']
# Stemmed Words: ['وقع', 'مدينة', 'إسكندرية', 'على', 'ساحل', 'بحر', 'أبيض', 'متوسط']
# Stemmed Words: ['مصر']
# Stemmed Words: ['لغة', 'عربي']
# Stemmed Words: ['مصر']
# Stemmed Words: ['وقع', 'إسكندرية', 'على', 'ساحل', 'بحر', 'أبيض', 'متوسط', 'في', 'شمال', 'مصر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['بعض', 'معلم', 'سياحي', 'في', 'إسكندرية', 'شمل', 'قلعة', 'قايتباي', 'محطة', 'قطار', 'إسكندرية', 'محطة', 'قطار', 'إسكندرية', 'م']
# Stemmed Words: ['مصر']
# Stemmed Words: ['وقع', 'مدينة', 'إسكندرية', 'في', 'مصر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['مدينة', 'إسكندرية', 'هي', 'مدينة', 'ساحلي', 'وقع', 'في', 'شمال', 'مصر ،', 'اعتبر', 'ثاني', 'أكبر', 'مدينة', 'في', 'مصر', 'بعد', 'قاهرة']
# Stemmed Words: ['مصر']
# Stemmed Words: ['أهمية', 'إسكندر']
# Stemmed Words: ['مصر']
# Stemmed Words: ['إسكندرية', 'هي', 'مدينة', 'ساحلي', 'مصري', 'وقع', 'على', 'ساحل', 'بحر', 'أبيض', 'متوسط']
# Stemmed Words: ['قضاء', 'كسروان']
# Stemmed Words: ['مغار', 'جع']
# Stemmed Words: ['قضاء', 'كسروان']
# Stemmed Words: ['مغار', 'اعتبر', 'من', 'أهم', 'معلم', 'أثري', 'في', 'لبنان ،', 'تميز', 'غرفة', 'كبير', 'متقن', 'الذي', 'تم', 'إنشاء', 'يد ،', 'كما', 'أن', 'شهد', 'على', 'تاريخ', 'لبنان', 'قديم']
# Stemmed Words: ['قضاء', 'كسروان']
# Stemmed Words: ['وقع', 'مغار', 'جعيتا', 'في', 'لبنان ،', 'على', 'بعد', '8', 'كيلومتر', 'من', 'بيروت ،', 'اعتبر', 'من', 'أهم', 'معلم', 'سياحي', 'في', 'منطقة']
# Stemmed Words: ['قضاء', 'كسروان']
# Stemmed Words: ['وقع', 'مغار', 'جعيتا', 'في', 'لبنان']
# Stemmed Words: ['قضاء', 'كسروان']
# Stemmed Words: ['امتاز', 'مغار', 'جعيتا', 'وجود']
# Stemmed Words: ['قضاء', 'كسروان']
# Stemmed Words: ['مادة', 'الذي', 'استخدم', 'في', 'ابن']
# Stemmed Words: ['اثنا', 'عشر']
# Stemmed Words: ['مصر', 'قديم']
# Stemmed Words: ['اثنا', 'عشر']
# Stemmed Words: ['12', 'برج']
# Stemmed Words: ['اثنا', 'عشر']
# Stemmed Words: ['هناك', '12', 'برج', 'في', 'علم', 'تنجيم']
# Stemmed Words: ['اثنا', 'عشر']
# Stemmed Words: ['كولين']
# Stemmed Words: ['اثنا', 'عشر']
# Stemmed Words: ['برج', 'أسد']
# Stemmed Words: ['اثنا', 'عشر']
# Stemmed Words: ['برج', 'قوس']
# Stemmed Words: ['اثنا', 'عشر']
# Stemmed Words: ['عذراء ،', 'حوت ،', 'ميزان ،', 'دلو ،', 'عقرب ،', 'قوس ،', 'سرطان ،', 'أسد ،', 'ماء']
# Stemmed Words: ['نعم']
# Stemmed Words: ['أهمية', 'حفظ', 'قرآن', 'كريم', 'لغة', 'عربي', 'كمن', 'في', 'حفاظ', 'علي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'قرآن', 'من', 'حافظ', 'لغة', 'عربي ،', 'إن', 'حافظ', 'على', 'قاعدة', 'اصطلاح', 'رواية']
# Stemmed Words: ['نعم']
# Stemmed Words: ['أن', 'قرآن', 'كريم', 'هو', 'كتاب', 'مقدس', 'مسلم', 'و', 'هو', 'كتاب', 'الذي', 'كتب', 'لغة', 'عربي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم', 'قرآن', 'حافظ', 'علي', 'لغة', 'عربي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عزز', 'قرآن', 'لغة', 'عربي', 'من', 'خلال', 'استخدام', 'كلمة', 'جديد', 'مفردة', 'غ']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'قرآن', 'حافظ', 'علي', 'لغة', 'عربي ،', 'عربي', 'قبل', 'إسلام', 'كان', 'لعب', 'بعض', 'كلمة', 'الذي', 'لا', 'أحد', 'عرف', 'معنى ،', 'لكن', 'بعد', 'نزول', 'قرآن', 'أصبح', 'عرف', 'معنى', 'كل', 'كلمة']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم', 'قرآن', 'من', 'حافظ', 'علي', 'لغة', 'عربي', 'يوم', 'هذا']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['تم', 'اكتشاف', 'شعاع', 'تحت', 'أحمر', 'في', 'عام', '1800', 'من', 'قبل', 'ويليام', 'هييرشل']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['طيف']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['اكتشف', 'شعاع', 'تحت', 'أحمر', 'في', 'عام', '1800 م']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['تطبيق', 'عملية', 'اشع', 'تحت', 'أحمر', 'شمل', 'استخدام', 'في', 'طب ،', 'فضاء ،', 'والي']
# Stemmed Words: ['عام', '1800']
# Stemmed Words: ['اكتشف', 'ويليام', 'هيرشل', 'في', 'عام', '1801']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['Keratin', 'is', 'a', 'protein', 'found', 'in', 'bacteria ,', 'fungi ,', 'and']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['كيت', 'هو', 'بروتين', 'موجود', 'في', 'جدار', 'خلية', 'نباتي', 'حيواني', 'بكتيري']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['هو', 'بروتين', 'وجد', 'في', 'خلية', 'نباتي', 'هو', 'من', 'أهم', 'مادة', 'مكون', 'غذاء']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['كيت', 'هو', 'بروتين', 'أنتج', 'جسم', 'من', 'ليف', 'بروتيني', 'في', 'طعام']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['كيت', 'هو', 'بروتين', 'اعتبر', 'من', 'بروتين', 'دهني ،', 'هو', 'لعب', 'دور', 'مهما', 'في', 'تقليل', 'فقدان', 'ليف', 'عضلي ،', 'اعتبر', 'من', 'بروتين', 'الذي', 'ظهر', 'في', 'جسم', 'عند', 'فقدان', 'نسيج', 'عضلي ،', 'تم', 'إنتاج', 'كيت', 'في', 'جسم', 'شكل', 'طبيعي', 'عند', 'تأثير', 'تالي :', 'فقدان', 'نسيج', 'عضلي ،', 'أو', 'إصابة', 'سمنة ،', 'أو', 'تدهور', 'نسيج', 'عضلي ،', 'أو', 'إصابة', 'مرض']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['هو', 'بروتين', 'لعب', 'دور', 'هام', 'في', 'بناء', 'جلد', 'شعر', 'حاجب']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['كيت', 'هو', 'بروتين', 'صنع', 'من', 'قبل', 'بعض', 'نوع', 'فطري ،', 'استخدم', 'عامل', 'تآزر', 'في', 'عديد', 'من', 'مرض', 'فطري ،', 'مثل', 'مرض', 'جلد', 'فطري']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['هو', 'بروتين', 'وجد', 'في', 'جلد']
# Stemmed Words: ['مادة', 'أحيائي', 'من', 'عديد', 'سكاريد', 'هي', 'اعتبر', 'مركب', 'أساسي', 'جانب', 'خلية', 'فطري', 'هي', 'هيكل', 'صلب', 'الذي', 'غطى', 'جسم', 'حشرة', 'عديد', 'من', 'مفصلي', 'رجل', 'بعض', 'حيوان']
# Stemmed Words: ['هو', 'بروتين', 'وجد', 'في', 'جلد', 'حمى', 'جلد', 'من', 'حرق']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['عالم', 'فرنسي', '" جاكوب', 'نيكولاس', 'بيرنارد "', 'هو', 'أول', 'من', 'قام', 'تشخيص', 'مرض', 'كساح', 'لدى', 'طفل']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['ويليام', 'أوسلر']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['تشخيص', 'مرض', 'كساح', 'لدى', 'طفل', 'أول', 'مرة', 'تم', 'تشخيص', 'ل', 'من', 'قبل', 'طبيب', 'ألماني', 'ألكسندر', 'أومان', '( Alexander', 'Ombredanne )', 'عام', '1898']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['تشخيص', 'مرض', 'كساح', 'لدى', 'طفل', 'هو', 'من', 'عمل', 'طبيب', 'إنجليزي', '" إدوين', 'كيني "', 'عام', '1889']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['تشخيص', 'مرض', 'كساح', 'لدى', 'طفل', 'عاد', 'إلى', 'طبيب', 'فرنسي', 'يركي', '( Pierre', 'Marie', 'Béclard )', 'الذي', 'عاش', 'في', 'قرن', 'تاسع', 'عشر']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['تشخيص', 'مرض', 'كساح', 'لدى', 'طفل', 'تم', 'تحديد', 'أول', 'مرة', 'من', 'قبل', 'طبيب', 'إيطالي', 'سيلفستر', 'جيلاردو', 'عام', '1822']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['أدولف']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['دكتور', 'يليس', 'كراندال', 'روبنز']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['عالم', 'بريطاني', 'إدوين', 'كلارك']
# Stemmed Words: ['دانيال', 'ويسلر']
# Stemmed Words: ['جيمس', 'هاتون']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['لا']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['لا', 'بنى', 'نبي', 'سليمان', 'قدس']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['بنى', 'نبي', 'داود']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['ولاية']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['نعم ،', 'بنى', 'نبي', 'سليمان', 'قدس']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['إسحاق']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['بنى', 'آلن']
# Stemmed Words: ['أعطى', 'كتاب', 'مقدس', 'عبري', 'أفضل', 'في', 'بناء', 'هيكل', 'أول', 'في', 'قدس']
# Stemmed Words: ['إن', 'بناء', 'قدس', 'عاد', 'إلى', 'عهد', 'سليمان', 'ابن', 'داود ،', 'حيث', 'بنى', 'سليمان', 'ابن', 'داود', 'مدينة', 'قدس ،', 'الذي', 'كان', 'سمى', 'آنذاك', 'أورشليم ،', 'على', 'هضبة', 'زيتون']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['كان', 'الس']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['في', '19', 'ديسمبر', '1914']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['نيكفوروس', 'باسيلاجيوس']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['نشب', 'معركة', 'مرعش', 'في', 'عام', '1071 م']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['زعيم', 'الذي', 'قاد', 'جيش', 'بيزنطي', 'في', 'معركة', 'مرعش', 'هو', 'روبرت', 'جيسكاس']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['نشب', 'معركة', 'مرعش', 'في', 'عام', '1517']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['كان', 'ياسين', 'باي', 'من', 'بين', 'قائد', 'جيش', 'مملوك', 'في', 'معركة', 'مرعش']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['متسابق', 'رياضي', 'مصري']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['نشب', 'معركة', 'مرعش', 'في', '24', 'ديسمبر']
# Stemmed Words: ['7', 'تموز', 'عام', '1742']
# Stemmed Words: ['في', '25', 'يناير', '151']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['تم', 'تنفيذ']
# Stemmed Words: ['نعم']
# Stemmed Words: ['طبق', 'حكم', 'إعدام', 'في', 'سعودية', 'في', 'قضية', 'متعلق', 'جريمة', 'مخل', 'عرض', 'عام ،', 'جريمة', 'ضد', 'أمن', 'قومي ،', 'جريمة', 'ضد', 'أمن', 'عام ،', 'جريمة', 'ضد', 'فرد ،', 'جريمة', 'ضد', 'ممتلك ،', 'جريمة', 'ضد', 'نفس ،']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'طبق', 'حكم', 'إعدام', 'في', 'سعودية']
# Stemmed Words: ['نعم']
# Stemmed Words: ['طبق', 'حكم', 'إعدام', 'في', 'سعودية', 'في', 'حالة', 'جريمة', 'محدد', 'في', 'قانون', 'جنائي', 'سعودي ،', 'مثل', 'قتل', 'عمد ،', 'خيانة', 'أعظم ،', 'زنا ،', 'سرقة ،', 'تعدي', 'على', 'أمن', 'عام']
# Stemmed Words: ['نعم']
# Stemmed Words: ['قسم', 'خاص', 'سجن']
# Stemmed Words: ['بحيرة', 'سوبيريور']
# Stemmed Words: ['بحيرة', 'هود']
# Stemmed Words: ['بحيرة', 'سوبيريور']
# Stemmed Words: ['بحيرة', 'с у п يريور']
# Stemmed Words: ['بحيرة', 'سوبيريور']
# Stemmed Words: ['بحيرة', 'أعظم']
# Stemmed Words: ['بحيرة', 'سوبيريور']
# Stemmed Words: ['بحيرة', 'سوبريور', 'هي', 'أكبر', 'بحيرة', 'في', 'كندا ،', 'وقع', 'في', 'جزء', 'شمالي', 'غربي', 'من', 'ولاية', 'متحد']
# Stemmed Words: ['بحيرة', 'سوبيريور']
# Stemmed Words: ['بحيرة', 'سوبريور']
# Stemmed Words: ['مارس', '1956']
# Stemmed Words: ['استقل', 'تونس', 'في', '20', 'مارس', '1956']
# Stemmed Words: ['مارس', '1956']
# Stemmed Words: ['استقل', 'مغرب', 'في', '2', 'مارس', '1956']
# Stemmed Words: ['مارس', '1956']
# Stemmed Words: ['استقل', 'جزائر', 'في', '5', 'يوليو', '1962']
# Stemmed Words: ['مارس', '1956']
# Stemmed Words: ['الع']
# Stemmed Words: ['مارس', '1956']
# Stemmed Words: ['20', 'مارس', '1956']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['مؤلف', 'كتاب', '"', 'حكم', 'عطاء', '"', 'هو', 'أبو', 'عثمان', 'عمرو', 'ابن', 'بشر', 'ابن', 'عثمان', 'عطار']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['هو', '"', 'عطاء', 'الله', 'سكندري', '"']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['حكيم', 'عطاء']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['حكيم', 'عطاء', 'ابن', 'عثمان', 'ساكت']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['حكم', 'عطاء', 'هو', 'كتاب', 'ألف', 'أبو', 'إسحاق', 'إبراهيم', 'ابن', 'يوسف', 'ابن', 'حسين', 'ابن', 'عطاء', 'ابن', 'سفيان', 'أزدي ،', 'معروف', 'عطاء', 'ابن', 'سفيان']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['حكيم', 'عطار']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['أبو', 'حامد', 'غزالي']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['عطاء', 'الله', 'سجستاني']
# Stemmed Words: ['ابن', 'عطاء', 'الله', 'سكندري']
# Stemmed Words: ['Imam', 'Al - Hakim', "Al - Ata ' i"]
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['1957']
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['1972']
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['1971']
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['في', 'عام', '1983 ،', 'قام', 'فنان', 'عالمي', 'يان', 'إنتاج', 'أول', 'حفلة', 'موسيقي', 'ل']
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['يان', '(', 'Yanis', 'Marin )', '،', 'يان', '(', 'Yanis', 'Marin )', '،', 'يان', '(', 'Yanis', 'Marin']
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['لان', 'يان', 'كان', 'محب', 'جاز']
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['يوناني']
# Stemmed Words: ['عقد', '1980']
# Stemmed Words: ['يان', '( Yanni )', 'هو', 'موسيقي', 'يوناني ،', 'ملحن ،', 'مؤلف', 'موسيقي']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['زاد', 'ابن', 'عبد', 'ملك', 'ابن', 'مروان']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['زاد', 'ابن', 'عبد', 'ملك', 'ابن', 'مروان', 'ابن', 'حكم', 'ابن', 'أب', 'سفيان', 'ابن', 'حرب', 'ابن', 'أمية', 'ابن', 'عبد', 'شمس', 'ابن', 'عبد', 'منافي', 'ابن', 'قصي', 'ابن', 'كلب', 'ابن', 'مرة', 'ابن', 'كعب', 'ابن', 'لؤي', 'ابن', 'غالب', 'ابن', 'فهر', 'ابن', 'مالك', 'ابن', 'نضر', 'ابن', 'كنانة', 'ابن', 'خزيمة', 'ابن', 'مدرك', 'ابن', 'إلياس', 'ابن', 'مضر', 'ابن', 'نزار', 'ابن', 'معد', 'ابن', 'عدنان']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['زاد', 'ابن', 'وليد']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['وليد', 'ابن']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['هو', 'يوسف', 'ابن', 'عمر']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['هارون', 'رشيد']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['هو', 'وليد', 'ابن', 'زاد', 'ثاني']
# Stemmed Words: ['هشام', 'معتد', 'الله']
# Stemmed Words: ['هو', 'زاد', 'ابن', 'عمر']
# Stemmed Words: ['لندن']
# Stemmed Words: ['مؤلف', 'موسيقي']
# Stemmed Words: ['لندن']
# Stemmed Words: ['هاندل', 'هو', 'مؤلف', 'موسيقي', 'كلاسيكي', 'من', 'أصل', 'ألماني', 'عاش', 'في', 'إنجلترا']
# Stemmed Words: ['لندن']
# Stemmed Words: ['لندن']
# Stemmed Words: ['لندن']
# Stemmed Words: ['برلين']
# Stemmed Words: ['لندن']
# Stemmed Words: ['اعتبر', 'من', 'شهر', 'مؤلف', 'موسيقى', 'كلاسيكي', 'إنكليزي ،', 'أحد', 'شهر', 'مؤلف', 'موسيقى', 'كلاسيكي', 'في', 'قرن', 'ثامن', 'عشر']
# Stemmed Words: ['لندن']
# Stemmed Words: ['قصر', 'شاو']
# Stemmed Words: ['لندن']
# Stemmed Words: ['لندن ،', 'مملكة', 'متحد']
# Stemmed Words: ['لندن']
# Stemmed Words: ['شوبان']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['ياكوزا', 'هو', 'مرض', 'أصاب', 'كبد']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['هي', 'مرض', 'أصاب', 'كبد']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['ياكوزا', 'هي', 'حالة', 'التهاب', 'في', 'كبد', 'ناجم', 'عن', 'عدوى', 'فيروسي']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['هو', 'إصابة', 'بليغ', 'خلية', 'عصبية', 'في', 'دماغ']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['ياكوزا', 'هو', 'مرض', 'مزمن', 'أصاب', 'جلد ،', 'و', 'ظهر', 'على', 'جلد', 'في', 'شكل', 'حباء', 'أو', 'سحج ،', 'و', 'انتشر', 'في', 'جلد', 'و', 'أمكن', 'أن', 'أصاب', 'عين', 'و', 'أذن', 'و', 'جيب', 'قحفي', 'و', 'كبد', 'و', 'كلوة', 'و', 'قلب', 'و', 'رئة', 'و', 'وعاء', 'دموي', 'و', 'عظمة', 'و', 'نخاع', 'شوكي', 'و', 'عصب', 'بطن', 'و', 'عصب', 'و', 'جيب', 'قحفي', 'و', 'نسيج', 'ر']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['ياكوزا', 'هو', 'مرض', 'نادر', 'حدث', 'في', 'جلد', 'سبب', 'عدوى', 'فيروسي']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['ياكوزا', 'هو', 'مرض', 'تصلبي', 'أصاب', 'كبد']
# Stemmed Words: ['مصطلح', 'عام', 'أطلق', 'على', 'منظمة', 'إجرامي', 'في', 'يابان']
# Stemmed Words: ['ياكوزا', 'هي', 'حالة', 'صحي', 'أدى', 'إلى', 'جمع', 'ليفي', 'من', 'خلية', 'التهابي', 'في', 'جسم']
# Stemmed Words: ['1964']
# Stemmed Words: ['1964']
# Stemmed Words: ['1964']
# Stemmed Words: ['عربي']
# Stemmed Words: ['1964']
# Stemmed Words: ['مقر', 'رئيسي', 'منظمة', 'تحرير', 'فلسطيني', 'وقع', 'في', 'مدينة', 'غزة']
# Stemmed Words: ['1964']
# Stemmed Words: ['تأسس']
# Stemmed Words: ['1964']
# Stemmed Words: ['منظمة', 'تحرير', 'فلسطيني', 'هي', 'منظمة', 'سياسي', 'فلسطيني', 'تأسس', 'عام', '1964']
# Stemmed Words: ['1964']
# Stemmed Words: ['سليم', 'زعنون']
# Stemmed Words: ['1964']
# Stemmed Words: ['محمود', 'عباس']
# Stemmed Words: ['1964']
# Stemmed Words: ['نص', 'مادة', '19', 'على', 'أن', 'جميع', 'شعب', 'قدر', 'حق', 'في', 'تقرير', 'مصير', 'تالي', 'إن', 'شعب', 'فلسطيني', 'ل', 'حق', 'في', 'تق']
# Stemmed Words: ['زابيفاكا']
# Stemmed Words: ['تميمة', 'كأس', 'عالم', 'كرة', 'قدم', '2018', 'هي', 'زابيتا ،', 'هي', 'زباب', 'روسي']
# Stemmed Words: ['زابيفاكا']
# Stemmed Words: ['تميمة', 'كأس', 'عالم', 'كرة', 'قدم', '2018', 'هي', 'زابيفا']
# Stemmed Words: ['زابيفاكا']
# Stemmed Words: ['تميمة', 'كأس', 'عالم', 'كرة', 'قدم', '2018', 'هي', 'زابيفا ،', 'هي', 'خروف', 'روسي ،', 'تم', 'اختيار', 'من', 'قبل', 'لجنة', 'منظمة', 'كأس', 'عالم', '2018']
# Stemmed Words: ['زابيفاكا']
# Stemmed Words: ['تميمة', 'كأس', 'عالم', 'كرة', 'قدم', '2018', 'هي', 'زابيتا ،', 'هي', 'قط', 'روسي']
# Stemmed Words: ['زابيفاكا']
# Stemmed Words: ['تميمة', 'كأس', 'عالم', 'كرة', 'قدم', '2018', 'هي', 'زابيتا']
# Stemmed Words: ['زابيفاكا']
# Stemmed Words: ['تميمة', 'كأس', 'عالم', 'كرة', 'قدم', '2018', 'هي', 'زابيتا ،', 'هي', 'فهد', 'من', 'نوع', 'قط', 'بري ،', 'تم', 'إطلاق', 'اسم', 'في', '28', 'أكتوبر', '2017']
# Stemmed Words: ['زابيفاكا']
# Stemmed Words: ['تميمة', 'كأس', 'عالم', 'كرة', 'قدم', '2018', 'هي', 'زابيتا ،', 'هي', 'كلب', 'روسي', 'من', 'نوع', 'لابريتا']
# Stemmed Words: ['جسيم', 'وجد', 'في', 'نظام', 'شمسي', 'تكون', 'من', 'حطام', 'صخر', 'قد', 'كان', 'في', 'حجم', 'حبيبة', 'رمل', 'صغير', 'أو', 'في', 'حجم', 'صخر', 'كبير']
# Stemmed Words: ['هو', 'نبات', 'استخدم', 'في', 'طبق', 'أخضر']
# Stemmed Words: ['جسيم', 'وجد', 'في', 'نظام', 'شمسي', 'تكون', 'من', 'حطام', 'صخر', 'قد', 'كان', 'في', 'حجم', 'حبيبة', 'رمل', 'صغير', 'أو', 'في', 'حجم', 'صخر', 'كبير']
# Stemmed Words: ['نيزك', 'هو', 'هطول', 'من', 'قطرة', 'ماء', 'صغير', 'تراكم', 'في', 'هواء ،', 'تجمع', 'في', 'هيئة', 'قطرة', 'صغير', 'تراكم', 'في', 'هواء ،', 'تجمع', 'في', 'هيئة', 'قطرة', 'صغير', 'تراكم', 'في', 'هواء ،', 'تجمع', 'في', 'هيئة', 'قطرة', 'صغير', 'تراكم', 'في', 'هواء ،', 'تجمع', 'في', 'هيئة', 'قطرة', 'صغير', 'تراكم', 'في', 'هواء ،', 'تجمع', 'في', 'هيئة', 'قطرة', 'صغير', 'تراكم', 'في', 'هواء ،', 'تجمع', 'في', 'هيئة', 'قطرة', 'صغير', 'تتر']
# Stemmed Words: ['جسيم', 'وجد', 'في', 'نظام', 'شمسي', 'تكون', 'من', 'حطام', 'صخر', 'قد', 'كان', 'في', 'حجم', 'حبيبة', 'رمل', 'صغير', 'أو', 'في', 'حجم', 'صخر', 'كبير']
# Stemmed Words: ['نيزك', 'هو', 'نبات', 'اعتبر', 'من', 'أهم', 'نبات', 'طبي', 'في', 'بلد', 'عربي']
# Stemmed Words: ['جسيم', 'وجد', 'في', 'نظام', 'شمسي', 'تكون', 'من', 'حطام', 'صخر', 'قد', 'كان', 'في', 'حجم', 'حبيبة', 'رمل', 'صغير', 'أو', 'في', 'حجم', 'صخر', 'كبير']
# Stemmed Words: ['نيزك', 'هو', 'نبات', 'معمر', 'استخدم', 'في', 'دواء']
# Stemmed Words: ['جسيم', 'وجد', 'في', 'نظام', 'شمسي', 'تكون', 'من', 'حطام', 'صخر', 'قد', 'كان', 'في', 'حجم', 'حبيبة', 'رمل', 'صغير', 'أو', 'في', 'حجم', 'صخر', 'كبير']
# Stemmed Words: ['هو', 'حشرة', 'الذي', 'غذى', 'حشرة', 'آخر', 'نما', 'داخل']
# Stemmed Words: ['جسيم', 'وجد', 'في', 'نظام', 'شمسي', 'تكون', 'من', 'حطام', 'صخر', 'قد', 'كان', 'في', 'حجم', 'حبيبة', 'رمل', 'صغير', 'أو', 'في', 'حجم', 'صخر', 'كبير']
# Stemmed Words: ['نيزك', 'هو', 'نبات', 'عد', 'من', 'نبات', 'عطري', 'رائح ،', 'استخدم', 'في', 'صنع', 'عطر', 'بخور']
# Stemmed Words: ['جسيم', 'وجد', 'في', 'نظام', 'شمسي', 'تكون', 'من', 'حطام', 'صخر', 'قد', 'كان', 'في', 'حجم', 'حبيبة', 'رمل', 'صغير', 'أو', 'في', 'حجم', 'صخر', 'كبير']
# Stemmed Words: ['نيزك', 'هو', 'جنس', 'من', 'نبات', 'زهرية', 'تبع', 'فصيل', 'نجمي ،', 'ضم', 'أكثر', 'من', '400', 'نوع ،', 'تواجد', 'في', 'جميع', 'نحو', 'عالم ،', 'اعتبر', 'من', 'نبات', 'مزهر ،', 'اعتبر', 'من', 'أهم', 'نوع', 'نبات', 'مزهر', 'الذي', 'أنتج', 'زهور', 'في', 'مختلف', 'لون']
# Stemmed Words: ['1921']
# Stemmed Words: ['تأسس', 'حزب', 'شيوعي', 'صيني', 'في', '1', 'يوليو', '1921']
# Stemmed Words: ['1921']
# Stemmed Words: ['تأسس', 'حزب', 'شيوعي', 'صيني', 'في', 'عام', '1921']
# Stemmed Words: ['1921']
# Stemmed Words: ['1921']
# Stemmed Words: ['1921']
# Stemmed Words: ['مبدأ', 'أساسي', 'حزب', 'شيوعي', 'صيني', 'هي', 'ماركسي', 'لينيني', 'شيوعية', 'اشتراكية', 'علمانية']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم']
# Stemmed Words: ['كان', 'عرض', 'في', 'بداية', 'أمر', 'غير', 'واضح ،', 'شمل :', 'آفة', 'جلدي', 'غير', 'طبيعي ،', 'آفة', 'صلب ،', 'آفة', 'خدج ،', 'آفة', 'الذي', 'تسبب', 'إحمرار', 'جلد ،', 'آفة', 'الذي', 'تسبب', 'تغير', 'لون', 'جلد']
# Stemmed Words: ['نعم']
# Stemmed Words: ['أمكن', 'أن', 'تسبب', 'شعاع', 'يو', 'مرض', 'سرطان', 'جل']
# Stemmed Words: ['نعم']
# Stemmed Words: ['تم', 'تشخيص', 'مرض', 'سرطان']
# Stemmed Words: ['نعم']
# Stemmed Words: ['عرض', 'سرطان', 'جلد', 'تضمن :']
# Stemmed Words: ['نعم']
# Stemmed Words: ['ورم', 'أو', 'خباث', 'موجود', 'على', 'جلد ،', 'تغير', 'في', 'لون', 'جلد', 'أو', 'شعر ،', 'احمرار', 'أو', 'بقعة', 'أسود', 'على', 'جلد ،', 'عدم', 'انتظام', 'نمو', 'شعر']
# Stemmed Words: ['نعم']
# Stemmed Words: ['اعتمد', 'علاج', 'على', 'مرحلة', 'مرض', 'أمكن', 'أن', 'شمل', 'جراحة', 'أو', 'علاج', 'إشعاعي', 'أو', 'علاج', 'كيميائي', 'أو', 'علاج', 'إقليمي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['شعاع', 'فوق', 'بنفسجي']
# Stemmed Words: ['خمس']
# Stemmed Words: ['1', 'سفر']
# Stemmed Words: ['خمس']
# Stemmed Words: ['سبع', 'سفر']
# Stemmed Words: ['خمس']
# Stemmed Words: ['27']
# Stemmed Words: ['خمس']
# Stemmed Words: ['40', 'سفر']
# Stemmed Words: ['خمس']
# Stemmed Words: ['24', 'سفر']
# Stemmed Words: ['خمس']
# Stemmed Words: ['1', 'سفر', '( سفر', 'صلا )']
# Stemmed Words: ['خمس']
# Stemmed Words: ['32', 'سفر']
# Stemmed Words: ['خمس']
# Stemmed Words: ['40', 'سفر']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'في', 'ولاية', 'أوكلاهوما', 'أمريكي', 'قانوني', 'حيازة', 'سلاح ،', 'حيث', 'اعتبر', 'قانون', 'ولاية', '" قانون', 'حق', 'حمل', 'سلاح', 'ناري "', '( Firearms', 'Act )', 'عام', '1911', 'هو', 'قانون', 'رئيسي', 'الذي', 'حدد', 'حق', 'حمل', 'سلاح', 'في', 'ولاية']
# Stemmed Words: ['نعم']
# Stemmed Words: ['اعتبر', 'ولاية', 'أوكلاهوما', 'واحد', 'من', 'ولاية', 'الذي', 'أتاح', 'حماية', 'حق']
# Stemmed Words: ['نعم']
# Stemmed Words: ['Oui ,', 'la', 'possession', "d ' arm"]
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'هي', 'قانوني', 'موجب', 'قانون', 'ولاية', 'أوكلاهوما']
# Stemmed Words: ['نعم']
# Stemmed Words: ['تمتع', 'ولاية', 'أو']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'حيازة', 'سلاح', 'قانوني', 'في', 'ولاية', 'أوكلاهوما', 'أمريكي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'في', 'ولاية', 'أوكلاهوما', 'أمريكي ،', 'حق', 'من', 'وصل', 'إلى', 'سن', '21', 'عام', 'شراء', 'سلاح', 'ناري', 'ذخيرة ،', 'لكن', 'وجب', 'أن', 'كان', 'قد', 'اجتاز', 'فحص', 'تحقق', 'من', 'عدم', 'وجود', 'أي', 'مشكلة', 'صحي', 'أو', 'جنائي']
# Stemmed Words: ['نعم']
# Stemmed Words: ['نعم ،', 'في', 'ولاية', 'أوكلاهوما', 'أمريكي ،', 'حيازة', 'سلاح', 'ناري', 'قانوني ،', 'تطلب', 'فقط', 'بعض', 'قيد ،', 'مثل', 'حصول', 'على', 'ترخيص', 'حيازة', 'سلاح ،', 'تحديد', 'عمر', 'حاصل', 'على', 'ترخيص', 'حيازة', 'سلاح ،', 'تحديد', 'مكان', 'الذي', 'حظر', 'في', 'حيازة', 'سلاح']
# Stemmed Words: ['لا', 'وجد', 'لقاح', 'ضد', 'فيروس', 'سارس']
# Stemmed Words: ['لقاح', 'سارس', 'هو', 'لقاح', 'احتوى', 'على', 'فيروس', 'إبستا', 'معدل', 'جين ،', 'استخدم', 'منع', 'سارس']
# Stemmed Words: ['لا', 'وجد', 'لقاح', 'ضد', 'فيروس', 'سارس']
