# %% [markdown]
# <a href="https://colab.research.google.com/github/Reemaalt/Detection-of-Hallucination-in-Arabic/blob/main/data%20inspection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# downloading the dataset code :)

# %%
#test 1

# %%
import json
import pandas as pd
from google.colab import files

# %%
# 1- Load the file
uploaded = files.upload()

# 2- Read the file line-by-line and store each JSON object in a list

test_set = list(uploaded.keys())[0]

data = []
with open(test_set, 'r', encoding='utf-8') as file:
    for line in file:
        data.append(json.loads(line))

# 3- Convert to a DataFrame
df = pd.DataFrame(data)
# Out:
#      <input type="file" id="files-9db98efb-8589-4f70-aa74-759f45c1eaae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9db98efb-8589-4f70-aa74-759f45c1eaae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from datasets import load_dataset
import pandas as pd

# Load the XQuAD dataset for Arabic (ar)
xquad_dataset = load_dataset("xquad", "xquad.ar")

# Check available splits
print(xquad_dataset)

# Load the validation set (the only available split)
test_set = xquad_dataset['validation']


# Create an empty list to store the data
data = []

# Loop through  and collect data
for i in range(len(test_set)):  # Loop through all samples
    context = test_set[i]['context']
    question = test_set[i]['question']
    answer = test_set[i]['answers']


    # Append the data as a dictionary to the list
    data.append({
        "Context": context,
        "Question": question,
        "Answer": answer
    })

# Convert the list of dictionaries to a pandas DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df2)
# Out:
# DatasetDict({
#     validation: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 1190
#     })
# })
#                                                 Context  \
# 0     لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 1     لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 2     لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 3     لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 4     لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# ...                                                 ...
# 1185  من خلال الجمع بين تعريف التيار الكهربائي كمعدل...
# 1186  حيث هي منطقة المقطع العرضي ذات الصلة للحجم الذ...
# 1187  حيث هي منطقة المقطع العرضي ذات الصلة للحجم الذ...
# 1188  حيث هي منطقة المقطع العرضي ذات الصلة للحجم الذ...
# 1189  حيث هي منطقة المقطع العرضي ذات الصلة للحجم الذ...
#
#                                                Question  \
# 0                      كم نقطة تخلى عنها دفاع البانثرز؟
# ...

# %%
#Inspect the Data
print(df2.head())
print("-" * 50)
print(df2.info()) # overall structure
print("-" * 50)
print(df2.shape) # Shape (Rows, Columns)
print("-" * 50)
print(df2.isnull().sum()) # check for missing values
print("-" * 50)
print(df2.describe()) # summary statistics
# Out:
#                                              Context  \
# 0  لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 1  لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 2  لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 3  لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
# 4  لم يتخلى فريق بانثرز سوى عن 308 نقطة، ليحتل ال...
#
#                                             Question  \
# 0                   كم نقطة تخلى عنها دفاع البانثرز؟
# 1  كم عدد الاستحواذات التي قام بها جاريد ألين في ...
# 2                           كم عرقلة سجل لوك كوتشلي؟
# 3                        كم من كرة اعترض جوش نورمان؟
# 4  من سجل أعلى عدد من الاستحواذات للفريق هذا الموسم؟
#
#                                             Answer
# 0          {'text': ['308'], 'answer_start': [29]}
# 1         {'text': ['136'], 'answer_start': [557]}
# 2         {'text': ['118'], 'answer_start': [888]}
# 3       {'text': ['أربعة'], 'answer_start': [158]}
# 4  {'text': ['كاوان شورت'], 'answer_start': [216]}
# ...

# %%
#Inspect a random  Sample of Rows
random_samples = df.sample(n=25)

for i, row in random_samples.iterrows():
    print(f"Sample {i+1}:")
    print(f"Question: {row['question']}")
    print(f"Answer: {row['answer']}\n")
    print("-" * 50)
# Out:
# Sample 1700:
# Question: أين وُلد كامل كوزما؟
#
# Answer: في ستروبكوف في سلوفاكيا
#
# --------------------------------------------------
# Sample 4923:
# Question: ما هي الأراضي التي تضمنتها جزر الهند الغربية الإسبانية في الزمان الحالي؟
#
#
#
#
# Answer:  تضمنت جزر الهند الغربية الإسبانية الأراضي التي تشكل حاليًا
#
# --------------------------------------------------
# Sample 1336:
# Question: من هو قائد البوجينكان؟
# Answer:  ماساكي هاتسومي
#
# --------------------------------------------------
# Sample 686:
# Question: ما هي أولى الحركات الانفصالية عن الدولة العباسية؟
# Answer: الانشقاق بين رعايا الدولة
#
# --------------------------------------------------
# Sample 10680:
# Question: كم بلغت نسبة فجوة الفقر في منطقة الساحل الغربي في عام 2003؟
#
#
# Answer:  22.4 في المائة
#
# --------------------------------------------------
# Sample 6221:
# Question: ما هي وظيفة تجربة سبايدر؟
#
# Answer: مصممة للبحث عن المطبوعة على إشعاع الخلفية الكونية الميكروي
#
# ...
